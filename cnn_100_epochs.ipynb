# %%
# univariate multi-step vector-output 1d cnn example
from numpy import array
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
import pandas as pd

from math import log
from math import exp
from scipy.stats import boxcox

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps_in, n_steps_out):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps_in
		out_end_ix = end_ix + n_steps_out
		# check if we are beyond the sequence
		if out_end_ix > len(sequence):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# %%
# invert a boxcox transform for one value
def invert_boxcox(value, lam):
	# log case
	if lam == 0:
		return exp(value)
	# all other cases
	return exp(log(lam * value + 1) / lam)

# %%
data = pd.read_csv("Timeseries_real_data_interview.csv")
t = data.iloc[0:11964] #11565
v = data.iloc[11964:19940]
ts = data.iloc[19940:20001]
# define input sequence
train_seq = t['Value'].values
val_seq = v['Value'].values
test_seq = ts['Value'].values

tr, tr_lamb = boxcox(train_seq)
vl, vl_lamb = boxcox(val_seq)
ts, ts_lamb = boxcox(test_seq)

print('Training Sequence : %d'%len(train_seq))
print('Validation Sequence : %d'%len(val_seq))
print('Testing Sequence : %d'%len(test_seq))
# Out:
# Training Sequence : 11964
# Validation Sequence : 7976
# Testing Sequence : 60

# %%
# choose a number of time steps
n_steps_in, n_steps_out = 30, 30
# split into samples
X_train, y_train = split_sequence(tr, n_steps_in, n_steps_out)
X_val, y_val = split_sequence(vl, n_steps_in, n_steps_out)
X_test, y_test = split_sequence(ts, n_steps_in, n_steps_out)
# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], n_features))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))

# %%
# define model
import keras.backend as kb

def r2_score(y_true, y_pred):
    ss_res = kb.sum(kb.square(y_true - y_pred))
    ss_tot = kb.sum(kb.square(y_true - kb.mean(y_true)))
    return (1 - ss_res/(ss_tot + kb.epsilon()))

model = Sequential()
model.add(Conv1D(filters=126, kernel_size=2, activation='tanh', input_shape=(n_steps_in, n_features), kernel_regularizer=keras.regularizers.l2(l=0.01), kernel_initializer='he_normal'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(n_steps_out))

adam = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=adam, loss='mse', metrics=[r2_score, 'mae', keras.metrics.RootMeanSquaredError()])

# %%
# fit model
history = model.fit(X_train, y_train, epochs=100, verbose=1, validation_data=(X_val, y_val), batch_size=64)
# Out:
# Epoch 1/100
# 187/187 [==============================] - 5s 26ms/step - loss: 41.2502 - r2_score: 0.1189 - mae: 4.7940 - root_mean_squared_error: 6.2407 - val_loss: 76.6351 - val_r2_score: -2.3904 - val_mae: 7.6510 - val_root_mean_squared_error: 8.6360
# Epoch 2/100
# 187/187 [==============================] - 4s 21ms/step - loss: 12.7336 - r2_score: 0.7545 - mae: 2.5469 - root_mean_squared_error: 3.2968 - val_loss: 40.6675 - val_r2_score: -0.7720 - val_mae: 5.3636 - val_root_mean_squared_error: 6.2432
# Epoch 3/100
# 187/187 [==============================] - 4s 19ms/step - loss: 10.0285 - r2_score: 0.8082 - mae: 2.1965 - root_mean_squared_error: 2.9119 - val_loss: 27.8481 - val_r2_score: -0.2032 - val_mae: 4.2434 - val_root_mean_squared_error: 5.1409
# Epoch 4/100
# 187/187 [==============================] - 3s 18ms/step - loss: 9.0223 - r2_score: 0.8256 - mae: 2.0676 - root_mean_squared_error: 2.7765 - val_loss: 18.7779 - val_r2_score: 0.2010 - val_mae: 3.2988 - val_root_mean_squared_error: 4.1909
# Epoch 5/100
# 187/187 [==============================] - 3s 19ms/step - loss: 8.3955 - r2_score: 0.8358 - mae: 1.9871 - root_mean_squared_error: 2.6948 - val_loss: 18.7269 - val_r2_score: 0.1990 - val_mae: 3.3391 - val_root_mean_squared_error: 4.2034
# Epoch 6/100
# 187/187 [==============================] - 3s 18ms/step - loss: 7.9989 - r2_score: 0.8415 - mae: 1.9370 - root_mean_squared_error: 2.6462 - val_loss: 13.4331 - val_r2_score: 0.4354 - val_mae: 2.6892 - val_root_mean_squared_error: 3.5348
# Epoch 7/100
# 187/187 [==============================] - 3s 18ms/step - loss: 7.6903 - r2_score: 0.8463 - mae: 1.9028 - root_mean_squared_error: 2.6078 - val_loss: 13.7360 - val_r2_score: 0.4188 - val_mae: 2.7494 - val_root_mean_squared_error: 3.5905
# Epoch 8/100
# 187/187 [==============================] - 3s 19ms/step - loss: 7.5072 - r2_score: 0.8474 - mae: 1.8822 - root_mean_squared_error: 2.5886 - val_loss: 13.2083 - val_r2_score: 0.4403 - val_mae: 2.6940 - val_root_mean_squared_error: 3.5267
# Epoch 9/100
# 187/187 [==============================] - 3s 18ms/step - loss: 7.3578 - r2_score: 0.8502 - mae: 1.8685 - root_mean_squared_error: 2.5722 - val_loss: 13.2695 - val_r2_score: 0.4355 - val_mae: 2.7162 - val_root_mean_squared_error: 3.5433
# Epoch 10/100
# 187/187 [==============================] - 4s 19ms/step - loss: 7.1806 - r2_score: 0.8528 - mae: 1.8426 - root_mean_squared_error: 2.5474 - val_loss: 9.5397 - val_r2_score: 0.6032 - val_mae: 2.1928 - val_root_mean_squared_error: 2.9782
# Epoch 11/100
# 187/187 [==============================] - 3s 18ms/step - loss: 7.0813 - r2_score: 0.8546 - mae: 1.8340 - root_mean_squared_error: 2.5357 - val_loss: 9.0850 - val_r2_score: 0.6225 - val_mae: 2.1336 - val_root_mean_squared_error: 2.9070
# Epoch 12/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.9747 - r2_score: 0.8559 - mae: 1.8189 - root_mean_squared_error: 2.5208 - val_loss: 10.3536 - val_r2_score: 0.5636 - val_mae: 2.3186 - val_root_mean_squared_error: 3.1221
# Epoch 13/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.8788 - r2_score: 0.8579 - mae: 1.8056 - root_mean_squared_error: 2.5069 - val_loss: 10.4329 - val_r2_score: 0.5590 - val_mae: 2.3268 - val_root_mean_squared_error: 3.1385
# Epoch 14/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.8120 - r2_score: 0.8586 - mae: 1.7976 - root_mean_squared_error: 2.4978 - val_loss: 10.5946 - val_r2_score: 0.5508 - val_mae: 2.3542 - val_root_mean_squared_error: 3.1672
# Epoch 15/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.7524 - r2_score: 0.8599 - mae: 1.7909 - root_mean_squared_error: 2.4895 - val_loss: 8.2285 - val_r2_score: 0.6578 - val_mae: 2.0134 - val_root_mean_squared_error: 2.7716
# Epoch 16/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.6903 - r2_score: 0.8609 - mae: 1.7828 - root_mean_squared_error: 2.4802 - val_loss: 8.7075 - val_r2_score: 0.6353 - val_mae: 2.0861 - val_root_mean_squared_error: 2.8594
# Epoch 17/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.6615 - r2_score: 0.8612 - mae: 1.7795 - root_mean_squared_error: 2.4773 - val_loss: 8.0771 - val_r2_score: 0.6636 - val_mae: 2.0000 - val_root_mean_squared_error: 2.74954 - mae: 1.7915 - root_mean - ETA: 1s - loss: 6.6840 - r2_score: 0.8610 - mae: 1.7821 - root_mean_squared_error: 2. - ETA: 0s - loss: 6.6537 - r2_score: 0.8615 - mae: 1.7788 - root_mean_squared_error: 2. - ETA: 0s - loss: 6.6451 - r2_score: 0.8617 - mae: 1.7777 - r
# Epoch 18/100
# 187/187 [==============================] - 4s 19ms/step - loss: 6.6120 - r2_score: 0.8616 - mae: 1.7731 - root_mean_squared_error: 2.4701 - val_loss: 7.4436 - val_r2_score: 0.6923 - val_mae: 1.9243 - val_root_mean_squared_error: 2.6344
# Epoch 19/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.5883 - r2_score: 0.8625 - mae: 1.7719 - root_mean_squared_error: 2.4681 - val_loss: 7.6338 - val_r2_score: 0.6826 - val_mae: 1.9379 - val_root_mean_squared_error: 2.6727
# Epoch 20/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.5374 - r2_score: 0.8631 - mae: 1.7644 - root_mean_squared_error: 2.4604 - val_loss: 9.1369 - val_r2_score: 0.6132 - val_mae: 2.1472 - val_root_mean_squared_error: 2.9427
# Epoch 21/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.5247 - r2_score: 0.8633 - mae: 1.7637 - root_mean_squared_error: 2.4604 - val_loss: 8.8884 - val_r2_score: 0.6242 - val_mae: 2.1134 - val_root_mean_squared_error: 2.9024
# Epoch 22/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.4950 - r2_score: 0.8638 - mae: 1.7608 - root_mean_squared_error: 2.4570 - val_loss: 8.5791 - val_r2_score: 0.6377 - val_mae: 2.0690 - val_root_mean_squared_error: 2.8508
# Epoch 23/100
# 187/187 [==============================] - 3s 19ms/step - loss: 6.4481 - r2_score: 0.8641 - mae: 1.7554 - root_mean_squared_error: 2.4500 - val_loss: 8.5932 - val_r2_score: 0.6364 - val_mae: 2.0726 - val_root_mean_squared_error: 2.8556_mean_squ
# Epoch 24/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.4326 - r2_score: 0.8622 - mae: 1.7550 - root_mean_squared_error: 2.4495 - val_loss: 7.4060 - val_r2_score: 0.6906 - val_mae: 1.9314 - val_root_mean_squared_error: 2.6419
# Epoch 25/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.4519 - r2_score: 0.8610 - mae: 1.7602 - root_mean_squared_error: 2.4560 - val_loss: 8.0947 - val_r2_score: 0.6578 - val_mae: 2.0100 - val_root_mean_squared_error: 2.7714
# Epoch 26/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.5062 - r2_score: 0.8621 - mae: 1.7702 - root_mean_squared_error: 2.4695 - val_loss: 11.3825 - val_r2_score: 0.5083 - val_mae: 2.4989 - val_root_mean_squared_error: 3.3137
# Epoch 27/100
# 187/187 [==============================] - 4s 19ms/step - loss: 6.3968 - r2_score: 0.8625 - mae: 1.7542 - root_mean_squared_error: 2.4496 - val_loss: 6.9104 - val_r2_score: 0.7116 - val_mae: 1.8726 - val_root_mean_squared_error: 2.5535
# Epoch 28/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.4177 - r2_score: 0.8633 - mae: 1.7594 - root_mean_squared_error: 2.4562 - val_loss: 8.0184 - val_r2_score: 0.6598 - val_mae: 2.0057 - val_root_mean_squared_error: 2.7640
# Epoch 29/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.3658 - r2_score: 0.8629 - mae: 1.7527 - root_mean_squared_error: 2.4480 - val_loss: 6.4870 - val_r2_score: 0.7337 - val_mae: 1.9344 - val_root_mean_squared_error: 2.47383786 - r2_score: 0.8642 - mae: 1.7550 - root_mean
# Epoch 30/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.5009 - r2_score: 0.8612 - mae: 1.7823 - root_mean_squared_error: 2.4776 - val_loss: 8.9584 - val_r2_score: 0.6158 - val_mae: 2.1392 - val_root_mean_squared_error: 2.9328
# Epoch 31/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.3156 - r2_score: 0.8652 - mae: 1.7470 - root_mean_squared_error: 2.4420 - val_loss: 7.4905 - val_r2_score: 0.6823 - val_mae: 1.9351 - val_root_mean_squared_error: 2.6727
# Epoch 32/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.3067 - r2_score: 0.8649 - mae: 1.7474 - root_mean_squared_error: 2.4422 - val_loss: 7.3523 - val_r2_score: 0.6882 - val_mae: 1.9304 - val_root_mean_squared_error: 2.6486
# Epoch 33/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.2928 - r2_score: 0.8652 - mae: 1.7479 - root_mean_squared_error: 2.4415 - val_loss: 9.1462 - val_r2_score: 0.6056 - val_mae: 2.1658 - val_root_mean_squared_error: 2.9698
# Epoch 34/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.2981 - r2_score: 0.8644 - mae: 1.7503 - root_mean_squared_error: 2.4447 - val_loss: 7.3445 - val_r2_score: 0.6878 - val_mae: 1.9315 - val_root_mean_squared_error: 2.6510
# Epoch 35/100
# 187/187 [==============================] - 4s 19ms/step - loss: 6.2793 - r2_score: 0.8647 - mae: 1.7487 - root_mean_squared_error: 2.4429 - val_loss: 7.7981 - val_r2_score: 0.6661 - val_mae: 1.9861 - val_root_mean_squared_error: 2.7371
# Epoch 36/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.2772 - r2_score: 0.8641 - mae: 1.7486 - root_mean_squared_error: 2.4446 - val_loss: 6.7307 - val_r2_score: 0.7156 - val_mae: 1.8637 - val_root_mean_squared_error: 2.5366
# Epoch 37/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.2701 - r2_score: 0.8647 - mae: 1.7500 - root_mean_squared_error: 2.4451 - val_loss: 6.5562 - val_r2_score: 0.7230 - val_mae: 1.8408 - val_root_mean_squared_error: 2.5039
# Epoch 38/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.2503 - r2_score: 0.8637 - mae: 1.7480 - root_mean_squared_error: 2.4431 - val_loss: 7.8153 - val_r2_score: 0.6642 - val_mae: 1.9943 - val_root_mean_squared_error: 2.74566.2967 - r2_score
# Epoch 39/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.2363 - r2_score: 0.8653 - mae: 1.7480 - root_mean_squared_error: 2.4421 - val_loss: 8.4952 - val_r2_score: 0.6325 - val_mae: 2.0763 - val_root_mean_squared_error: 2.8684
# Epoch 40/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.2078 - r2_score: 0.8656 - mae: 1.7442 - root_mean_squared_error: 2.4382 - val_loss: 9.1365 - val_r2_score: 0.6033 - val_mae: 2.1718 - val_root_mean_squared_error: 2.9796
# Epoch 41/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.2027 - r2_score: 0.8653 - mae: 1.7441 - root_mean_squared_error: 2.4390 - val_loss: 7.1128 - val_r2_score: 0.6950 - val_mae: 1.9056 - val_root_mean_squared_error: 2.6197
# Epoch 42/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.2174 - r2_score: 0.8645 - mae: 1.7489 - root_mean_squared_error: 2.4437 - val_loss: 10.8157 - val_r2_score: 0.5264 - val_mae: 2.4331 - val_root_mean_squared_error: 3.2518
# Epoch 43/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.2338 - r2_score: 0.8616 - mae: 1.7516 - root_mean_squared_error: 2.4487 - val_loss: 6.4058 - val_r2_score: 0.7284 - val_mae: 1.8652 - val_root_mean_squared_error: 2.4843
# Epoch 44/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.2618 - r2_score: 0.8633 - mae: 1.7580 - root_mean_squared_error: 2.4559 - val_loss: 7.8812 - val_r2_score: 0.6588 - val_mae: 2.0012 - val_root_mean_squared_error: 2.7667
# Epoch 45/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.1685 - r2_score: 0.8652 - mae: 1.7448 - root_mean_squared_error: 2.4383 - val_loss: 9.6729 - val_r2_score: 0.5770 - val_mae: 2.2652 - val_root_mean_squared_error: 3.0746
# Epoch 46/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.1897 - r2_score: 0.8646 - mae: 1.7474 - root_mean_squared_error: 2.4440 - val_loss: 7.5849 - val_r2_score: 0.6718 - val_mae: 1.9687 - val_root_mean_squared_error: 2.7151
# Epoch 47/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.1651 - r2_score: 0.8649 - mae: 1.7442 - root_mean_squared_error: 2.4404 - val_loss: 8.2893 - val_r2_score: 0.6393 - val_mae: 2.0676 - val_root_mean_squared_error: 2.8431
# Epoch 48/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.1448 - r2_score: 0.8659 - mae: 1.7420 - root_mean_squared_error: 2.4375 - val_loss: 8.1073 - val_r2_score: 0.6471 - val_mae: 2.0381 - val_root_mean_squared_error: 2.8120
# Epoch 49/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.1234 - r2_score: 0.8662 - mae: 1.7383 - root_mean_squared_error: 2.4345 - val_loss: 6.1996 - val_r2_score: 0.7356 - val_mae: 1.8299 - val_root_mean_squared_error: 2.4507
# Epoch 50/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.1452 - r2_score: 0.8655 - mae: 1.7454 - root_mean_squared_error: 2.4402 - val_loss: 6.5452 - val_r2_score: 0.7188 - val_mae: 1.8567 - val_root_mean_squared_error: 2.5214
# Epoch 51/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.1468 - r2_score: 0.8654 - mae: 1.7471 - root_mean_squared_error: 2.4417 - val_loss: 8.6105 - val_r2_score: 0.6233 - val_mae: 2.1097 - val_root_mean_squared_error: 2.9032
# Epoch 52/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.1046 - r2_score: 0.8659 - mae: 1.7385 - root_mean_squared_error: 2.4342 - val_loss: 7.3933 - val_r2_score: 0.6786 - val_mae: 1.9433 - val_root_mean_squared_error: 2.6864
# Epoch 53/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.1309 - r2_score: 0.8651 - mae: 1.7458 - root_mean_squared_error: 2.4407 - val_loss: 8.1331 - val_r2_score: 0.6444 - val_mae: 2.0500 - val_root_mean_squared_error: 2.8217
# Epoch 54/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.0974 - r2_score: 0.8656 - mae: 1.7396 - root_mean_squared_error: 2.4349 - val_loss: 7.5571 - val_r2_score: 0.6705 - val_mae: 1.9697 - val_root_mean_squared_error: 2.7186
# Epoch 55/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.0924 - r2_score: 0.8658 - mae: 1.7396 - root_mean_squared_error: 2.4349 - val_loss: 8.5587 - val_r2_score: 0.6247 - val_mae: 2.1072 - val_root_mean_squared_error: 2.8979
# Epoch 56/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.0788 - r2_score: 0.8652 - mae: 1.7387 - root_mean_squared_error: 2.4331 - val_loss: 8.0201 - val_r2_score: 0.6491 - val_mae: 2.0308 - val_root_mean_squared_error: 2.8043
# Epoch 57/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.1227 - r2_score: 0.8652 - mae: 1.7481 - root_mean_squared_error: 2.4431 - val_loss: 8.7816 - val_r2_score: 0.6141 - val_mae: 2.1354 - val_root_mean_squared_error: 2.9377
# Epoch 58/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.0860 - r2_score: 0.8653 - mae: 1.7417 - root_mean_squared_error: 2.4365 - val_loss: 10.1033 - val_r2_score: 0.5545 - val_mae: 2.3387 - val_root_mean_squared_error: 3.1553
# Epoch 59/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.1414 - r2_score: 0.8642 - mae: 1.7512 - root_mean_squared_error: 2.4487 - val_loss: 6.6419 - val_r2_score: 0.7123 - val_mae: 1.8791 - val_root_mean_squared_error: 2.5492
# Epoch 60/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.0825 - r2_score: 0.8657 - mae: 1.7430 - root_mean_squared_error: 2.4374 - val_loss: 8.1764 - val_r2_score: 0.6410 - val_mae: 2.0505 - val_root_mean_squared_error: 2.8349652 - mae: 1.7446 - root_mean_squared_err
# Epoch 61/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.0794 - r2_score: 0.8658 - mae: 1.7428 - root_mean_squared_error: 2.4375 - val_loss: 7.7599 - val_r2_score: 0.6598 - val_mae: 1.9940 - val_root_mean_squared_error: 2.7611
# Epoch 62/100
# 187/187 [==============================] - 3s 19ms/step - loss: 6.0461 - r2_score: 0.8660 - mae: 1.7368 - root_mean_squared_error: 2.4314 - val_loss: 7.6710 - val_r2_score: 0.6639 - val_mae: 1.9871 - val_root_mean_squared_error: 2.7456
# Epoch 63/100
# 187/187 [==============================] - 3s 17ms/step - loss: 6.0558 - r2_score: 0.8655 - mae: 1.7396 - root_mean_squared_error: 2.4341 - val_loss: 6.7991 - val_r2_score: 0.7040 - val_mae: 1.8845 - val_root_mean_squared_error: 2.5826
# Epoch 64/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.0904 - r2_score: 0.8651 - mae: 1.7465 - root_mean_squared_error: 2.4419 - val_loss: 6.6712 - val_r2_score: 0.7102 - val_mae: 1.8829 - val_root_mean_squared_error: 2.5584
# Epoch 65/100
# 187/187 [==============================] - 3s 19ms/step - loss: 6.0643 - r2_score: 0.8658 - mae: 1.7440 - root_mean_squared_error: 2.4373 - val_loss: 8.2451 - val_r2_score: 0.6368 - val_mae: 2.0655 - val_root_mean_squared_error: 2.8500
# Epoch 66/100
# 187/187 [==============================] - 3s 17ms/step - loss: 6.0485 - r2_score: 0.8661 - mae: 1.7384 - root_mean_squared_error: 2.4347 - val_loss: 9.2929 - val_r2_score: 0.5891 - val_mae: 2.2177 - val_root_mean_squared_error: 3.0288
# Epoch 67/100
# 187/187 [==============================] - 3s 17ms/step - loss: 6.0401 - r2_score: 0.8654 - mae: 1.7387 - root_mean_squared_error: 2.4336 - val_loss: 6.1253 - val_r2_score: 0.7355 - val_mae: 1.8372 - val_root_mean_squared_error: 2.4513
# Epoch 68/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.0489 - r2_score: 0.8647 - mae: 1.7428 - root_mean_squared_error: 2.4360 - val_loss: 6.5270 - val_r2_score: 0.7162 - val_mae: 1.8576 - val_root_mean_squared_error: 2.5325
# Epoch 69/100
# 187/187 [==============================] - 3s 17ms/step - loss: 6.0462 - r2_score: 0.8655 - mae: 1.7401 - root_mean_squared_error: 2.4360 - val_loss: 6.5387 - val_r2_score: 0.7162 - val_mae: 1.8793 - val_root_mean_squared_error: 2.5353
# Epoch 70/100
# 187/187 [==============================] - 4s 20ms/step - loss: 6.0244 - r2_score: 0.8662 - mae: 1.7388 - root_mean_squared_error: 2.4321 - val_loss: 7.4093 - val_r2_score: 0.6746 - val_mae: 1.9488 - val_root_mean_squared_error: 2.7021
# Epoch 71/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.0018 - r2_score: 0.8638 - mae: 1.7340 - root_mean_squared_error: 2.4280 - val_loss: 6.3493 - val_r2_score: 0.7286 - val_mae: 1.9703 - val_root_mean_squared_error: 2.4987
# Epoch 72/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.2071 - r2_score: 0.8622 - mae: 1.7721 - root_mean_squared_error: 2.4704 - val_loss: 9.1016 - val_r2_score: 0.5971 - val_mae: 2.1888 - val_root_mean_squared_error: 2.9997
# Epoch 73/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.0069 - r2_score: 0.8664 - mae: 1.7350 - root_mean_squared_error: 2.4299 - val_loss: 7.4715 - val_r2_score: 0.6716 - val_mae: 1.9688 - val_root_mean_squared_error: 2.71480070 - r2_score: 0.8663 - mae: 1.7351 - root_mean_squared_error: 2.43
# Epoch 74/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.0246 - r2_score: 0.8660 - mae: 1.7407 - root_mean_squared_error: 2.4340 - val_loss: 8.1924 - val_r2_score: 0.6387 - val_mae: 2.0659 - val_root_mean_squared_error: 2.8449
# Epoch 75/100
# 187/187 [==============================] - 3s 19ms/step - loss: 6.0059 - r2_score: 0.8651 - mae: 1.7370 - root_mean_squared_error: 2.4306 - val_loss: 6.9074 - val_r2_score: 0.6979 - val_mae: 1.9118 - val_root_mean_squared_error: 2.6097
# Epoch 76/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.0493 - r2_score: 0.8651 - mae: 1.7447 - root_mean_squared_error: 2.4400 - val_loss: 7.6082 - val_r2_score: 0.6649 - val_mae: 1.9812 - val_root_mean_squared_error: 2.7411
# Epoch 77/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.0241 - r2_score: 0.8660 - mae: 1.7398 - root_mean_squared_error: 2.4352 - val_loss: 7.7630 - val_r2_score: 0.6574 - val_mae: 2.0110 - val_root_mean_squared_error: 2.7695
# Epoch 78/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.0170 - r2_score: 0.8654 - mae: 1.7388 - root_mean_squared_error: 2.4342 - val_loss: 6.3282 - val_r2_score: 0.7244 - val_mae: 1.8502 - val_root_mean_squared_error: 2.4975
# Epoch 79/100
# 187/187 [==============================] - 3s 17ms/step - loss: 6.0531 - r2_score: 0.8654 - mae: 1.7458 - root_mean_squared_error: 2.4420 - val_loss: 9.7247 - val_r2_score: 0.5679 - val_mae: 2.2813 - val_root_mean_squared_error: 3.1042
# Epoch 80/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.0098 - r2_score: 0.8662 - mae: 1.7362 - root_mean_squared_error: 2.4335 - val_loss: 7.0166 - val_r2_score: 0.6917 - val_mae: 1.9082 - val_root_mean_squared_error: 2.6324- mae:
# Epoch 81/100
# 187/187 [==============================] - 3s 17ms/step - loss: 5.9862 - r2_score: 0.8662 - mae: 1.7346 - root_mean_squared_error: 2.4290 - val_loss: 6.3838 - val_r2_score: 0.7219 - val_mae: 1.8665 - val_root_mean_squared_error: 2.5097
# Epoch 82/100
# 187/187 [==============================] - 3s 17ms/step - loss: 6.0178 - r2_score: 0.8654 - mae: 1.7422 - root_mean_squared_error: 2.4359 - val_loss: 6.4097 - val_r2_score: 0.7203 - val_mae: 1.8567 - val_root_mean_squared_error: 2.5152
# Epoch 83/100
# 187/187 [==============================] - 3s 18ms/step - loss: 5.9960 - r2_score: 0.8655 - mae: 1.7368 - root_mean_squared_error: 2.4317 - val_loss: 6.0858 - val_r2_score: 0.7357 - val_mae: 1.8317 - val_root_mean_squared_error: 2.4503
# Epoch 84/100
# 187/187 [==============================] - 3s 18ms/step - loss: 6.0166 - r2_score: 0.8654 - mae: 1.7433 - root_mean_squared_error: 2.4363 - val_loss: 6.9540 - val_r2_score: 0.6944 - val_mae: 1.9016 - val_root_mean_squared_error: 2.6218
# Epoch 85/100
# 187/187 [==============================] - 3s 17ms/step - loss: 6.0076 - r2_score: 0.8658 - mae: 1.7395 - root_mean_squared_error: 2.4348 - val_loss: 6.9475 - val_r2_score: 0.6948 - val_mae: 1.9103 - val_root_mean_squared_error: 2.6208
# Epoch 86/100
# 187/187 [==============================] - 3s 17ms/step - loss: 5.9994 - r2_score: 0.8659 - mae: 1.7392 - root_mean_squared_error: 2.4334 - val_loss: 7.7440 - val_r2_score: 0.6580 - val_mae: 2.0098 - val_root_mean_squared_error: 2.7689
# Epoch 87/100
# 187/187 [==============================] - 3s 18ms/step - loss: 5.9951 - r2_score: 0.8663 - mae: 1.7370 - root_mean_squared_error: 2.4328 - val_loss: 6.1926 - val_r2_score: 0.7299 - val_mae: 1.8270 - val_root_mean_squared_error: 2.4733
# Epoch 88/100
# 187/187 [==============================] - 3s 17ms/step - loss: 5.9871 - r2_score: 0.8665 - mae: 1.7372 - root_mean_squared_error: 2.4315 - val_loss: 8.0370 - val_r2_score: 0.6444 - val_mae: 2.0438 - val_root_mean_squared_error: 2.8219
# Epoch 89/100
# 187/187 [==============================] - 3s 18ms/step - loss: 5.9859 - r2_score: 0.8656 - mae: 1.7361 - root_mean_squared_error: 2.4316 - val_loss: 6.1156 - val_r2_score: 0.7336 - val_mae: 1.8298 - val_root_mean_squared_error: 2.4582
# Epoch 90/100
# 187/187 [==============================] - 3s 17ms/step - loss: 6.0319 - r2_score: 0.8652 - mae: 1.7462 - root_mean_squared_error: 2.4413 - val_loss: 7.2946 - val_r2_score: 0.6782 - val_mae: 1.9475 - val_root_mean_squared_error: 2.6876
# Epoch 91/100
# 187/187 [==============================] - 3s 18ms/step - loss: 5.9724 - r2_score: 0.8656 - mae: 1.7354 - root_mean_squared_error: 2.4293 - val_loss: 6.0304 - val_r2_score: 0.7402 - val_mae: 1.9029 - val_root_mean_squared_error: 2.4414
# Epoch 92/100
# 187/187 [==============================] - 3s 17ms/step - loss: 6.0515 - r2_score: 0.8636 - mae: 1.7521 - root_mean_squared_error: 2.4458 - val_loss: 8.1676 - val_r2_score: 0.6383 - val_mae: 2.0637 - val_root_mean_squared_error: 2.8458
# Epoch 93/100
# 187/187 [==============================] - 3s 17ms/step - loss: 5.9874 - r2_score: 0.8663 - mae: 1.7373 - root_mean_squared_error: 2.4329 - val_loss: 6.7396 - val_r2_score: 0.7038 - val_mae: 1.8729 - val_root_mean_squared_error: 2.5830
# Epoch 94/100
# 187/187 [==============================] - 3s 18ms/step - loss: 5.9701 - r2_score: 0.8654 - mae: 1.7352 - root_mean_squared_error: 2.4296 - val_loss: 6.3052 - val_r2_score: 0.7248 - val_mae: 1.8555 - val_root_mean_squared_error: 2.4978
# Epoch 95/100
# 187/187 [==============================] - 3s 17ms/step - loss: 5.9941 - r2_score: 0.8661 - mae: 1.7407 - root_mean_squared_error: 2.4348 - val_loss: 10.1697 - val_r2_score: 0.5472 - val_mae: 2.3560 - val_root_mean_squared_error: 3.1788
# Epoch 96/100
# 187/187 [==============================] - 3s 18ms/step - loss: 5.9753 - r2_score: 0.8663 - mae: 1.7353 - root_mean_squared_error: 2.4312 - val_loss: 8.9945 - val_r2_score: 0.6005 - val_mae: 2.1816 - val_root_mean_squared_error: 2.9884
# Epoch 97/100
# 187/187 [==============================] - 3s 17ms/step - loss: 5.9881 - r2_score: 0.8657 - mae: 1.7384 - root_mean_squared_error: 2.4340 - val_loss: 6.9580 - val_r2_score: 0.6936 - val_mae: 1.9111 - val_root_mean_squared_error: 2.6258
# Epoch 98/100
# 187/187 [==============================] - 3s 18ms/step - loss: 5.9816 - r2_score: 0.8658 - mae: 1.7378 - root_mean_squared_error: 2.4329 - val_loss: 7.1847 - val_r2_score: 0.6830 - val_mae: 1.9302 - val_root_mean_squared_error: 2.6688
# Epoch 99/100
# 187/187 [==============================] - 3s 18ms/step - loss: 5.9575 - r2_score: 0.8661 - mae: 1.7357 - root_mean_squared_error: 2.4282 - val_loss: 8.6578 - val_r2_score: 0.6157 - val_mae: 2.1346 - val_root_mean_squared_error: 2.9321
# Epoch 100/100
# 187/187 [==============================] - 3s 17ms/step - loss: 5.9691 - r2_score: 0.8655 - mae: 1.7352 - root_mean_squared_error: 2.4308 - val_loss: 7.6483 - val_r2_score: 0.6619 - val_mae: 1.9960 - val_root_mean_squared_error: 2.7547

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('MSE - CNN Model')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/cnn/loss.png')
plt.show()

# %%
plt.plot(history.history['r2_score'])
plt.plot(history.history['val_r2_score'])
plt.title('R2 Score - CNN Model')
plt.ylabel('R2 Score')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/cnn/r2_score.png')
plt.show()

# %%
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('MAE - CNN Model')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/cnn/mae.png')
plt.show()

# %%
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('RMSE - CNN Model')
plt.ylabel('RMSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/cnn/rmse.png')
plt.show()

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='saved/cnn/model.png', show_shapes=True, show_layer_names=True)

# %%
print(model.summary())
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_18 (Conv1D)           (None, 29, 126)           378
# _________________________________________________________________
# max_pooling1d_18 (MaxPooling (None, 14, 126)           0
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 1764)              0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 1764)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 30)                52950
# =================================================================
# Total params: 53,328
# Trainable params: 53,328
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
hist_df = pd.DataFrame(history.history) 
hist_csv_file = 'saved/cnn/history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
prediction = model.predict(X_test, verbose=0)
# Out:
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FEAF9FA3A8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(prediction, y_test)
r2 = r2_score(prediction[0], y_test[0])
print('Predicted MSE : %s'%mse)
print('Predicted R2 Score : %s'%r2)
# Out:
# Predicted MSE : 1.0413548062974043
# Predicted R2 Score : 0.6484340006620677

# %%
y_test[0]
# Out:
# array([14.75274718, 14.52532563, 14.43978398, 14.73415866, 14.93712005,
#        16.31742387, 15.99903992, 15.45547817, 15.7767913 , 16.99510365,
#        17.62197755, 17.53821249, 18.05517037, 17.95538347, 18.22478739,
#        19.54693849, 19.18823898, 20.35027236, 19.03428519, 19.34392341,
#        19.34553527, 18.50742023, 18.4990102 , 17.58222371, 18.34088583,
#        16.5565262 , 16.17991096, 15.69968205, 15.58516797, 15.29423038])

# %%
prediction[0]
# Out:
# array([15.693191, 15.096613, 15.459937, 15.756039, 15.561147, 16.450756,
#        15.702071, 16.379715, 17.060564, 17.509077, 17.597393, 18.398813,
#        18.316305, 18.717337, 19.570261, 20.395449, 20.123568, 20.279127,
#        20.992294, 19.857874, 19.913418, 19.91884 , 19.252468, 18.382038,
#        18.375439, 18.665268, 17.873308, 17.46976 , 16.360237, 16.395798],
#       dtype=float32)

# %%
x = np.arange(30)
y_test_invert = []

# Inverse Box-Cox Transform
for i in range(len(y_test[0])):
    y_test_invert.append(invert_boxcox(y_test[0][i], ts_lamb))
plt.bar(x, y_test_invert)
# Out:
# <BarContainer object of 30 artists>

# %%
x = np.arange(30)
y_prediction_invert = []

# Inverse Box-Cox Transform
for i in range(len(y_test[0])):
    y_prediction_invert.append(invert_boxcox(prediction[0][i], ts_lamb))
plt.bar(x, y_prediction_invert)
# Out:
# <BarContainer object of 30 artists>

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_prediction_invert, y_test_invert)
r2 = r2_score(y_prediction_invert, y_test_invert)
print('Predicted MSE : %s'%mse)
print('Predicted R2 Score : %s'%r2)
# Out:
# Predicted MSE : 94.83848285813048
# Predicted R2 Score : 0.6575378111534304

# %%
y_prediction_invert
# Out:
# [76.5937254238927,
#  71.55177345701351,
#  74.60212886479772,
#  77.13479239343161,
#  75.46309569105773,
#  83.24147981148964,
#  76.67006516948351,
#  82.60642940014968,
#  88.79183916623253,
#  92.98745776918369,
#  93.82492647601825,
#  101.59464072393992,
#  100.78058093049138,
#  104.76778963132047,
#  113.5028624425338,
#  122.28381762956276,
#  119.35485643354808,
#  121.0263822697092,
#  128.83705747272364,
#  116.52656927917063,
#  117.11504919032062,
#  117.17257955204983,
#  110.2077111909813,
#  101.42886718085938,
#  101.36368777215306,
#  104.24576984942993,
#  96.46531302904297,
#  92.61583411593898,
#  82.43273432688942,
#  82.74998522933227]

# %%
y_test_invert
# Out:
# [68.7229498558514,
#  66.88314403489694,
#  66.19753176817476,
#  68.57164266251183,
#  70.2326649574087,
#  82.05158118122326,
#  79.24458484836387,
#  74.56431045526703,
#  77.31386907748917,
#  88.18752142535003,
#  94.05871505735975,
#  93.2633270464537,
#  98.22551788565214,
#  97.25774811541993,
#  99.8814262747274,
#  113.25939803090051,
#  109.54757547020331,
#  121.7946965426342,
#  107.97327128356129,
#  111.15106604868612,
#  111.16772796285335,
#  102.67115334375592,
#  102.58759224070153,
#  93.68081636735795,
#  101.02276466165708,
#  84.19144718319225,
#  80.83327099203122,
#  76.64952386758928,
#  75.66815798045012,
#  73.20307621397502]

# %%
plt.plot(y_test_invert)
plt.plot(y_prediction_invert)
plt.title('CNN - 30 Day Forecast')
plt.ylabel('Rainfall')
plt.xlabel('Days')
plt.legend(['Actual', 'Predicted'], loc='upper left')
plt.savefig('saved/cnn/test.png')
plt.show()
