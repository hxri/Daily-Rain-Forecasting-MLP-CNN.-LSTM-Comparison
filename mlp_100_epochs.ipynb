# %%
# univariate multi-step vector-output 1d cnn example
from numpy import array
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
import pandas as pd

from math import log
from math import exp
from scipy.stats import boxcox

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps_in, n_steps_out):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps_in
		out_end_ix = end_ix + n_steps_out
		# check if we are beyond the sequence
		if out_end_ix > len(sequence):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# %%
# invert a boxcox transform for one value
def invert_boxcox(value, lam):
	# log case
	if lam == 0:
		return exp(value)
	# all other cases
	return exp(log(lam * value + 1) / lam)

# %%
data = pd.read_csv("Timeseries_real_data_interview.csv")
t = data.iloc[0:11964] #11565
v = data.iloc[11964:19940]
ts = data.iloc[19940:20001]
# define input sequence
train_seq = t['Value'].values
val_seq = v['Value'].values
test_seq = ts['Value'].values

tr, tr_lamb = boxcox(train_seq)
vl, vl_lamb = boxcox(val_seq)
ts, ts_lamb = boxcox(test_seq)

print('Training Sequence : %d'%len(train_seq))
print('Validation Sequence : %d'%len(val_seq))
print('Testing Sequence : %d'%len(test_seq))
# Out:
# Training Sequence : 11964
# Validation Sequence : 7976
# Testing Sequence : 60

# %%
# choose a number of time steps
n_steps_in, n_steps_out = 30, 30
# split into samples
X_train, y_train = split_sequence(tr, n_steps_in, n_steps_out)
X_val, y_val = split_sequence(vl, n_steps_in, n_steps_out)
X_test, y_test = split_sequence(ts, n_steps_in, n_steps_out)
# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1

# %%
print(X_train.shape)
# Out:
# (11905, 30)

# %%
# define model
import keras.backend as kb

def r2_score(y_true, y_pred):
    ss_res = kb.sum(kb.square(y_true - y_pred))
    ss_tot = kb.sum(kb.square(y_true - kb.mean(y_true)))
    return (1 - ss_res/(ss_tot + kb.epsilon()))

model = Sequential()
model.add(Dense(140, activation='elu', input_dim=n_steps_in))
model.add(Dropout(0.2))
model.add(Dense(n_steps_out))


adam = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=adam, loss='mse', metrics=[r2_score,'mae', keras.metrics.RootMeanSquaredError()])

# %%
# fit model
history = model.fit(X_train, y_train, epochs=100, verbose=1, validation_data=(X_val, y_val), batch_size=64)
# Out:
# Epoch 1/100
# 187/187 [==============================] - 2s 12ms/step - loss: 52.3739 - r2_score: -0.1812 - mae: 5.0456 - root_mean_squared_error: 7.2370 - val_loss: 7.7028 - val_r2_score: 0.6623 - val_mae: 2.0163 - val_root_mean_squared_error: 2.7754
# Epoch 2/100
# 187/187 [==============================] - 2s 9ms/step - loss: 15.1097 - r2_score: 0.6583 - mae: 3.0125 - root_mean_squared_error: 3.8871 - val_loss: 12.0862 - val_r2_score: 0.4639 - val_mae: 2.7270 - val_root_mean_squared_error: 3.4765
# Epoch 3/100
# 187/187 [==============================] - 2s 10ms/step - loss: 12.5791 - r2_score: 0.7154 - mae: 2.7312 - root_mean_squared_error: 3.5467 - val_loss: 10.8908 - val_r2_score: 0.5164 - val_mae: 2.5530 - val_root_mean_squared_error: 3.3001
# Epoch 4/100
# 187/187 [==============================] - 2s 9ms/step - loss: 11.2717 - r2_score: 0.7452 - mae: 2.5743 - root_mean_squared_error: 3.3573 - val_loss: 12.1021 - val_r2_score: 0.4613 - val_mae: 2.7557 - val_root_mean_squared_error: 3.4788
# Epoch 5/100
# 187/187 [==============================] - 2s 9ms/step - loss: 10.5768 - r2_score: 0.7605 - mae: 2.4781 - root_mean_squared_error: 3.2522 - val_loss: 13.5655 - val_r2_score: 0.3949 - val_mae: 2.9533 - val_root_mean_squared_error: 3.6831
# Epoch 6/100
# 187/187 [==============================] - 2s 9ms/step - loss: 10.0855 - r2_score: 0.7715 - mae: 2.4161 - root_mean_squared_error: 3.1758 - val_loss: 14.0058 - val_r2_score: 0.3743 - val_mae: 3.0435 - val_root_mean_squared_error: 3.7424
# Epoch 7/100
# 187/187 [==============================] - 2s 9ms/step - loss: 9.6670 - r2_score: 0.7812 - mae: 2.3560 - root_mean_squared_error: 3.1092 - val_loss: 12.5027 - val_r2_score: 0.4410 - val_mae: 2.8243 - val_root_mean_squared_error: 3.5359
# Epoch 8/100
# 187/187 [==============================] - 2s 10ms/step - loss: 9.4041 - r2_score: 0.7856 - mae: 2.3205 - root_mean_squared_error: 3.0666 - val_loss: 4.7709 - val_r2_score: 0.7930 - val_mae: 1.5494 - val_root_mean_squared_error: 2.1842
# Epoch 9/100
# 187/187 [==============================] - 2s 9ms/step - loss: 9.3314 - r2_score: 0.7885 - mae: 2.3099 - root_mean_squared_error: 3.0547 - val_loss: 5.0783 - val_r2_score: 0.7778 - val_mae: 1.5605 - val_root_mean_squared_error: 2.2535
# Epoch 10/100
# 187/187 [==============================] - 2s 11ms/step - loss: 9.0384 - r2_score: 0.7956 - mae: 2.2679 - root_mean_squared_error: 3.0064 - val_loss: 17.7403 - val_r2_score: 0.2050 - val_mae: 3.5695 - val_root_mean_squared_error: 4.2119
# Epoch 11/100
# 187/187 [==============================] - 2s 9ms/step - loss: 8.9512 - r2_score: 0.7969 - mae: 2.2532 - root_mean_squared_error: 2.9919 - val_loss: 5.6972 - val_r2_score: 0.7489 - val_mae: 1.6641 - val_root_mean_squared_error: 2.3869
# Epoch 12/100
# 187/187 [==============================] - 2s 9ms/step - loss: 8.9207 - r2_score: 0.7986 - mae: 2.2517 - root_mean_squared_error: 2.9868 - val_loss: 12.9849 - val_r2_score: 0.4175 - val_mae: 2.9031 - val_root_mean_squared_error: 3.6035
# Epoch 13/100
# 187/187 [==============================] - 2s 9ms/step - loss: 8.6534 - r2_score: 0.8035 - mae: 2.2067 - root_mean_squared_error: 2.9417 - val_loss: 11.4357 - val_r2_score: 0.4877 - val_mae: 2.6235 - val_root_mean_squared_error: 3.3817
# Epoch 14/100
# 187/187 [==============================] - 2s 9ms/step - loss: 8.5988 - r2_score: 0.8040 - mae: 2.2006 - root_mean_squared_error: 2.9324 - val_loss: 11.3828 - val_r2_score: 0.4901 - val_mae: 2.6463 - val_root_mean_squared_error: 3.3738
# Epoch 15/100
# 187/187 [==============================] - 2s 10ms/step - loss: 8.5545 - r2_score: 0.8061 - mae: 2.1964 - root_mean_squared_error: 2.9248 - val_loss: 17.6276 - val_r2_score: 0.2074 - val_mae: 3.5463 - val_root_mean_squared_error: 4.1985
# Epoch 16/100
# 187/187 [==============================] - 2s 9ms/step - loss: 8.5094 - r2_score: 0.8072 - mae: 2.1881 - root_mean_squared_error: 2.9171 - val_loss: 8.2136 - val_r2_score: 0.6331 - val_mae: 2.1093 - val_root_mean_squared_error: 2.8659
# Epoch 17/100
# 187/187 [==============================] - 2s 9ms/step - loss: 8.3195 - r2_score: 0.8119 - mae: 2.1563 - root_mean_squared_error: 2.8844 - val_loss: 9.6339 - val_r2_score: 0.5688 - val_mae: 2.3599 - val_root_mean_squared_error: 3.1038
# Epoch 18/100
# 187/187 [==============================] - 2s 9ms/step - loss: 8.2615 - r2_score: 0.8127 - mae: 2.1474 - root_mean_squared_error: 2.8743 - val_loss: 17.4146 - val_r2_score: 0.2173 - val_mae: 3.5085 - val_root_mean_squared_error: 4.1731
# Epoch 19/100
# 187/187 [==============================] - 2s 9ms/step - loss: 8.2235 - r2_score: 0.8141 - mae: 2.1458 - root_mean_squared_error: 2.8677 - val_loss: 11.4070 - val_r2_score: 0.4883 - val_mae: 2.6441 - val_root_mean_squared_error: 3.3774
# Epoch 20/100
# 187/187 [==============================] - 2s 9ms/step - loss: 8.1912 - r2_score: 0.8150 - mae: 2.1417 - root_mean_squared_error: 2.8620 - val_loss: 8.2669 - val_r2_score: 0.6313 - val_mae: 2.1180 - val_root_mean_squared_error: 2.8752
# Epoch 21/100
# 187/187 [==============================] - 2s 9ms/step - loss: 8.1306 - r2_score: 0.8162 - mae: 2.1282 - root_mean_squared_error: 2.8514 - val_loss: 9.5055 - val_r2_score: 0.5743 - val_mae: 2.3326 - val_root_mean_squared_error: 3.0831
# Epoch 22/100
# 187/187 [==============================] - 2s 10ms/step - loss: 8.0147 - r2_score: 0.8186 - mae: 2.1103 - root_mean_squared_error: 2.8310 - val_loss: 5.4204 - val_r2_score: 0.7620 - val_mae: 1.6406 - val_root_mean_squared_error: 2.3282
# Epoch 23/100
# 187/187 [==============================] - 2s 9ms/step - loss: 8.0396 - r2_score: 0.8181 - mae: 2.1172 - root_mean_squared_error: 2.8354 - val_loss: 12.6021 - val_r2_score: 0.4344 - val_mae: 2.8345 - val_root_mean_squared_error: 3.5499
# Epoch 24/100
# 187/187 [==============================] - 2s 9ms/step - loss: 7.9637 - r2_score: 0.8201 - mae: 2.1000 - root_mean_squared_error: 2.8220 - val_loss: 9.9574 - val_r2_score: 0.5542 - val_mae: 2.4131 - val_root_mean_squared_error: 3.1555
# Epoch 25/100
# 187/187 [==============================] - 2s 10ms/step - loss: 7.9364 - r2_score: 0.8201 - mae: 2.0983 - root_mean_squared_error: 2.8172 - val_loss: 11.1476 - val_r2_score: 0.4998 - val_mae: 2.6018 - val_root_mean_squared_error: 3.3388
# Epoch 26/100
# 187/187 [==============================] - 2s 9ms/step - loss: 7.9940 - r2_score: 0.8188 - mae: 2.1080 - root_mean_squared_error: 2.8274 - val_loss: 26.3061 - val_r2_score: -0.1818 - val_mae: 4.5890 - val_root_mean_squared_error: 5.1289
# Epoch 27/100
# 187/187 [==============================] - 2s 8ms/step - loss: 8.0158 - r2_score: 0.8183 - mae: 2.1093 - root_mean_squared_error: 2.8312 - val_loss: 16.4093 - val_r2_score: 0.2635 - val_mae: 3.4026 - val_root_mean_squared_error: 4.0508
# Epoch 28/100
# 187/187 [==============================] - 2s 9ms/step - loss: 7.9592 - r2_score: 0.8197 - mae: 2.1002 - root_mean_squared_error: 2.8212 - val_loss: 12.7454 - val_r2_score: 0.4287 - val_mae: 2.8128 - val_root_mean_squared_error: 3.5701
# Epoch 29/100
# 187/187 [==============================] - 2s 9ms/step - loss: 7.8540 - r2_score: 0.8222 - mae: 2.0848 - root_mean_squared_error: 2.8025 - val_loss: 8.0190 - val_r2_score: 0.6429 - val_mae: 2.0663 - val_root_mean_squared_error: 2.8318
# Epoch 30/100
# 187/187 [==============================] - 3s 14ms/step - loss: 7.8831 - r2_score: 0.8213 - mae: 2.0884 - root_mean_squared_error: 2.8077 - val_loss: 6.5247 - val_r2_score: 0.7109 - val_mae: 1.8140 - val_root_mean_squared_error: 2.5543
# Epoch 31/100
# 187/187 [==============================] - 1s 7ms/step - loss: 7.8634 - r2_score: 0.8221 - mae: 2.0856 - root_mean_squared_error: 2.8042 - val_loss: 12.1470 - val_r2_score: 0.4563 - val_mae: 2.7634 - val_root_mean_squared_error: 3.4853
# Epoch 32/100
# 187/187 [==============================] - 1s 5ms/step - loss: 7.8488 - r2_score: 0.8210 - mae: 2.0833 - root_mean_squared_error: 2.8016 - val_loss: 18.3224 - val_r2_score: 0.1771 - val_mae: 3.6263 - val_root_mean_squared_error: 4.2805
# Epoch 33/100
# 187/187 [==============================] - 1s 5ms/step - loss: 7.9946 - r2_score: 0.8191 - mae: 2.1043 - root_mean_squared_error: 2.8275 - val_loss: 13.2164 - val_r2_score: 0.4079 - val_mae: 2.9470 - val_root_mean_squared_error: 3.6354
# Epoch 34/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.7635 - r2_score: 0.8241 - mae: 2.0690 - root_mean_squared_error: 2.7863 - val_loss: 7.9530 - val_r2_score: 0.6456 - val_mae: 2.0624 - val_root_mean_squared_error: 2.8201
# Epoch 35/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.6971 - r2_score: 0.8262 - mae: 2.0573 - root_mean_squared_error: 2.7744 - val_loss: 11.0225 - val_r2_score: 0.5065 - val_mae: 2.5964 - val_root_mean_squared_error: 3.3200
# Epoch 36/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.7190 - r2_score: 0.8252 - mae: 2.0622 - root_mean_squared_error: 2.7783 - val_loss: 5.1520 - val_r2_score: 0.7744 - val_mae: 1.5814 - val_root_mean_squared_error: 2.2698
# Epoch 37/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.7711 - r2_score: 0.8239 - mae: 2.0736 - root_mean_squared_error: 2.7877 - val_loss: 4.9052 - val_r2_score: 0.7863 - val_mae: 1.5610 - val_root_mean_squared_error: 2.2148
# Epoch 38/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.7983 - r2_score: 0.8226 - mae: 2.0753 - root_mean_squared_error: 2.7925 - val_loss: 8.3819 - val_r2_score: 0.6262 - val_mae: 2.1413 - val_root_mean_squared_error: 2.8952
# Epoch 39/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.7091 - r2_score: 0.8247 - mae: 2.0617 - root_mean_squared_error: 2.7765 - val_loss: 9.9843 - val_r2_score: 0.5531 - val_mae: 2.4188 - val_root_mean_squared_error: 3.1598
# Epoch 40/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.6928 - r2_score: 0.8238 - mae: 2.0575 - root_mean_squared_error: 2.7736 - val_loss: 5.3755 - val_r2_score: 0.7640 - val_mae: 1.6255 - val_root_mean_squared_error: 2.3185
# Epoch 41/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.8180 - r2_score: 0.8236 - mae: 2.0782 - root_mean_squared_error: 2.7961 - val_loss: 7.7585 - val_r2_score: 0.6549 - val_mae: 2.0287 - val_root_mean_squared_error: 2.7854
# Epoch 42/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.6380 - r2_score: 0.8270 - mae: 2.0482 - root_mean_squared_error: 2.7637 - val_loss: 6.3421 - val_r2_score: 0.7193 - val_mae: 1.7785 - val_root_mean_squared_error: 2.5184
# Epoch 43/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.6352 - r2_score: 0.8266 - mae: 2.0507 - root_mean_squared_error: 2.7632 - val_loss: 12.6620 - val_r2_score: 0.4337 - val_mae: 2.8393 - val_root_mean_squared_error: 3.5584
# Epoch 44/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.7387 - r2_score: 0.8246 - mae: 2.0624 - root_mean_squared_error: 2.7818 - val_loss: 12.7044 - val_r2_score: 0.4313 - val_mae: 2.8525 - val_root_mean_squared_error: 3.5643
# Epoch 45/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.6866 - r2_score: 0.8261 - mae: 2.0555 - root_mean_squared_error: 2.7725 - val_loss: 5.2357 - val_r2_score: 0.7704 - val_mae: 1.5817 - val_root_mean_squared_error: 2.2882
# Epoch 46/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.6867 - r2_score: 0.8260 - mae: 2.0582 - root_mean_squared_error: 2.7725 - val_loss: 7.3863 - val_r2_score: 0.6716 - val_mae: 1.9614 - val_root_mean_squared_error: 2.7178
# Epoch 47/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.6753 - r2_score: 0.8261 - mae: 2.0558 - root_mean_squared_error: 2.7704 - val_loss: 6.2132 - val_r2_score: 0.7255 - val_mae: 1.7688 - val_root_mean_squared_error: 2.4926
# Epoch 48/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.6477 - r2_score: 0.8260 - mae: 2.0509 - root_mean_squared_error: 2.7654 - val_loss: 4.8949 - val_r2_score: 0.7908 - val_mae: 1.7279 - val_root_mean_squared_error: 2.2124
# Epoch 49/100
# 187/187 [==============================] - 2s 9ms/step - loss: 7.7966 - r2_score: 0.8237 - mae: 2.0765 - root_mean_squared_error: 2.7922 - val_loss: 11.0360 - val_r2_score: 0.5066 - val_mae: 2.5910 - val_root_mean_squared_error: 3.3220
# Epoch 50/100
# 187/187 [==============================] - 2s 9ms/step - loss: 7.6774 - r2_score: 0.8263 - mae: 2.0559 - root_mean_squared_error: 2.7708 - val_loss: 7.9565 - val_r2_score: 0.6458 - val_mae: 2.0670 - val_root_mean_squared_error: 2.8207
# Epoch 51/100
# 187/187 [==============================] - 2s 9ms/step - loss: 7.6408 - r2_score: 0.8267 - mae: 2.0494 - root_mean_squared_error: 2.7642 - val_loss: 5.2083 - val_r2_score: 0.7717 - val_mae: 1.5820 - val_root_mean_squared_error: 2.2822
# Epoch 52/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.7164 - r2_score: 0.8230 - mae: 2.0628 - root_mean_squared_error: 2.7778 - val_loss: 4.5125 - val_r2_score: 0.8052 - val_mae: 1.5277 - val_root_mean_squared_error: 2.1243
# Epoch 53/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.7679 - r2_score: 0.8245 - mae: 2.0723 - root_mean_squared_error: 2.7871 - val_loss: 7.2800 - val_r2_score: 0.6768 - val_mae: 1.9417 - val_root_mean_squared_error: 2.6982
# Epoch 54/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.5485 - r2_score: 0.8297 - mae: 2.0328 - root_mean_squared_error: 2.7475 - val_loss: 10.3291 - val_r2_score: 0.5390 - val_mae: 2.4829 - val_root_mean_squared_error: 3.2139
# Epoch 55/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.5784 - r2_score: 0.8272 - mae: 2.0375 - root_mean_squared_error: 2.7529 - val_loss: 4.5685 - val_r2_score: 0.8031 - val_mae: 1.5634 - val_root_mean_squared_error: 2.1374
# Epoch 56/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.7680 - r2_score: 0.8247 - mae: 2.0703 - root_mean_squared_error: 2.7871 - val_loss: 9.6927 - val_r2_score: 0.5676 - val_mae: 2.3696 - val_root_mean_squared_error: 3.1133
# Epoch 57/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.6562 - r2_score: 0.8238 - mae: 2.0498 - root_mean_squared_error: 2.7670 - val_loss: 4.6333 - val_r2_score: 0.8020 - val_mae: 1.6520 - val_root_mean_squared_error: 2.1525
# Epoch 58/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.7349 - r2_score: 0.8245 - mae: 2.0648 - root_mean_squared_error: 2.7812 - val_loss: 14.4931 - val_r2_score: 0.3508 - val_mae: 3.1448 - val_root_mean_squared_error: 3.8070
# Epoch 59/100
# 187/187 [==============================] - 1s 8ms/step - loss: 7.6740 - r2_score: 0.8263 - mae: 2.0532 - root_mean_squared_error: 2.7702 - val_loss: 8.0119 - val_r2_score: 0.6436 - val_mae: 2.0740 - val_root_mean_squared_error: 2.8305
# Epoch 60/100
# 187/187 [==============================] - 1s 8ms/step - loss: 7.5502 - r2_score: 0.8279 - mae: 2.0341 - root_mean_squared_error: 2.7478 - val_loss: 5.3688 - val_r2_score: 0.7654 - val_mae: 1.6590 - val_root_mean_squared_error: 2.3171
# Epoch 61/100
# 187/187 [==============================] - 1s 8ms/step - loss: 7.7254 - r2_score: 0.8253 - mae: 2.0630 - root_mean_squared_error: 2.7795 - val_loss: 9.5581 - val_r2_score: 0.5732 - val_mae: 2.3445 - val_root_mean_squared_error: 3.0916
# Epoch 62/100
# 187/187 [==============================] - 1s 8ms/step - loss: 7.5469 - r2_score: 0.8292 - mae: 2.0334 - root_mean_squared_error: 2.7472 - val_loss: 9.3530 - val_r2_score: 0.5828 - val_mae: 2.3113 - val_root_mean_squared_error: 3.0583
# Epoch 63/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.5666 - r2_score: 0.8288 - mae: 2.0371 - root_mean_squared_error: 2.7508 - val_loss: 7.3986 - val_r2_score: 0.6717 - val_mae: 1.9592 - val_root_mean_squared_error: 2.7200
# Epoch 64/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.5794 - r2_score: 0.8286 - mae: 2.0395 - root_mean_squared_error: 2.7531 - val_loss: 7.7408 - val_r2_score: 0.6558 - val_mae: 2.0210 - val_root_mean_squared_error: 2.7822
# Epoch 65/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.4764 - r2_score: 0.8313 - mae: 2.0234 - root_mean_squared_error: 2.7343 - val_loss: 8.8642 - val_r2_score: 0.6056 - val_mae: 2.2231 - val_root_mean_squared_error: 2.9773
# Epoch 66/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.5174 - r2_score: 0.8298 - mae: 2.0294 - root_mean_squared_error: 2.7418 - val_loss: 10.6886 - val_r2_score: 0.5227 - val_mae: 2.5198 - val_root_mean_squared_error: 3.2693
# Epoch 67/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.5660 - r2_score: 0.8288 - mae: 2.0374 - root_mean_squared_error: 2.7506 - val_loss: 7.7835 - val_r2_score: 0.6541 - val_mae: 2.0320 - val_root_mean_squared_error: 2.7899
# Epoch 68/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.5645 - r2_score: 0.8285 - mae: 2.0340 - root_mean_squared_error: 2.7504 - val_loss: 5.2588 - val_r2_score: 0.7698 - val_mae: 1.6066 - val_root_mean_squared_error: 2.2932
# Epoch 69/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.4849 - r2_score: 0.8305 - mae: 2.0238 - root_mean_squared_error: 2.7359 - val_loss: 9.8827 - val_r2_score: 0.5593 - val_mae: 2.3931 - val_root_mean_squared_error: 3.1437
# Epoch 70/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.5548 - r2_score: 0.8286 - mae: 2.0333 - root_mean_squared_error: 2.7486 - val_loss: 5.4504 - val_r2_score: 0.7606 - val_mae: 1.6122 - val_root_mean_squared_error: 2.3346
# Epoch 71/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.5885 - r2_score: 0.8272 - mae: 2.0429 - root_mean_squared_error: 2.7547 - val_loss: 7.9341 - val_r2_score: 0.6478 - val_mae: 2.0587 - val_root_mean_squared_error: 2.8168
# Epoch 72/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.5219 - r2_score: 0.8297 - mae: 2.0309 - root_mean_squared_error: 2.7426 - val_loss: 7.5177 - val_r2_score: 0.6665 - val_mae: 1.9828 - val_root_mean_squared_error: 2.7418
# Epoch 73/100
# 187/187 [==============================] - 2s 9ms/step - loss: 7.5084 - r2_score: 0.8301 - mae: 2.0250 - root_mean_squared_error: 2.7401 - val_loss: 10.5688 - val_r2_score: 0.5282 - val_mae: 2.5138 - val_root_mean_squared_error: 3.2510
# Epoch 74/100
# 187/187 [==============================] - 1s 8ms/step - loss: 7.5847 - r2_score: 0.8277 - mae: 2.0368 - root_mean_squared_error: 2.7540 - val_loss: 11.4225 - val_r2_score: 0.4907 - val_mae: 2.6694 - val_root_mean_squared_error: 3.3797
# Epoch 75/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.7151 - r2_score: 0.8253 - mae: 2.0598 - root_mean_squared_error: 2.7776 - val_loss: 10.6698 - val_r2_score: 0.5236 - val_mae: 2.5360 - val_root_mean_squared_error: 3.2665
# Epoch 76/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.5512 - r2_score: 0.8282 - mae: 2.0355 - root_mean_squared_error: 2.7479 - val_loss: 6.7422 - val_r2_score: 0.7013 - val_mae: 1.8482 - val_root_mean_squared_error: 2.5966
# Epoch 77/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.5908 - r2_score: 0.8285 - mae: 2.0444 - root_mean_squared_error: 2.7551 - val_loss: 5.6090 - val_r2_score: 0.7540 - val_mae: 1.6567 - val_root_mean_squared_error: 2.3683
# Epoch 78/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.5348 - r2_score: 0.8297 - mae: 2.0295 - root_mean_squared_error: 2.7450 - val_loss: 7.1850 - val_r2_score: 0.6820 - val_mae: 1.9182 - val_root_mean_squared_error: 2.6805
# Epoch 79/100
# 187/187 [==============================] - 2s 9ms/step - loss: 7.4457 - r2_score: 0.8318 - mae: 2.0161 - root_mean_squared_error: 2.7287 - val_loss: 8.4584 - val_r2_score: 0.6245 - val_mae: 2.1492 - val_root_mean_squared_error: 2.9083
# Epoch 80/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.4668 - r2_score: 0.8315 - mae: 2.0203 - root_mean_squared_error: 2.7325 - val_loss: 8.5780 - val_r2_score: 0.6191 - val_mae: 2.1783 - val_root_mean_squared_error: 2.9288
# Epoch 81/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.4716 - r2_score: 0.8308 - mae: 2.0204 - root_mean_squared_error: 2.7334 - val_loss: 4.8128 - val_r2_score: 0.7902 - val_mae: 1.5019 - val_root_mean_squared_error: 2.1938
# Epoch 82/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.4447 - r2_score: 0.8317 - mae: 2.0172 - root_mean_squared_error: 2.7285 - val_loss: 9.3279 - val_r2_score: 0.5857 - val_mae: 2.3179 - val_root_mean_squared_error: 3.0542
# Epoch 83/100
# 187/187 [==============================] - 2s 9ms/step - loss: 7.4867 - r2_score: 0.8306 - mae: 2.0198 - root_mean_squared_error: 2.7362 - val_loss: 6.5521 - val_r2_score: 0.7107 - val_mae: 1.8070 - val_root_mean_squared_error: 2.5597
# Epoch 84/100
# 187/187 [==============================] - 2s 9ms/step - loss: 7.4953 - r2_score: 0.8296 - mae: 2.0245 - root_mean_squared_error: 2.7378 - val_loss: 5.2406 - val_r2_score: 0.7712 - val_mae: 1.6145 - val_root_mean_squared_error: 2.2892
# Epoch 85/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.5077 - r2_score: 0.8292 - mae: 2.0271 - root_mean_squared_error: 2.7400 - val_loss: 4.6372 - val_r2_score: 0.8003 - val_mae: 1.5860 - val_root_mean_squared_error: 2.1534
# Epoch 86/100
# 187/187 [==============================] - 2s 9ms/step - loss: 7.6468 - r2_score: 0.8255 - mae: 2.0519 - root_mean_squared_error: 2.7653 - val_loss: 4.8946 - val_r2_score: 0.7909 - val_mae: 1.7486 - val_root_mean_squared_error: 2.2124
# Epoch 87/100
# 187/187 [==============================] - 1s 7ms/step - loss: 7.6265 - r2_score: 0.8276 - mae: 2.0487 - root_mean_squared_error: 2.7616 - val_loss: 19.2498 - val_r2_score: 0.1384 - val_mae: 3.7924 - val_root_mean_squared_error: 4.3875
# Epoch 88/100
# 187/187 [==============================] - 1s 7ms/step - loss: 7.4824 - r2_score: 0.8299 - mae: 2.0206 - root_mean_squared_error: 2.7354 - val_loss: 4.5516 - val_r2_score: 0.8024 - val_mae: 1.4743 - val_root_mean_squared_error: 2.1334
# Epoch 89/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.4483 - r2_score: 0.8313 - mae: 2.0159 - root_mean_squared_error: 2.7291 - val_loss: 6.6612 - val_r2_score: 0.7056 - val_mae: 1.8255 - val_root_mean_squared_error: 2.5809
# Epoch 90/100
# 187/187 [==============================] - 1s 8ms/step - loss: 7.4361 - r2_score: 0.8317 - mae: 2.0163 - root_mean_squared_error: 2.7269 - val_loss: 8.8314 - val_r2_score: 0.6077 - val_mae: 2.2170 - val_root_mean_squared_error: 2.9718
# Epoch 91/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.4450 - r2_score: 0.8305 - mae: 2.0170 - root_mean_squared_error: 2.7285 - val_loss: 4.7649 - val_r2_score: 0.7930 - val_mae: 1.5276 - val_root_mean_squared_error: 2.1829
# Epoch 92/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.4274 - r2_score: 0.8307 - mae: 2.0139 - root_mean_squared_error: 2.7253 - val_loss: 6.2243 - val_r2_score: 0.7262 - val_mae: 1.7733 - val_root_mean_squared_error: 2.4949
# Epoch 93/100
# 187/187 [==============================] - 1s 8ms/step - loss: 7.4453 - r2_score: 0.8306 - mae: 2.0164 - root_mean_squared_error: 2.7286 - val_loss: 4.6511 - val_r2_score: 0.7982 - val_mae: 1.5059 - val_root_mean_squared_error: 2.1566
# Epoch 94/100
# 187/187 [==============================] - 1s 8ms/step - loss: 7.3944 - r2_score: 0.8322 - mae: 2.0081 - root_mean_squared_error: 2.7193 - val_loss: 6.6544 - val_r2_score: 0.7061 - val_mae: 1.8251 - val_root_mean_squared_error: 2.5796
# Epoch 95/100
# 187/187 [==============================] - 1s 8ms/step - loss: 7.4442 - r2_score: 0.8309 - mae: 2.0149 - root_mean_squared_error: 2.7284 - val_loss: 6.3096 - val_r2_score: 0.7220 - val_mae: 1.7756 - val_root_mean_squared_error: 2.5119
# Epoch 96/100
# 187/187 [==============================] - 1s 8ms/step - loss: 7.4914 - r2_score: 0.8306 - mae: 2.0236 - root_mean_squared_error: 2.7370 - val_loss: 7.0791 - val_r2_score: 0.6869 - val_mae: 1.8998 - val_root_mean_squared_error: 2.6607
# Epoch 97/100
# 187/187 [==============================] - 1s 8ms/step - loss: 7.3901 - r2_score: 0.8323 - mae: 2.0073 - root_mean_squared_error: 2.7185 - val_loss: 4.8771 - val_r2_score: 0.7873 - val_mae: 1.5165 - val_root_mean_squared_error: 2.2084
# Epoch 98/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.4686 - r2_score: 0.8300 - mae: 2.0182 - root_mean_squared_error: 2.7329 - val_loss: 6.4458 - val_r2_score: 0.7154 - val_mae: 1.7825 - val_root_mean_squared_error: 2.5389
# Epoch 99/100
# 187/187 [==============================] - 2s 8ms/step - loss: 7.4122 - r2_score: 0.8317 - mae: 2.0104 - root_mean_squared_error: 2.7225 - val_loss: 6.6391 - val_r2_score: 0.7071 - val_mae: 1.8204 - val_root_mean_squared_error: 2.5767
# Epoch 100/100
# 187/187 [==============================] - 2s 9ms/step - loss: 7.3849 - r2_score: 0.8328 - mae: 2.0066 - root_mean_squared_error: 2.7175 - val_loss: 5.8234 - val_r2_score: 0.7440 - val_mae: 1.6708 - val_root_mean_squared_error: 2.4132

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('MSE - LSTM Model')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/mlp/loss.png')
plt.show()

# %%
plt.plot(history.history['r2_score'])
plt.plot(history.history['val_r2_score'])
plt.title('R2 Score - LSTM Model')
plt.ylabel('R2 Score')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/mlp/r2_score.png')
plt.show()

# %%
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('MAE - LSTM Model')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/mlp/mae.png')
plt.show()

# %%
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('RMSE - LSTM Model')
plt.ylabel('RMSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/mlp/rmse.png')
plt.show()

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='saved/mlp/model.png', show_shapes=True, show_layer_names=True)

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 140)               4340
# _________________________________________________________________
# dropout (Dropout)            (None, 140)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                4230
# =================================================================
# Total params: 8,570
# Trainable params: 8,570
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
hist_df = pd.DataFrame(history.history) 
hist_csv_file = 'saved/mlp/history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
prediction = model.predict(X_test, verbose=0)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(prediction, y_test)
r2 = r2_score(prediction[0], y_test[0])
print('Predicted MSE : %s'%mse)
print('Predicted R2 Score : %s'%r2)
# Out:
# Predicted MSE : 1.7184208737579947
# Predicted R2 Score : 0.012624266341547341

# %%
y_test[0]
# Out:
# array([14.75274718, 14.52532563, 14.43978398, 14.73415866, 14.93712005,
#        16.31742387, 15.99903992, 15.45547817, 15.7767913 , 16.99510365,
#        17.62197755, 17.53821249, 18.05517037, 17.95538347, 18.22478739,
#        19.54693849, 19.18823898, 20.35027236, 19.03428519, 19.34392341,
#        19.34553527, 18.50742023, 18.4990102 , 17.58222371, 18.34088583,
#        16.5565262 , 16.17991096, 15.69968205, 15.58516797, 15.29423038])

# %%
prediction[0]
# Out:
# array([16.63174 , 16.510376, 16.342327, 16.390469, 16.668411, 16.54498 ,
#        16.644941, 17.002518, 17.571953, 17.92025 , 18.291245, 18.690113,
#        19.578753, 19.327919, 19.632826, 20.072882, 19.904613, 19.867952,
#        20.284008, 19.656694, 19.8989  , 19.608877, 19.210508, 18.743608,
#        18.710962, 18.179247, 17.589357, 17.576382, 17.208906, 16.981262],
#       dtype=float32)

# %%
x = np.arange(30)
y_test_invert = []

# Inverse Box-Cox Transform
for i in range(len(y_test[0])):
    y_test_invert.append(invert_boxcox(y_test[0][i], ts_lamb))
plt.bar(x, y_test_invert)
# Out:
# <BarContainer object of 30 artists>

# %%
x = np.arange(30)
y_prediction_invert = []

# Inverse Box-Cox Transform
for i in range(len(y_test[0])):
    y_prediction_invert.append(invert_boxcox(prediction[0][i], ts_lamb))
plt.bar(x, y_prediction_invert)
# Out:
# <BarContainer object of 30 artists>

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_prediction_invert, y_test_invert)
r2 = r2_score(y_prediction_invert, y_test_invert)
print('Predicted MSE : %s'%mse)
print('Predicted R2 Score : %s'%r2)
# Out:
# Predicted MSE : 145.27367823243782
# Predicted R2 Score : 0.1330746821059242

# %%
y_prediction_invert
# Out:
# [84.87023162701124,
#  83.77629476165738,
#  82.27318055891922,
#  82.70240334761895,
#  85.20215222434287,
#  84.08747773645162,
#  84.98964282846063,
#  88.25586379153556,
#  93.5833042598293,
#  96.91814117095133,
#  100.53396482062703,
#  104.49469571588409,
#  113.59157001931007,
#  110.98569398574115,
#  114.15725923103403,
#  118.81271369971145,
#  117.02167060309263,
#  116.63323969679779,
#  121.07901529691021,
#  114.40740387598423,
#  116.96108329330659,
#  113.90654787871426,
#  109.77623339850507,
#  105.03167096680087,
#  104.70381344304174,
#  99.43548346616399,
#  93.74857323160431,
#  93.62534583865033,
#  90.16887729777613,
#  88.06000201596258]

# %%
y_test_invert
# Out:
# [68.7229498558514,
#  66.88314403489694,
#  66.19753176817476,
#  68.57164266251183,
#  70.2326649574087,
#  82.05158118122326,
#  79.24458484836387,
#  74.56431045526703,
#  77.31386907748917,
#  88.18752142535003,
#  94.05871505735975,
#  93.2633270464537,
#  98.22551788565214,
#  97.25774811541993,
#  99.8814262747274,
#  113.25939803090051,
#  109.54757547020331,
#  121.7946965426342,
#  107.97327128356129,
#  111.15106604868612,
#  111.16772796285335,
#  102.67115334375592,
#  102.58759224070153,
#  93.68081636735795,
#  101.02276466165708,
#  84.19144718319225,
#  80.83327099203122,
#  76.64952386758928,
#  75.66815798045012,
#  73.20307621397502]

# %%
plt.plot(y_test_invert)
plt.plot(y_prediction_invert)
plt.title('MLP - 30 Day Forecast')
plt.ylabel('Rainfall')
plt.xlabel('Days')
plt.legend(['Actual', 'Predicted'], loc='upper left')
plt.savefig('saved/mlp/test.png')
plt.show()
