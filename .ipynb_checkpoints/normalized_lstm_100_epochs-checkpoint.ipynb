# %%
# univariate multi-step vector-output 1d cnn example
from numpy import array
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
import pandas as pd

from math import log
from math import exp
from scipy.stats import boxcox

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps_in, n_steps_out):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps_in
		out_end_ix = end_ix + n_steps_out
		# check if we are beyond the sequence
		if out_end_ix > len(sequence):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# %%
# invert a boxcox transform for one value
def invert_boxcox(value, lam):
	# log case
	if lam == 0:
		return exp(value)
	# all other cases
	return exp(log(lam * value + 1) / lam)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

data = pd.read_csv("Timeseries_real_data_interview.csv")
t = data.iloc[0:11964] #11565
v = data.iloc[11964:19940]
ts = data.iloc[19940:20001]
# define input sequence
train_seq = t['Value'].values
val_seq = v['Value'].values
test_seq = ts['Value'].values

train_seq, tr_lamb = boxcox(train_seq)
val_seq, vl_lamb = boxcox(val_seq)
test_seq, ts_lamb = boxcox(test_seq)

train_seq = train_seq.reshape((len(train_seq), 1))
val_seq = val_seq.reshape((len(val_seq), 1))
test_seq = test_seq.reshape((len(test_seq), 1))

scaler1 = scaler.fit(train_seq)
train_seq = scaler1.transform(train_seq)

scaler2 = scaler.fit(val_seq)
val_seq = scaler2.transform(val_seq)

scaler3 = scaler.fit(test_seq)
test_seq = scaler3.transform(test_seq)

"""
tr, tr_lamb = boxcox(train_seq)
vl, vl_lamb = boxcox(val_seq)
ts, ts_lamb = boxcox(test_seq)
"""

print('Training Sequence : %d'%len(train_seq))
print('Validation Sequence : %d'%len(val_seq))
print('Testing Sequence : %d'%len(test_seq))

s1 = []
s2 = []
s3 = []

for i in range(len(train_seq)):
    s1.append(train_seq[i][0])
    
for i in range(len(val_seq)):
    s2.append(val_seq[i][0])
    
for i in range(len(test_seq)):
    s3.append(test_seq[i][0])
    
tr = s1
vl = s2
ts = s3
# Out:
# Training Sequence : 11964
# Validation Sequence : 7976
# Testing Sequence : 60

# %%
# choose a number of time steps
n_steps_in, n_steps_out = 30, 30
# split into samples
X_train, y_train = split_sequence(tr, n_steps_in, n_steps_out)
X_val, y_val = split_sequence(vl, n_steps_in, n_steps_out)
X_test, y_test = split_sequence(ts, n_steps_in, n_steps_out)
# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1

# %%
# define model
import keras.backend as kb

def r2_score(y_true, y_pred):
    ss_res = kb.sum(kb.square(y_true - y_pred))
    ss_tot = kb.sum(kb.square(y_true - kb.mean(y_true)))
    return (1 - ss_res/(ss_tot + kb.epsilon()))

model = Sequential()
model.add(Dense(140, activation='elu', input_dim=n_steps_in))
model.add(Dropout(0.2))
model.add(Dense(n_steps_out))


adam = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=adam, loss='mse', metrics=[r2_score,'mae', keras.metrics.RootMeanSquaredError()])

# %%
# fit model
history = model.fit(X_train, y_train, epochs=100, verbose=1, validation_data=(X_val, y_val), batch_size=64)
# Out:
# Epoch 1/100
# 185/187 [============================>.] - ETA: 0s - loss: 0.0179 - r2_score: 0.0345 - mae: 0.0948 - root_mean_squared_error: 0.1338WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0156s). Check your callbacks.
# 187/187 [==============================] - 2s 11ms/step - loss: 0.0178 - r2_score: 0.0404 - mae: 0.0946 - root_mean_squared_error: 0.1336 - val_loss: 0.0039 - val_r2_score: 0.7441 - val_mae: 0.0448 - val_root_mean_squared_error: 0.0622
# Epoch 2/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0059 - r2_score: 0.6809 - mae: 0.0593 - root_mean_squared_error: 0.0770 - val_loss: 0.0033 - val_r2_score: 0.7862 - val_mae: 0.0428 - val_root_mean_squared_error: 0.0571
# Epoch 3/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0047 - r2_score: 0.7457 - mae: 0.0523 - root_mean_squared_error: 0.0687 - val_loss: 0.0030 - val_r2_score: 0.8030 - val_mae: 0.0393 - val_root_mean_squared_error: 0.0548
# Epoch 4/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0041 - r2_score: 0.7804 - mae: 0.0482 - root_mean_squared_error: 0.0639 - val_loss: 0.0028 - val_r2_score: 0.8143 - val_mae: 0.0376 - val_root_mean_squared_error: 0.0532
# Epoch 5/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0037 - r2_score: 0.7990 - mae: 0.0456 - root_mean_squared_error: 0.0609 - val_loss: 0.0028 - val_r2_score: 0.8171 - val_mae: 0.0381 - val_root_mean_squared_error: 0.0528
# Epoch 6/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0035 - r2_score: 0.8091 - mae: 0.0443 - root_mean_squared_error: 0.0595 - val_loss: 0.0028 - val_r2_score: 0.8133 - val_mae: 0.0399 - val_root_mean_squared_error: 0.0533
# Epoch 7/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0034 - r2_score: 0.8178 - mae: 0.0430 - root_mean_squared_error: 0.0581 - val_loss: 0.0033 - val_r2_score: 0.7783 - val_mae: 0.0404 - val_root_mean_squared_error: 0.0579
# Epoch 8/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0033 - r2_score: 0.8217 - mae: 0.0425 - root_mean_squared_error: 0.0575 - val_loss: 0.0028 - val_r2_score: 0.8176 - val_mae: 0.0367 - val_root_mean_squared_error: 0.0527
# Epoch 9/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0032 - r2_score: 0.8255 - mae: 0.0418 - root_mean_squared_error: 0.0568 - val_loss: 0.0028 - val_r2_score: 0.8131 - val_mae: 0.0392 - val_root_mean_squared_error: 0.0533
# Epoch 10/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0032 - r2_score: 0.8301 - mae: 0.0413 - root_mean_squared_error: 0.0562 - val_loss: 0.0027 - val_r2_score: 0.8260 - val_mae: 0.0363 - val_root_mean_squared_error: 0.0515
# Epoch 11/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0031 - r2_score: 0.8341 - mae: 0.0405 - root_mean_squared_error: 0.0553 - val_loss: 0.0027 - val_r2_score: 0.8199 - val_mae: 0.0384 - val_root_mean_squared_error: 0.0524
# Epoch 12/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0030 - r2_score: 0.8374 - mae: 0.0402 - root_mean_squared_error: 0.0549 - val_loss: 0.0028 - val_r2_score: 0.8192 - val_mae: 0.0369 - val_root_mean_squared_error: 0.0525
# Epoch 13/100
# 187/187 [==============================] - 2s 10ms/step - loss: 0.0030 - r2_score: 0.8385 - mae: 0.0399 - root_mean_squared_error: 0.0547 - val_loss: 0.0029 - val_r2_score: 0.8121 - val_mae: 0.0411 - val_root_mean_squared_error: 0.0535
# Epoch 14/100
# 187/187 [==============================] - 2s 13ms/step - loss: 0.0030 - r2_score: 0.8400 - mae: 0.0397 - root_mean_squared_error: 0.0545 - val_loss: 0.0026 - val_r2_score: 0.8275 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0513
# Epoch 15/100
# 187/187 [==============================] - 1s 5ms/step - loss: 0.0029 - r2_score: 0.8446 - mae: 0.0390 - root_mean_squared_error: 0.0537 - val_loss: 0.0034 - val_r2_score: 0.7715 - val_mae: 0.0391 - val_root_mean_squared_error: 0.0587
# Epoch 16/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0029 - r2_score: 0.8434 - mae: 0.0392 - root_mean_squared_error: 0.0539 - val_loss: 0.0027 - val_r2_score: 0.8259 - val_mae: 0.0368 - val_root_mean_squared_error: 0.0516
# Epoch 17/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0029 - r2_score: 0.8462 - mae: 0.0388 - root_mean_squared_error: 0.0534 - val_loss: 0.0029 - val_r2_score: 0.8067 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0542
# Epoch 18/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0029 - r2_score: 0.8458 - mae: 0.0388 - root_mean_squared_error: 0.0535 - val_loss: 0.0026 - val_r2_score: 0.8268 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0514
# Epoch 19/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0028 - r2_score: 0.8488 - mae: 0.0383 - root_mean_squared_error: 0.0529 - val_loss: 0.0029 - val_r2_score: 0.8058 - val_mae: 0.0365 - val_root_mean_squared_error: 0.0543
# Epoch 20/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0028 - r2_score: 0.8493 - mae: 0.0382 - root_mean_squared_error: 0.0529 - val_loss: 0.0033 - val_r2_score: 0.7818 - val_mae: 0.0387 - val_root_mean_squared_error: 0.0574
# Epoch 21/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0028 - r2_score: 0.8500 - mae: 0.0381 - root_mean_squared_error: 0.0527 - val_loss: 0.0027 - val_r2_score: 0.8195 - val_mae: 0.0367 - val_root_mean_squared_error: 0.0524
# Epoch 22/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0027 - r2_score: 0.8520 - mae: 0.0377 - root_mean_squared_error: 0.0524 - val_loss: 0.0029 - val_r2_score: 0.8082 - val_mae: 0.0408 - val_root_mean_squared_error: 0.0540
# Epoch 23/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0027 - r2_score: 0.8523 - mae: 0.0378 - root_mean_squared_error: 0.0524 - val_loss: 0.0026 - val_r2_score: 0.8285 - val_mae: 0.0362 - val_root_mean_squared_error: 0.0512
# Epoch 24/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0027 - r2_score: 0.8538 - mae: 0.0376 - root_mean_squared_error: 0.0522 - val_loss: 0.0026 - val_r2_score: 0.8280 - val_mae: 0.0366 - val_root_mean_squared_error: 0.0512
# Epoch 25/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0027 - r2_score: 0.8537 - mae: 0.0375 - root_mean_squared_error: 0.0521 - val_loss: 0.0029 - val_r2_score: 0.8079 - val_mae: 0.0359 - val_root_mean_squared_error: 0.0540
# Epoch 26/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8546 - mae: 0.0374 - root_mean_squared_error: 0.0520 - val_loss: 0.0027 - val_r2_score: 0.8248 - val_mae: 0.0367 - val_root_mean_squared_error: 0.0517
# Epoch 27/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0027 - r2_score: 0.8547 - mae: 0.0374 - root_mean_squared_error: 0.0519 - val_loss: 0.0027 - val_r2_score: 0.8257 - val_mae: 0.0362 - val_root_mean_squared_error: 0.0516
# Epoch 28/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8553 - mae: 0.0372 - root_mean_squared_error: 0.0518 - val_loss: 0.0029 - val_r2_score: 0.8105 - val_mae: 0.0358 - val_root_mean_squared_error: 0.0536
# Epoch 29/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8556 - mae: 0.0373 - root_mean_squared_error: 0.0518 - val_loss: 0.0029 - val_r2_score: 0.8080 - val_mae: 0.0358 - val_root_mean_squared_error: 0.0540
# Epoch 30/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0027 - r2_score: 0.8558 - mae: 0.0371 - root_mean_squared_error: 0.0517 - val_loss: 0.0030 - val_r2_score: 0.8007 - val_mae: 0.0373 - val_root_mean_squared_error: 0.0549
# Epoch 31/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8556 - mae: 0.0371 - root_mean_squared_error: 0.0517 - val_loss: 0.0028 - val_r2_score: 0.8167 - val_mae: 0.0359 - val_root_mean_squared_error: 0.0528
# Epoch 32/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8561 - mae: 0.0371 - root_mean_squared_error: 0.0516 - val_loss: 0.0027 - val_r2_score: 0.8252 - val_mae: 0.0377 - val_root_mean_squared_error: 0.0517
# Epoch 33/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8565 - mae: 0.0370 - root_mean_squared_error: 0.0516 - val_loss: 0.0027 - val_r2_score: 0.8222 - val_mae: 0.0377 - val_root_mean_squared_error: 0.0521
# Epoch 34/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0027 - r2_score: 0.8558 - mae: 0.0370 - root_mean_squared_error: 0.0516 - val_loss: 0.0030 - val_r2_score: 0.8016 - val_mae: 0.0432 - val_root_mean_squared_error: 0.0549
# Epoch 35/100
# 187/187 [==============================] - 2s 11ms/step - loss: 0.0027 - r2_score: 0.8553 - mae: 0.0373 - root_mean_squared_error: 0.0518 - val_loss: 0.0027 - val_r2_score: 0.8252 - val_mae: 0.0373 - val_root_mean_squared_error: 0.0516
# Epoch 36/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8571 - mae: 0.0369 - root_mean_squared_error: 0.0515 - val_loss: 0.0028 - val_r2_score: 0.8158 - val_mae: 0.0364 - val_root_mean_squared_error: 0.0529
# Epoch 37/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0027 - r2_score: 0.8567 - mae: 0.0370 - root_mean_squared_error: 0.0515 - val_loss: 0.0027 - val_r2_score: 0.8261 - val_mae: 0.0356 - val_root_mean_squared_error: 0.0515
# Epoch 38/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8574 - mae: 0.0368 - root_mean_squared_error: 0.0514 - val_loss: 0.0028 - val_r2_score: 0.8132 - val_mae: 0.0403 - val_root_mean_squared_error: 0.0533
# Epoch 39/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8573 - mae: 0.0369 - root_mean_squared_error: 0.0514 - val_loss: 0.0028 - val_r2_score: 0.8175 - val_mae: 0.0373 - val_root_mean_squared_error: 0.0527
# Epoch 40/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0026 - r2_score: 0.8578 - mae: 0.0368 - root_mean_squared_error: 0.0513 - val_loss: 0.0027 - val_r2_score: 0.8263 - val_mae: 0.0363 - val_root_mean_squared_error: 0.0515
# Epoch 41/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0026 - r2_score: 0.8589 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0026 - val_r2_score: 0.8275 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0513
# Epoch 42/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0026 - r2_score: 0.8573 - mae: 0.0367 - root_mean_squared_error: 0.0513 - val_loss: 0.0026 - val_r2_score: 0.8286 - val_mae: 0.0368 - val_root_mean_squared_error: 0.0512
# Epoch 43/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0026 - r2_score: 0.8585 - mae: 0.0368 - root_mean_squared_error: 0.0513 - val_loss: 0.0027 - val_r2_score: 0.8230 - val_mae: 0.0364 - val_root_mean_squared_error: 0.0519
# Epoch 44/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8585 - mae: 0.0368 - root_mean_squared_error: 0.0513 - val_loss: 0.0026 - val_r2_score: 0.8276 - val_mae: 0.0374 - val_root_mean_squared_error: 0.0513
# Epoch 45/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8578 - mae: 0.0368 - root_mean_squared_error: 0.0513 - val_loss: 0.0027 - val_r2_score: 0.8257 - val_mae: 0.0376 - val_root_mean_squared_error: 0.0516
# Epoch 46/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8583 - mae: 0.0368 - root_mean_squared_error: 0.0513 - val_loss: 0.0027 - val_r2_score: 0.8226 - val_mae: 0.0357 - val_root_mean_squared_error: 0.0520
# Epoch 47/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8582 - mae: 0.0367 - root_mean_squared_error: 0.0513 - val_loss: 0.0027 - val_r2_score: 0.8247 - val_mae: 0.0358 - val_root_mean_squared_error: 0.0517
# Epoch 48/100
# 187/187 [==============================] - 2s 10ms/step - loss: 0.0026 - r2_score: 0.8586 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0028 - val_r2_score: 0.8129 - val_mae: 0.0357 - val_root_mean_squared_error: 0.0533
# Epoch 49/100
# 187/187 [==============================] - 2s 10ms/step - loss: 0.0026 - r2_score: 0.8574 - mae: 0.0368 - root_mean_squared_error: 0.0514 - val_loss: 0.0026 - val_r2_score: 0.8269 - val_mae: 0.0367 - val_root_mean_squared_error: 0.0514
# Epoch 50/100
# 187/187 [==============================] - 2s 11ms/step - loss: 0.0026 - r2_score: 0.8589 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8260 - val_mae: 0.0359 - val_root_mean_squared_error: 0.0515
# Epoch 51/100
# 187/187 [==============================] - 2s 11ms/step - loss: 0.0026 - r2_score: 0.8588 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8206 - val_mae: 0.0392 - val_root_mean_squared_error: 0.0523
# Epoch 52/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8580 - mae: 0.0368 - root_mean_squared_error: 0.0514 - val_loss: 0.0027 - val_r2_score: 0.8257 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0515
# Epoch 53/100
# 187/187 [==============================] - 1s 5ms/step - loss: 0.0026 - r2_score: 0.8594 - mae: 0.0366 - root_mean_squared_error: 0.0511 - val_loss: 0.0027 - val_r2_score: 0.8235 - val_mae: 0.0368 - val_root_mean_squared_error: 0.0519
# Epoch 54/100
# 187/187 [==============================] - 1s 4ms/step - loss: 0.0026 - r2_score: 0.8581 - mae: 0.0368 - root_mean_squared_error: 0.0513 - val_loss: 0.0028 - val_r2_score: 0.8171 - val_mae: 0.0399 - val_root_mean_squared_error: 0.0528
# Epoch 55/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8580 - mae: 0.0368 - root_mean_squared_error: 0.0513 - val_loss: 0.0029 - val_r2_score: 0.8103 - val_mae: 0.0363 - val_root_mean_squared_error: 0.0537
# Epoch 56/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8576 - mae: 0.0368 - root_mean_squared_error: 0.0514 - val_loss: 0.0028 - val_r2_score: 0.8141 - val_mae: 0.0376 - val_root_mean_squared_error: 0.0531
# Epoch 57/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0026 - r2_score: 0.8577 - mae: 0.0368 - root_mean_squared_error: 0.0514 - val_loss: 0.0027 - val_r2_score: 0.8217 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0521
# Epoch 58/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8582 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8203 - val_mae: 0.0377 - val_root_mean_squared_error: 0.0523
# Epoch 59/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8581 - mae: 0.0368 - root_mean_squared_error: 0.0514 - val_loss: 0.0027 - val_r2_score: 0.8258 - val_mae: 0.0370 - val_root_mean_squared_error: 0.0516
# Epoch 60/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8588 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8234 - val_mae: 0.0358 - val_root_mean_squared_error: 0.0519
# Epoch 61/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8578 - mae: 0.0367 - root_mean_squared_error: 0.0513 - val_loss: 0.0028 - val_r2_score: 0.8171 - val_mae: 0.0383 - val_root_mean_squared_error: 0.0528
# Epoch 62/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8582 - mae: 0.0368 - root_mean_squared_error: 0.0513 - val_loss: 0.0028 - val_r2_score: 0.8161 - val_mae: 0.0354 - val_root_mean_squared_error: 0.0529
# Epoch 63/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8593 - mae: 0.0366 - root_mean_squared_error: 0.0512 - val_loss: 0.0028 - val_r2_score: 0.8188 - val_mae: 0.0359 - val_root_mean_squared_error: 0.0525
# Epoch 64/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8589 - mae: 0.0366 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8201 - val_mae: 0.0396 - val_root_mean_squared_error: 0.0524
# Epoch 65/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8588 - mae: 0.0366 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8214 - val_mae: 0.0386 - val_root_mean_squared_error: 0.0522
# Epoch 66/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8590 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8245 - val_mae: 0.0368 - val_root_mean_squared_error: 0.0517
# Epoch 67/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8590 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8243 - val_mae: 0.0378 - val_root_mean_squared_error: 0.0518
# Epoch 68/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8581 - mae: 0.0368 - root_mean_squared_error: 0.0513 - val_loss: 0.0027 - val_r2_score: 0.8213 - val_mae: 0.0393 - val_root_mean_squared_error: 0.0522
# Epoch 69/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8583 - mae: 0.0368 - root_mean_squared_error: 0.0513 - val_loss: 0.0027 - val_r2_score: 0.8262 - val_mae: 0.0368 - val_root_mean_squared_error: 0.0515
# Epoch 70/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8588 - mae: 0.0366 - root_mean_squared_error: 0.0511 - val_loss: 0.0026 - val_r2_score: 0.8273 - val_mae: 0.0362 - val_root_mean_squared_error: 0.0514
# Epoch 71/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8588 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0030 - val_r2_score: 0.8021 - val_mae: 0.0370 - val_root_mean_squared_error: 0.0547
# Epoch 72/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8583 - mae: 0.0368 - root_mean_squared_error: 0.0513 - val_loss: 0.0027 - val_r2_score: 0.8246 - val_mae: 0.0361 - val_root_mean_squared_error: 0.0517
# Epoch 73/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8584 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8211 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0522
# Epoch 74/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8585 - mae: 0.0366 - root_mean_squared_error: 0.0511 - val_loss: 0.0027 - val_r2_score: 0.8195 - val_mae: 0.0364 - val_root_mean_squared_error: 0.0524
# Epoch 75/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8579 - mae: 0.0368 - root_mean_squared_error: 0.0513 - val_loss: 0.0028 - val_r2_score: 0.8146 - val_mae: 0.0404 - val_root_mean_squared_error: 0.0531
# Epoch 76/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8574 - mae: 0.0369 - root_mean_squared_error: 0.0514 - val_loss: 0.0027 - val_r2_score: 0.8243 - val_mae: 0.0387 - val_root_mean_squared_error: 0.0518
# Epoch 77/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8592 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8251 - val_mae: 0.0366 - val_root_mean_squared_error: 0.0517
# Epoch 78/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8590 - mae: 0.0366 - root_mean_squared_error: 0.0511 - val_loss: 0.0027 - val_r2_score: 0.8246 - val_mae: 0.0363 - val_root_mean_squared_error: 0.0517
# Epoch 79/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0026 - r2_score: 0.8581 - mae: 0.0367 - root_mean_squared_error: 0.0513 - val_loss: 0.0027 - val_r2_score: 0.8229 - val_mae: 0.0369 - val_root_mean_squared_error: 0.0520
# Epoch 80/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8580 - mae: 0.0368 - root_mean_squared_error: 0.0513 - val_loss: 0.0027 - val_r2_score: 0.8258 - val_mae: 0.0367 - val_root_mean_squared_error: 0.0516
# Epoch 81/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8584 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8230 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0520
# Epoch 82/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8584 - mae: 0.0368 - root_mean_squared_error: 0.0513 - val_loss: 0.0027 - val_r2_score: 0.8254 - val_mae: 0.0374 - val_root_mean_squared_error: 0.0516
# Epoch 83/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8582 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8213 - val_mae: 0.0382 - val_root_mean_squared_error: 0.0522
# Epoch 84/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8580 - mae: 0.0368 - root_mean_squared_error: 0.0513 - val_loss: 0.0026 - val_r2_score: 0.8275 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0513
# Epoch 85/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8586 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8246 - val_mae: 0.0376 - val_root_mean_squared_error: 0.0517
# Epoch 86/100
# 187/187 [==============================] - 2s 12ms/step - loss: 0.0026 - r2_score: 0.8590 - mae: 0.0366 - root_mean_squared_error: 0.0511 - val_loss: 0.0028 - val_r2_score: 0.8159 - val_mae: 0.0367 - val_root_mean_squared_error: 0.0529
# Epoch 87/100
# 187/187 [==============================] - 1s 7ms/step - loss: 0.0026 - r2_score: 0.8580 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0026 - val_r2_score: 0.8269 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0514
# Epoch 88/100
# 187/187 [==============================] - 1s 7ms/step - loss: 0.0026 - r2_score: 0.8591 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8216 - val_mae: 0.0358 - val_root_mean_squared_error: 0.0521
# Epoch 89/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8588 - mae: 0.0366 - root_mean_squared_error: 0.0511 - val_loss: 0.0028 - val_r2_score: 0.8155 - val_mae: 0.0357 - val_root_mean_squared_error: 0.0530
# Epoch 90/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8589 - mae: 0.0367 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8213 - val_mae: 0.0382 - val_root_mean_squared_error: 0.0522
# Epoch 91/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0026 - r2_score: 0.8590 - mae: 0.0366 - root_mean_squared_error: 0.0511 - val_loss: 0.0027 - val_r2_score: 0.8248 - val_mae: 0.0378 - val_root_mean_squared_error: 0.0517
# Epoch 92/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8578 - mae: 0.0367 - root_mean_squared_error: 0.0513 - val_loss: 0.0027 - val_r2_score: 0.8247 - val_mae: 0.0356 - val_root_mean_squared_error: 0.0517
# Epoch 93/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0026 - r2_score: 0.8585 - mae: 0.0366 - root_mean_squared_error: 0.0511 - val_loss: 0.0027 - val_r2_score: 0.8258 - val_mae: 0.0382 - val_root_mean_squared_error: 0.0516
# Epoch 94/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8589 - mae: 0.0367 - root_mean_squared_error: 0.0511 - val_loss: 0.0030 - val_r2_score: 0.8006 - val_mae: 0.0369 - val_root_mean_squared_error: 0.0550
# Epoch 95/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8580 - mae: 0.0368 - root_mean_squared_error: 0.0514 - val_loss: 0.0026 - val_r2_score: 0.8276 - val_mae: 0.0362 - val_root_mean_squared_error: 0.0513
# Epoch 96/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0026 - r2_score: 0.8595 - mae: 0.0366 - root_mean_squared_error: 0.0511 - val_loss: 0.0027 - val_r2_score: 0.8211 - val_mae: 0.0359 - val_root_mean_squared_error: 0.0522
# Epoch 97/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0026 - r2_score: 0.8594 - mae: 0.0366 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8216 - val_mae: 0.0368 - val_root_mean_squared_error: 0.0521
# Epoch 98/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0026 - r2_score: 0.8593 - mae: 0.0366 - root_mean_squared_error: 0.0511 - val_loss: 0.0027 - val_r2_score: 0.8261 - val_mae: 0.0368 - val_root_mean_squared_error: 0.0515
# Epoch 99/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0026 - r2_score: 0.8590 - mae: 0.0366 - root_mean_squared_error: 0.0511 - val_loss: 0.0027 - val_r2_score: 0.8260 - val_mae: 0.0367 - val_root_mean_squared_error: 0.0515
# Epoch 100/100
# 187/187 [==============================] - 1s 7ms/step - loss: 0.0026 - r2_score: 0.8591 - mae: 0.0366 - root_mean_squared_error: 0.0512 - val_loss: 0.0027 - val_r2_score: 0.8263 - val_mae: 0.0374 - val_root_mean_squared_error: 0.0515

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('MSE - MLP Model')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/mlp/loss.png')
plt.show()

# %%
plt.plot(history.history['r2_score'])
plt.plot(history.history['val_r2_score'])
plt.title('R2 Score - MLP Model')
plt.ylabel('R2 Score')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/mlp/r2_score.png')
plt.show()

# %%
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('MAE - MLP Model')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/mlp/mae.png')
plt.show()

# %%
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('RMSE - MLP Model')
plt.ylabel('RMSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/mlp/rmse.png')
plt.show()

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='saved/mlp/model.png', show_shapes=True, show_layer_names=True)

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 140)               4340
# _________________________________________________________________
# dropout (Dropout)            (None, 140)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                4230
# =================================================================
# Total params: 8,570
# Trainable params: 8,570
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
hist_df = pd.DataFrame(history.history) 
hist_csv_file = 'saved/mlp/history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
prediction = model.predict(X_test, verbose=0)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(prediction, y_test)
r2 = r2_score(prediction[0], y_test[0])
print('Predicted MSE : %s'%mse)
print('Predicted R2 Score : %s'%r2)
# Out:
# Predicted MSE : 0.006994238771823278
# Predicted R2 Score : 0.8708934631083037

# %%
y_test[0]
# Out:
# array([0.08691596, 0.04981832, 0.03586452, 0.08388375, 0.11699138,
#        0.34215042, 0.29021473, 0.20154741, 0.25396091, 0.45269545,
#        0.55495288, 0.54128889, 0.62561651, 0.60933899, 0.65328492,
#        0.86895792, 0.81044585, 1.        , 0.78533247, 0.83584153,
#        0.83610446, 0.69938878, 0.69801691, 0.54846812, 0.67222322,
#        0.38115346, 0.31971893, 0.24138264, 0.22270278, 0.17524422])

# %%
prediction[0]
# Out:
# array([0.15620525, 0.1194392 , 0.11753814, 0.12179816, 0.1243484 ,
#        0.1748163 , 0.19724008, 0.25026226, 0.3130809 , 0.38402694,
#        0.48791635, 0.528953  , 0.5912696 , 0.63407683, 0.6893914 ,
#        0.7261659 , 0.7611041 , 0.77124286, 0.7715235 , 0.74125457,
#        0.7281704 , 0.67012167, 0.62198424, 0.583674  , 0.5219052 ,
#        0.4326476 , 0.37845016, 0.30482888, 0.244897  , 0.17900488],
#       dtype=float32)

# %%
y_test_invert = scaler.inverse_transform(y_test)
y_test_invert
y_test_invert_final = []
# Inverse Box-Cox Transform
for i in range(len(y_test_invert[0])):
    y_test_invert_final.append(invert_boxcox(y_test_invert[0][i], ts_lamb))
x = np.arange(30)
plt.bar(x, y_test_invert_final)
# Out:
# <BarContainer object of 30 artists>

# %%
y_pred_invert = scaler.inverse_transform(prediction)

y_pred_invert_final = []
# Inverse Box-Cox Transform
for i in range(len(y_pred_invert[0])):
    y_pred_invert_final.append(invert_boxcox(y_pred_invert[0][i], ts_lamb))
x = np.arange(30)
plt.bar(x, y_pred_invert_final)
# Out:
# <BarContainer object of 30 artists>

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_pred_invert_final, y_test_invert_final)
r2 = r2_score(y_pred_invert_final, y_test_invert_final)
print('Predicted MSE : %s'%mse)
print('Predicted R2 Score : %s'%r2)
# Out:
# Predicted MSE : 24.350141776340717
# Predicted R2 Score : 0.8581246562564367

# %%
y_pred_invert
# Out:
# array([[15.177515, 14.952126, 14.940473, 14.966587, 14.982222, 15.291608,
#         15.429073, 15.754118, 16.139217, 16.574142, 17.21102 , 17.46259 ,
#         17.844612, 18.107035, 18.446133, 18.671574, 18.885757, 18.94791 ,
#         18.94963 , 18.764072, 18.683863, 18.328003, 18.032904, 17.798048,
#         17.419384, 16.872202, 16.539955, 16.08863 , 15.721226, 15.317285]],
#       dtype=float32)

# %%
y_test_invert
# Out:
# array([[14.75274718, 14.52532563, 14.43978398, 14.73415866, 14.93712005,
#         16.31742387, 15.99903992, 15.45547817, 15.7767913 , 16.99510365,
#         17.62197755, 17.53821249, 18.05517037, 17.95538347, 18.22478739,
#         19.54693849, 19.18823898, 20.35027236, 19.03428519, 19.34392341,
#         19.34553527, 18.50742023, 18.4990102 , 17.58222371, 18.34088583,
#         16.5565262 , 16.17991096, 15.69968205, 15.58516797, 15.29423038]])

# %%
plt.plot(y_test_invert[0])
plt.plot(y_pred_invert[0])
plt.title('CNN - 30 Day Forecast')
plt.ylabel('Rainfall')
plt.xlabel('Days')
plt.legend(['Actual', 'Predicted'], loc='upper left')
plt.savefig('saved/mlp/test.png')
plt.show()
