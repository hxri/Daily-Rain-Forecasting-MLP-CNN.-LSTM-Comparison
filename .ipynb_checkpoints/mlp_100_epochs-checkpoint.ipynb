# %%
# univariate multi-step vector-output 1d cnn example
from numpy import array
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
import pandas as pd

from math import log
from math import exp
from scipy.stats import boxcox

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps_in, n_steps_out):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps_in
		out_end_ix = end_ix + n_steps_out
		# check if we are beyond the sequence
		if out_end_ix > len(sequence):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# %%
# invert a boxcox transform for one value
def invert_boxcox(value, lam):
	# log case
	if lam == 0:
		return exp(value)
	# all other cases
	return exp(log(lam * value + 1) / lam)

# %%
data = pd.read_csv("Timeseries_real_data_interview.csv")
t = data.iloc[0:11964] #11565
v = data.iloc[11964:19940]
ts = data.iloc[19940:20001]
# define input sequence
train_seq = t['Value'].values
val_seq = v['Value'].values
test_seq = ts['Value'].values

tr, tr_lamb = boxcox(train_seq)
vl, vl_lamb = boxcox(val_seq)
ts, ts_lamb = boxcox(test_seq)

print('Training Sequence : %d'%len(train_seq))
print('Validation Sequence : %d'%len(val_seq))
print('Testing Sequence : %d'%len(test_seq))
# Out:
# Training Sequence : 11964
# Validation Sequence : 7976
# Testing Sequence : 60

# %%
# choose a number of time steps
n_steps_in, n_steps_out = 30, 30
# split into samples
X_train, y_train = split_sequence(tr, n_steps_in, n_steps_out)
X_val, y_val = split_sequence(vl, n_steps_in, n_steps_out)
X_test, y_test = split_sequence(ts, n_steps_in, n_steps_out)
# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], n_features))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))

# %%
# define model
import keras.backend as kb

def r2_score(y_true, y_pred):
    ss_res = kb.sum(kb.square(y_true - y_pred))
    ss_tot = kb.sum(kb.square(y_true - kb.mean(y_true)))
    return (1 - ss_res/(ss_tot + kb.epsilon()))

model = Sequential()
model.add(LSTM(90, activation='relu', return_sequences=True, input_shape=(n_steps_in, n_features)))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(n_steps_out))

adam = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=adam, loss='mse', metrics=[r2_score,'mae', keras.metrics.RootMeanSquaredError()])

# %%
# fit model
history = model.fit(X_train, y_train, epochs=100, verbose=1, validation_data=(X_val, y_val), batch_size=64)
# Out:
# Epoch 1/100
# 187/187 [==============================] - 12s 67ms/step - loss: 19.7149 - r2_score: 0.5541 - mae: 2.7736 - root_mean_squared_error: 4.4401 - val_loss: 5.6654 - val_r2_score: 0.7508 - val_mae: 1.6855 - val_root_mean_squared_error: 2.3802
# Epoch 2/100
# 187/187 [==============================] - 10s 53ms/step - loss: 6.5680 - r2_score: 0.8510 - mae: 1.8501 - root_mean_squared_error: 2.5628 - val_loss: 5.4399 - val_r2_score: 0.7619 - val_mae: 1.6479 - val_root_mean_squared_error: 2.3324
# Epoch 3/100
# 187/187 [==============================] - 7s 39ms/step - loss: 6.2986 - r2_score: 0.8573 - mae: 1.8049 - root_mean_squared_error: 2.5097 - val_loss: 5.8758 - val_r2_score: 0.7416 - val_mae: 1.7014 - val_root_mean_squared_error: 2.4240
# Epoch 4/100
# 187/187 [==============================] - 7s 40ms/step - loss: 6.1304 - r2_score: 0.8613 - mae: 1.7748 - root_mean_squared_error: 2.4760 - val_loss: 4.9387 - val_r2_score: 0.7848 - val_mae: 1.5471 - val_root_mean_squared_error: 2.2223
# Epoch 5/100
# 187/187 [==============================] - 7s 39ms/step - loss: 6.0320 - r2_score: 0.8634 - mae: 1.7580 - root_mean_squared_error: 2.4560 - val_loss: 4.6652 - val_r2_score: 0.7972 - val_mae: 1.4873 - val_root_mean_squared_error: 2.1599
# Epoch 6/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.9966 - r2_score: 0.8643 - mae: 1.7509 - root_mean_squared_error: 2.4488 - val_loss: 5.2139 - val_r2_score: 0.7724 - val_mae: 1.5823 - val_root_mean_squared_error: 2.2834
# Epoch 7/100
# 187/187 [==============================] - 7s 40ms/step - loss: 5.9520 - r2_score: 0.8652 - mae: 1.7432 - root_mean_squared_error: 2.4397 - val_loss: 4.9750 - val_r2_score: 0.7829 - val_mae: 1.5496 - val_root_mean_squared_error: 2.2305
# Epoch 8/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.8853 - r2_score: 0.8671 - mae: 1.7314 - root_mean_squared_error: 2.4260 - val_loss: 4.5484 - val_r2_score: 0.8025 - val_mae: 1.5084 - val_root_mean_squared_error: 2.1327
# Epoch 9/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.8708 - r2_score: 0.8671 - mae: 1.7287 - root_mean_squared_error: 2.4230 - val_loss: 5.8453 - val_r2_score: 0.7440 - val_mae: 1.6734 - val_root_mean_squared_error: 2.4177
# Epoch 10/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.8716 - r2_score: 0.8668 - mae: 1.7277 - root_mean_squared_error: 2.4231 - val_loss: 4.2774 - val_r2_score: 0.8153 - val_mae: 1.4820 - val_root_mean_squared_error: 2.0682
# Epoch 11/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.8258 - r2_score: 0.8684 - mae: 1.7228 - root_mean_squared_error: 2.4137 - val_loss: 4.6214 - val_r2_score: 0.7993 - val_mae: 1.4849 - val_root_mean_squared_error: 2.1497
# Epoch 12/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.7994 - r2_score: 0.8688 - mae: 1.7175 - root_mean_squared_error: 2.4082 - val_loss: 4.7350 - val_r2_score: 0.7941 - val_mae: 1.4906 - val_root_mean_squared_error: 2.1760
# Epoch 13/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.7827 - r2_score: 0.8685 - mae: 1.7124 - root_mean_squared_error: 2.4047 - val_loss: 4.3165 - val_r2_score: 0.8136 - val_mae: 1.5174 - val_root_mean_squared_error: 2.0776
# Epoch 14/100
# 187/187 [==============================] - 7s 40ms/step - loss: 5.7996 - r2_score: 0.8689 - mae: 1.7171 - root_mean_squared_error: 2.4082 - val_loss: 5.3412 - val_r2_score: 0.7668 - val_mae: 1.5898 - val_root_mean_squared_error: 2.3111
# Epoch 15/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.7680 - r2_score: 0.8695 - mae: 1.7103 - root_mean_squared_error: 2.4017 - val_loss: 4.5457 - val_r2_score: 0.8029 - val_mae: 1.4847 - val_root_mean_squared_error: 2.1321
# Epoch 16/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.7510 - r2_score: 0.8698 - mae: 1.7094 - root_mean_squared_error: 2.3981 - val_loss: 5.0778 - val_r2_score: 0.7784 - val_mae: 1.5385 - val_root_mean_squared_error: 2.2534
# Epoch 17/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.7488 - r2_score: 0.8697 - mae: 1.7077 - root_mean_squared_error: 2.3977 - val_loss: 4.2546 - val_r2_score: 0.8167 - val_mae: 1.5342 - val_root_mean_squared_error: 2.0627
# Epoch 18/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.7294 - r2_score: 0.8706 - mae: 1.7057 - root_mean_squared_error: 2.3936 - val_loss: 4.5898 - val_r2_score: 0.8007 - val_mae: 1.4908 - val_root_mean_squared_error: 2.1424
# Epoch 19/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.7175 - r2_score: 0.8709 - mae: 1.7016 - root_mean_squared_error: 2.3911 - val_loss: 4.4715 - val_r2_score: 0.8061 - val_mae: 1.4385 - val_root_mean_squared_error: 2.1146
# Epoch 20/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.7110 - r2_score: 0.8704 - mae: 1.7016 - root_mean_squared_error: 2.3898 - val_loss: 4.5933 - val_r2_score: 0.8011 - val_mae: 1.4749 - val_root_mean_squared_error: 2.1432
# Epoch 21/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.7327 - r2_score: 0.8697 - mae: 1.7054 - root_mean_squared_error: 2.3943 - val_loss: 5.7009 - val_r2_score: 0.7500 - val_mae: 1.6429 - val_root_mean_squared_error: 2.3877
# Epoch 22/100
# 187/187 [==============================] - 7s 40ms/step - loss: 5.7340 - r2_score: 0.8701 - mae: 1.7046 - root_mean_squared_error: 2.3946 - val_loss: 4.3497 - val_r2_score: 0.8115 - val_mae: 1.4458 - val_root_mean_squared_error: 2.0856
# Epoch 23/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.6898 - r2_score: 0.8711 - mae: 1.6990 - root_mean_squared_error: 2.3853 - val_loss: 4.4280 - val_r2_score: 0.8085 - val_mae: 1.5177 - val_root_mean_squared_error: 2.1043
# Epoch 24/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.6828 - r2_score: 0.8718 - mae: 1.6972 - root_mean_squared_error: 2.3839 - val_loss: 4.3444 - val_r2_score: 0.8119 - val_mae: 1.4313 - val_root_mean_squared_error: 2.0843
# Epoch 25/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.6698 - r2_score: 0.8715 - mae: 1.6941 - root_mean_squared_error: 2.3811 - val_loss: 4.4778 - val_r2_score: 0.8059 - val_mae: 1.5129 - val_root_mean_squared_error: 2.1161
# Epoch 26/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.6865 - r2_score: 0.8691 - mae: 1.6980 - root_mean_squared_error: 2.3846 - val_loss: 4.4775 - val_r2_score: 0.8068 - val_mae: 1.5780 - val_root_mean_squared_error: 2.1160
# Epoch 27/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.7993 - r2_score: 0.8676 - mae: 1.7186 - root_mean_squared_error: 2.4082 - val_loss: 4.9903 - val_r2_score: 0.7826 - val_mae: 1.5563 - val_root_mean_squared_error: 2.2339
# Epoch 28/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.6854 - r2_score: 0.8704 - mae: 1.6979 - root_mean_squared_error: 2.3844 - val_loss: 4.4742 - val_r2_score: 0.8072 - val_mae: 1.6119 - val_root_mean_squared_error: 2.1152
# Epoch 29/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.7071 - r2_score: 0.8710 - mae: 1.7028 - root_mean_squared_error: 2.3889 - val_loss: 4.9177 - val_r2_score: 0.7856 - val_mae: 1.5141 - val_root_mean_squared_error: 2.2176
# Epoch 30/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.6677 - r2_score: 0.8716 - mae: 1.6938 - root_mean_squared_error: 2.3807 - val_loss: 4.4022 - val_r2_score: 0.8094 - val_mae: 1.4940 - val_root_mean_squared_error: 2.0981
# Epoch 31/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.6495 - r2_score: 0.8723 - mae: 1.6916 - root_mean_squared_error: 2.3769 - val_loss: 4.5632 - val_r2_score: 0.8017 - val_mae: 1.4840 - val_root_mean_squared_error: 2.1362
# Epoch 32/100
# 187/187 [==============================] - 7s 40ms/step - loss: 5.6517 - r2_score: 0.8714 - mae: 1.6919 - root_mean_squared_error: 2.3773 - val_loss: 4.3239 - val_r2_score: 0.8131 - val_mae: 1.5063 - val_root_mean_squared_error: 2.0794
# Epoch 33/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.6577 - r2_score: 0.8723 - mae: 1.6946 - root_mean_squared_error: 2.3786 - val_loss: 4.5359 - val_r2_score: 0.8031 - val_mae: 1.5079 - val_root_mean_squared_error: 2.1298
# Epoch 34/100
# 187/187 [==============================] - 7s 40ms/step - loss: 5.6366 - r2_score: 0.8721 - mae: 1.6891 - root_mean_squared_error: 2.3742 - val_loss: 4.3377 - val_r2_score: 0.8127 - val_mae: 1.5396 - val_root_mean_squared_error: 2.0827
# Epoch 35/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.6376 - r2_score: 0.8726 - mae: 1.6903 - root_mean_squared_error: 2.3744 - val_loss: 4.5391 - val_r2_score: 0.8033 - val_mae: 1.5911 - val_root_mean_squared_error: 2.1305
# Epoch 36/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.6389 - r2_score: 0.8726 - mae: 1.6907 - root_mean_squared_error: 2.3746 - val_loss: 4.6883 - val_r2_score: 0.7963 - val_mae: 1.4917 - val_root_mean_squared_error: 2.1652
# Epoch 37/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.6168 - r2_score: 0.8730 - mae: 1.6862 - root_mean_squared_error: 2.3700 - val_loss: 6.3633 - val_r2_score: 0.7201 - val_mae: 1.7395 - val_root_mean_squared_error: 2.5226
# Epoch 38/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.6207 - r2_score: 0.8728 - mae: 1.6853 - root_mean_squared_error: 2.3708 - val_loss: 4.6418 - val_r2_score: 0.7984 - val_mae: 1.4483 - val_root_mean_squared_error: 2.1545
# Epoch 39/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.6110 - r2_score: 0.8727 - mae: 1.6861 - root_mean_squared_error: 2.3688 - val_loss: 4.6386 - val_r2_score: 0.7985 - val_mae: 1.5287 - val_root_mean_squared_error: 2.1537
# Epoch 40/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.6168 - r2_score: 0.8727 - mae: 1.6874 - root_mean_squared_error: 2.3700 - val_loss: 4.4544 - val_r2_score: 0.8070 - val_mae: 1.4641 - val_root_mean_squared_error: 2.1105
# Epoch 41/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.6003 - r2_score: 0.8726 - mae: 1.6844 - root_mean_squared_error: 2.3665 - val_loss: 4.8872 - val_r2_score: 0.7876 - val_mae: 1.5014 - val_root_mean_squared_error: 2.2107
# Epoch 42/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.6190 - r2_score: 0.8732 - mae: 1.6870 - root_mean_squared_error: 2.3704 - val_loss: 5.2465 - val_r2_score: 0.7701 - val_mae: 1.5683 - val_root_mean_squared_error: 2.2905
# Epoch 43/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.5810 - r2_score: 0.8730 - mae: 1.6806 - root_mean_squared_error: 2.3624 - val_loss: 7.8410 - val_r2_score: 0.6540 - val_mae: 2.0271 - val_root_mean_squared_error: 2.8002
# Epoch 44/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.6431 - r2_score: 0.8717 - mae: 1.6905 - root_mean_squared_error: 2.3755 - val_loss: 4.2999 - val_r2_score: 0.8142 - val_mae: 1.4609 - val_root_mean_squared_error: 2.0736
# Epoch 45/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.6050 - r2_score: 0.8732 - mae: 1.6856 - root_mean_squared_error: 2.3675 - val_loss: 4.6669 - val_r2_score: 0.7973 - val_mae: 1.4751 - val_root_mean_squared_error: 2.1603
# Epoch 46/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.5763 - r2_score: 0.8733 - mae: 1.6795 - root_mean_squared_error: 2.3614 - val_loss: 4.2467 - val_r2_score: 0.8168 - val_mae: 1.5189 - val_root_mean_squared_error: 2.0608
# Epoch 47/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.6123 - r2_score: 0.8732 - mae: 1.6882 - root_mean_squared_error: 2.3690 - val_loss: 5.3707 - val_r2_score: 0.7651 - val_mae: 1.5802 - val_root_mean_squared_error: 2.3175
# Epoch 48/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.5761 - r2_score: 0.8741 - mae: 1.6792 - root_mean_squared_error: 2.3614 - val_loss: 6.1888 - val_r2_score: 0.7282 - val_mae: 1.7143 - val_root_mean_squared_error: 2.4877
# Epoch 49/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.5755 - r2_score: 0.8736 - mae: 1.6790 - root_mean_squared_error: 2.3612 - val_loss: 4.3401 - val_r2_score: 0.8125 - val_mae: 1.5300 - val_root_mean_squared_error: 2.0833
# Epoch 50/100
# 187/187 [==============================] - 8s 40ms/step - loss: 5.5958 - r2_score: 0.8733 - mae: 1.6864 - root_mean_squared_error: 2.3655 - val_loss: 5.0488 - val_r2_score: 0.7795 - val_mae: 1.5386 - val_root_mean_squared_error: 2.2470
# Epoch 51/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.5442 - r2_score: 0.8741 - mae: 1.6747 - root_mean_squared_error: 2.3546 - val_loss: 4.6004 - val_r2_score: 0.8003 - val_mae: 1.4880 - val_root_mean_squared_error: 2.1449
# Epoch 52/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.5655 - r2_score: 0.8742 - mae: 1.6801 - root_mean_squared_error: 2.3591 - val_loss: 4.6673 - val_r2_score: 0.7969 - val_mae: 1.4971 - val_root_mean_squared_error: 2.1604
# Epoch 53/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.5447 - r2_score: 0.8744 - mae: 1.6769 - root_mean_squared_error: 2.3547 - val_loss: 4.3327 - val_r2_score: 0.8124 - val_mae: 1.4694 - val_root_mean_squared_error: 2.0815
# Epoch 54/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.5407 - r2_score: 0.8745 - mae: 1.6761 - root_mean_squared_error: 2.3539 - val_loss: 4.6688 - val_r2_score: 0.7987 - val_mae: 1.7269 - val_root_mean_squared_error: 2.1607
# Epoch 55/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.5436 - r2_score: 0.8742 - mae: 1.6792 - root_mean_squared_error: 2.3545 - val_loss: 4.2115 - val_r2_score: 0.8189 - val_mae: 1.4939 - val_root_mean_squared_error: 2.0522
# Epoch 56/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.5667 - r2_score: 0.8737 - mae: 1.6811 - root_mean_squared_error: 2.3594 - val_loss: 4.8232 - val_r2_score: 0.7898 - val_mae: 1.5509 - val_root_mean_squared_error: 2.1962
# Epoch 57/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.5129 - r2_score: 0.8748 - mae: 1.6720 - root_mean_squared_error: 2.3479 - val_loss: 4.3480 - val_r2_score: 0.8118 - val_mae: 1.4902 - val_root_mean_squared_error: 2.0852
# Epoch 58/100
# 187/187 [==============================] - 8s 42ms/step - loss: 5.5221 - r2_score: 0.8741 - mae: 1.6731 - root_mean_squared_error: 2.3499 - val_loss: 4.5790 - val_r2_score: 0.8017 - val_mae: 1.5853 - val_root_mean_squared_error: 2.1399
# Epoch 59/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.5439 - r2_score: 0.8744 - mae: 1.6774 - root_mean_squared_error: 2.3545 - val_loss: 4.1971 - val_r2_score: 0.8190 - val_mae: 1.4687 - val_root_mean_squared_error: 2.0487
# Epoch 60/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.5134 - r2_score: 0.8755 - mae: 1.6730 - root_mean_squared_error: 2.3481 - val_loss: 5.5350 - val_r2_score: 0.7574 - val_mae: 1.6060 - val_root_mean_squared_error: 2.3527
# Epoch 61/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.4898 - r2_score: 0.8758 - mae: 1.6675 - root_mean_squared_error: 2.3430 - val_loss: 5.3469 - val_r2_score: 0.7661 - val_mae: 1.5742 - val_root_mean_squared_error: 2.3123
# Epoch 62/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.4991 - r2_score: 0.8754 - mae: 1.6692 - root_mean_squared_error: 2.3450 - val_loss: 4.4445 - val_r2_score: 0.8073 - val_mae: 1.4860 - val_root_mean_squared_error: 2.1082
# Epoch 63/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.4913 - r2_score: 0.8759 - mae: 1.6687 - root_mean_squared_error: 2.3433 - val_loss: 4.4209 - val_r2_score: 0.8083 - val_mae: 1.4854 - val_root_mean_squared_error: 2.1026
# Epoch 64/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.4778 - r2_score: 0.8753 - mae: 1.6663 - root_mean_squared_error: 2.3405 - val_loss: 5.7161 - val_r2_score: 0.7522 - val_mae: 1.9836 - val_root_mean_squared_error: 2.3908
# Epoch 65/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.5522 - r2_score: 0.8742 - mae: 1.6812 - root_mean_squared_error: 2.3563 - val_loss: 4.8803 - val_r2_score: 0.7872 - val_mae: 1.5097 - val_root_mean_squared_error: 2.2091
# Epoch 66/100
# 187/187 [==============================] - 8s 43ms/step - loss: 5.4741 - r2_score: 0.8760 - mae: 1.6646 - root_mean_squared_error: 2.3397 - val_loss: 4.5710 - val_r2_score: 0.8015 - val_mae: 1.4930 - val_root_mean_squared_error: 2.1380
# Epoch 67/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.4600 - r2_score: 0.8766 - mae: 1.6640 - root_mean_squared_error: 2.3367 - val_loss: 4.3534 - val_r2_score: 0.8120 - val_mae: 1.4542 - val_root_mean_squared_error: 2.0865
# Epoch 68/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.4549 - r2_score: 0.8761 - mae: 1.6627 - root_mean_squared_error: 2.3356 - val_loss: 4.4353 - val_r2_score: 0.8080 - val_mae: 1.5406 - val_root_mean_squared_error: 2.1060
# Epoch 69/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.4580 - r2_score: 0.8766 - mae: 1.6644 - root_mean_squared_error: 2.3362 - val_loss: 4.4657 - val_r2_score: 0.8064 - val_mae: 1.4685 - val_root_mean_squared_error: 2.1132
# Epoch 70/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.4451 - r2_score: 0.8767 - mae: 1.6629 - root_mean_squared_error: 2.3335 - val_loss: 6.2875 - val_r2_score: 0.7237 - val_mae: 1.7303 - val_root_mean_squared_error: 2.5075
# Epoch 71/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.4324 - r2_score: 0.8764 - mae: 1.6597 - root_mean_squared_error: 2.3308 - val_loss: 4.7280 - val_r2_score: 0.7943 - val_mae: 1.5129 - val_root_mean_squared_error: 2.1744
# Epoch 72/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.4440 - r2_score: 0.8766 - mae: 1.6627 - root_mean_squared_error: 2.3332 - val_loss: 4.3066 - val_r2_score: 0.8139 - val_mae: 1.5073 - val_root_mean_squared_error: 2.0752
# Epoch 73/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.4284 - r2_score: 0.8772 - mae: 1.6596 - root_mean_squared_error: 2.3299 - val_loss: 4.3191 - val_r2_score: 0.8135 - val_mae: 1.5247 - val_root_mean_squared_error: 2.0782
# Epoch 74/100
# 187/187 [==============================] - 8s 42ms/step - loss: 5.4201 - r2_score: 0.8768 - mae: 1.6591 - root_mean_squared_error: 2.3281 - val_loss: 5.2185 - val_r2_score: 0.7722 - val_mae: 1.5496 - val_root_mean_squared_error: 2.2844
# Epoch 75/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.4233 - r2_score: 0.8768 - mae: 1.6589 - root_mean_squared_error: 2.3288 - val_loss: 4.1582 - val_r2_score: 0.8210 - val_mae: 1.5024 - val_root_mean_squared_error: 2.0392
# Epoch 76/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.4165 - r2_score: 0.8776 - mae: 1.6590 - root_mean_squared_error: 2.3273 - val_loss: 4.4202 - val_r2_score: 0.8083 - val_mae: 1.4696 - val_root_mean_squared_error: 2.1024
# Epoch 77/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.3910 - r2_score: 0.8771 - mae: 1.6546 - root_mean_squared_error: 2.3219 - val_loss: 4.4039 - val_r2_score: 0.8092 - val_mae: 1.4539 - val_root_mean_squared_error: 2.0985
# Epoch 78/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.3954 - r2_score: 0.8779 - mae: 1.6550 - root_mean_squared_error: 2.3228 - val_loss: 4.5131 - val_r2_score: 0.8043 - val_mae: 1.4680 - val_root_mean_squared_error: 2.1244
# Epoch 79/100
# 187/187 [==============================] - 8s 42ms/step - loss: 5.3868 - r2_score: 0.8769 - mae: 1.6536 - root_mean_squared_error: 2.3210 - val_loss: 4.5481 - val_r2_score: 0.8031 - val_mae: 1.5477 - val_root_mean_squared_error: 2.1326
# Epoch 80/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.3763 - r2_score: 0.8785 - mae: 1.6528 - root_mean_squared_error: 2.3187 - val_loss: 5.2509 - val_r2_score: 0.7705 - val_mae: 1.5656 - val_root_mean_squared_error: 2.2915
# Epoch 81/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.4043 - r2_score: 0.8778 - mae: 1.6554 - root_mean_squared_error: 2.3247 - val_loss: 4.5083 - val_r2_score: 0.8046 - val_mae: 1.5422 - val_root_mean_squared_error: 2.1233
# Epoch 82/100
# 187/187 [==============================] - 8s 42ms/step - loss: 5.3661 - r2_score: 0.8775 - mae: 1.6527 - root_mean_squared_error: 2.3165 - val_loss: 4.5803 - val_r2_score: 0.8017 - val_mae: 1.5733 - val_root_mean_squared_error: 2.1402
# Epoch 83/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.3640 - r2_score: 0.8786 - mae: 1.6514 - root_mean_squared_error: 2.3160 - val_loss: 5.3288 - val_r2_score: 0.7670 - val_mae: 1.5892 - val_root_mean_squared_error: 2.3084
# Epoch 84/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.3435 - r2_score: 0.8789 - mae: 1.6469 - root_mean_squared_error: 2.3116 - val_loss: 4.3766 - val_r2_score: 0.8110 - val_mae: 1.5191 - val_root_mean_squared_error: 2.0920
# Epoch 85/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.3377 - r2_score: 0.8781 - mae: 1.6475 - root_mean_squared_error: 2.3103 - val_loss: 4.7024 - val_r2_score: 0.7967 - val_mae: 1.6345 - val_root_mean_squared_error: 2.1685
# Epoch 86/100
# 187/187 [==============================] - 8s 42ms/step - loss: 5.3517 - r2_score: 0.8786 - mae: 1.6510 - root_mean_squared_error: 2.3134 - val_loss: 5.2713 - val_r2_score: 0.7699 - val_mae: 1.6031 - val_root_mean_squared_error: 2.2959
# Epoch 87/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.3366 - r2_score: 0.8787 - mae: 1.6462 - root_mean_squared_error: 2.3101 - val_loss: 6.1589 - val_r2_score: 0.7296 - val_mae: 1.7212 - val_root_mean_squared_error: 2.4817
# Epoch 88/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.3452 - r2_score: 0.8786 - mae: 1.6486 - root_mean_squared_error: 2.3120 - val_loss: 4.4358 - val_r2_score: 0.8081 - val_mae: 1.5096 - val_root_mean_squared_error: 2.1061
# Epoch 89/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.3461 - r2_score: 0.8786 - mae: 1.6504 - root_mean_squared_error: 2.3122 - val_loss: 4.5667 - val_r2_score: 0.8023 - val_mae: 1.5853 - val_root_mean_squared_error: 2.1370
# Epoch 90/100
# 187/187 [==============================] - 8s 42ms/step - loss: 5.2978 - r2_score: 0.8800 - mae: 1.6417 - root_mean_squared_error: 2.3017 - val_loss: 4.2439 - val_r2_score: 0.8168 - val_mae: 1.4716 - val_root_mean_squared_error: 2.0601
# Epoch 91/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.2813 - r2_score: 0.8804 - mae: 1.6387 - root_mean_squared_error: 2.2981 - val_loss: 4.3638 - val_r2_score: 0.8119 - val_mae: 1.4954 - val_root_mean_squared_error: 2.0890
# Epoch 92/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.3054 - r2_score: 0.8799 - mae: 1.6426 - root_mean_squared_error: 2.3034 - val_loss: 4.4364 - val_r2_score: 0.8084 - val_mae: 1.5358 - val_root_mean_squared_error: 2.1063
# Epoch 93/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.2724 - r2_score: 0.8807 - mae: 1.6380 - root_mean_squared_error: 2.2962 - val_loss: 4.7316 - val_r2_score: 0.7942 - val_mae: 1.5045 - val_root_mean_squared_error: 2.1752
# Epoch 94/100
# 187/187 [==============================] - 8s 42ms/step - loss: 5.2892 - r2_score: 0.8803 - mae: 1.6403 - root_mean_squared_error: 2.2998 - val_loss: 4.6768 - val_r2_score: 0.7967 - val_mae: 1.4850 - val_root_mean_squared_error: 2.1626
# Epoch 95/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.2606 - r2_score: 0.8805 - mae: 1.6356 - root_mean_squared_error: 2.2936 - val_loss: 4.7603 - val_r2_score: 0.7939 - val_mae: 1.6197 - val_root_mean_squared_error: 2.1818
# Epoch 96/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.3116 - r2_score: 0.8800 - mae: 1.6426 - root_mean_squared_error: 2.3047 - val_loss: 4.6710 - val_r2_score: 0.7972 - val_mae: 1.5437 - val_root_mean_squared_error: 2.1613
# Epoch 97/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.2336 - r2_score: 0.8815 - mae: 1.6311 - root_mean_squared_error: 2.2877 - val_loss: 4.4989 - val_r2_score: 0.8048 - val_mae: 1.4580 - val_root_mean_squared_error: 2.1211
# Epoch 98/100
# 187/187 [==============================] - 8s 42ms/step - loss: 5.2546 - r2_score: 0.8810 - mae: 1.6352 - root_mean_squared_error: 2.2923 - val_loss: 5.1721 - val_r2_score: 0.7741 - val_mae: 1.5568 - val_root_mean_squared_error: 2.2742
# Epoch 99/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.2394 - r2_score: 0.8815 - mae: 1.6321 - root_mean_squared_error: 2.2890 - val_loss: 4.9373 - val_r2_score: 0.7847 - val_mae: 1.5409 - val_root_mean_squared_error: 2.2220
# Epoch 100/100
# 187/187 [==============================] - 8s 41ms/step - loss: 5.2089 - r2_score: 0.8822 - mae: 1.6280 - root_mean_squared_error: 2.2823 - val_loss: 4.3569 - val_r2_score: 0.8119 - val_mae: 1.4986 - val_root_mean_squared_error: 2.0873

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('MSE - LSTM Model')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/simple_lstm/loss.png')
plt.show()

# %%
plt.plot(history.history['r2_score'])
plt.plot(history.history['val_r2_score'])
plt.title('R2 Score - LSTM Model')
plt.ylabel('R2 Score')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/simple_lstm/r2_score.png')
plt.show()

# %%
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('MAE - LSTM Model')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/simple_lstm/mae.png')
plt.show()

# %%
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('RMSE - LSTM Model')
plt.ylabel('RMSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/simple_lstm/rmse.png')
plt.show()

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='saved/simple_lstm/model.png', show_shapes=True, show_layer_names=True)

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 90)            33120
# _________________________________________________________________
# flatten (Flatten)            (None, 2700)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2700)              0
# _________________________________________________________________
# dense (Dense)                (None, 30)                81030
# =================================================================
# Total params: 114,150
# Trainable params: 114,150
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
hist_df = pd.DataFrame(history.history) 
hist_csv_file = 'saved/simple_lstm/history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
prediction = model.predict(X_test, verbose=0)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(prediction, y_test)
r2 = r2_score(prediction[0], y_test[0])
print('Predicted MSE : %s'%mse)
print('Predicted R2 Score : %s'%r2)
# Out:
# Predicted MSE : 0.9839808220693219
# Predicted R2 Score : 0.799331331168912

# %%
y_test[0]
# Out:
# array([14.75274718, 14.52532563, 14.43978398, 14.73415866, 14.93712005,
#        16.31742387, 15.99903992, 15.45547817, 15.7767913 , 16.99510365,
#        17.62197755, 17.53821249, 18.05517037, 17.95538347, 18.22478739,
#        19.54693849, 19.18823898, 20.35027236, 19.03428519, 19.34392341,
#        19.34553527, 18.50742023, 18.4990102 , 17.58222371, 18.34088583,
#        16.5565262 , 16.17991096, 15.69968205, 15.58516797, 15.29423038])

# %%
prediction[0]
# Out:
# array([15.16968  , 14.434849 , 14.6182995, 14.195645 , 14.21919  ,
#        14.357777 , 14.218783 , 14.587569 , 15.081846 , 15.955434 ,
#        16.478636 , 16.939056 , 17.808836 , 18.201633 , 18.964172 ,
#        19.613995 , 20.080214 , 20.677883 , 20.028452 , 20.066198 ,
#        20.252897 , 20.338196 , 19.558073 , 18.995914 , 18.594318 ,
#        18.095121 , 17.772404 , 16.794363 , 16.364847 , 15.888196 ],
#       dtype=float32)

# %%
x = np.arange(30)
y_test_invert = []

# Inverse Box-Cox Transform
for i in range(len(y_test[0])):
    y_test_invert.append(invert_boxcox(y_test[0][i], ts_lamb))
plt.bar(x, y_test_invert)
# Out:
# <BarContainer object of 30 artists>

# %%
x = np.arange(30)
y_prediction_invert = []

# Inverse Box-Cox Transform
for i in range(len(y_test[0])):
    y_prediction_invert.append(invert_boxcox(prediction[0][i], ts_lamb))
plt.bar(x, y_prediction_invert)
# Out:
# <BarContainer object of 30 artists>

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_prediction_invert, y_test_invert)
r2 = r2_score(y_prediction_invert, y_test_invert)
print('Predicted MSE : %s'%mse)
print('Predicted R2 Score : %s'%r2)
# Out:
# Predicted MSE : 85.43652046352844
# Predicted R2 Score : 0.8009340548350645

# %%
y_prediction_invert
# Out:
# [72.16014655234451,
#  66.15808325174649,
#  67.63229714476869,
#  64.26003736241177,
#  64.44564270037183,
#  65.54353545348722,
#  64.44243776550563,
#  67.38422503837253,
#  71.42913222127667,
#  78.8639088590833,
#  83.49136088614641,
#  87.67173009146904,
#  95.8450896379519,
#  99.6545740342946,
#  107.26005454187643,
#  113.96009759764456,
#  118.89106038653117,
#  125.3637485241675,
#  118.33849356904308,
#  118.7413190500305,
#  120.74372806720484,
#  121.66410901157073,
#  113.37559962543887,
#  107.58265796628595,
#  103.53653947234534,
#  98.61430918880527,
#  95.49548790173284,
#  86.34708244153882,
#  82.47382850757613,
#  78.27871131820272]

# %%
y_test_invert
# Out:
# [68.7229498558514,
#  66.88314403489694,
#  66.19753176817476,
#  68.57164266251183,
#  70.2326649574087,
#  82.05158118122326,
#  79.24458484836387,
#  74.56431045526703,
#  77.31386907748917,
#  88.18752142535003,
#  94.05871505735975,
#  93.2633270464537,
#  98.22551788565214,
#  97.25774811541993,
#  99.8814262747274,
#  113.25939803090051,
#  109.54757547020331,
#  121.7946965426342,
#  107.97327128356129,
#  111.15106604868612,
#  111.16772796285335,
#  102.67115334375592,
#  102.58759224070153,
#  93.68081636735795,
#  101.02276466165708,
#  84.19144718319225,
#  80.83327099203122,
#  76.64952386758928,
#  75.66815798045012,
#  73.20307621397502]
