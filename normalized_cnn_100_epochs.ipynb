# %%
# univariate multi-step vector-output 1d cnn example
from numpy import array
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
import pandas as pd

from math import log
from math import exp
from scipy.stats import boxcox

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps_in, n_steps_out):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps_in
		out_end_ix = end_ix + n_steps_out
		# check if we are beyond the sequence
		if out_end_ix > len(sequence):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# %%
# invert a boxcox transform for one value
def invert_boxcox(value, lam):
	# log case
	if lam == 0:
		return exp(value)
	# all other cases
	return exp(log(lam * value + 1) / lam)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

data = pd.read_csv("Timeseries_real_data_interview.csv")
t = data.iloc[0:11964] #11565
v = data.iloc[11964:19940]
ts = data.iloc[19940:20001]
# define input sequence
train_seq = t['Value'].values
val_seq = v['Value'].values
test_seq = ts['Value'].values

train_seq, tr_lamb = boxcox(train_seq)
val_seq, vl_lamb = boxcox(val_seq)
test_seq, ts_lamb = boxcox(test_seq)

train_seq = train_seq.reshape((len(train_seq), 1))
val_seq = val_seq.reshape((len(val_seq), 1))
test_seq = test_seq.reshape((len(test_seq), 1))

scaler1 = scaler.fit(train_seq)
train_seq = scaler1.transform(train_seq)

scaler2 = scaler.fit(val_seq)
val_seq = scaler2.transform(val_seq)

scaler3 = scaler.fit(test_seq)
test_seq = scaler3.transform(test_seq)

"""
tr, tr_lamb = boxcox(train_seq)
vl, vl_lamb = boxcox(val_seq)
ts, ts_lamb = boxcox(test_seq)
"""

print('Training Sequence : %d'%len(train_seq))
print('Validation Sequence : %d'%len(val_seq))
print('Testing Sequence : %d'%len(test_seq))

s1 = []
s2 = []
s3 = []

for i in range(len(train_seq)):
    s1.append(train_seq[i][0])
    
for i in range(len(val_seq)):
    s2.append(val_seq[i][0])
    
for i in range(len(test_seq)):
    s3.append(test_seq[i][0])
    
tr = s1
vl = s2
ts = s3
# Out:
# Training Sequence : 11964
# Validation Sequence : 7976
# Testing Sequence : 60

# %%
# choose a number of time steps
n_steps_in, n_steps_out = 30, 30
# split into samples
X_train, y_train = split_sequence(tr, n_steps_in, n_steps_out)
X_val, y_val = split_sequence(vl, n_steps_in, n_steps_out)
X_test, y_test = split_sequence(ts, n_steps_in, n_steps_out)
# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], n_features))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))

# %%
# define model
import keras.backend as kb

def r2_score(y_true, y_pred):
    ss_res = kb.sum(kb.square(y_true - y_pred))
    ss_tot = kb.sum(kb.square(y_true - kb.mean(y_true)))
    return (1 - ss_res/(ss_tot + kb.epsilon()))

model = Sequential()
model.add(Conv1D(filters=126, kernel_size=2, activation='tanh', input_shape=(n_steps_in, n_features), kernel_regularizer=keras.regularizers.l2(l=0.01), kernel_initializer='he_normal'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(n_steps_out))

adam = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=adam, loss='mse', metrics=[r2_score, 'mae', keras.metrics.RootMeanSquaredError()])

# %%
# fit model
history = model.fit(X_train, y_train, epochs=100, verbose=1, validation_data=(X_val, y_val), batch_size=64)
# Out:
# Epoch 1/100
# 187/187 [==============================] - 4s 23ms/step - loss: 2.1752 - r2_score: -3.7108 - mae: 0.2271 - root_mean_squared_error: 0.2957 - val_loss: 1.7882 - val_r2_score: -0.0267 - val_mae: 0.0922 - val_root_mean_squared_error: 0.1227
# Epoch 2/100
# 187/187 [==============================] - 4s 20ms/step - loss: 1.5544 - r2_score: -0.8073 - mae: 0.1429 - root_mean_squared_error: 0.1833 - val_loss: 1.2929 - val_r2_score: 0.6909 - val_mae: 0.0508 - val_root_mean_squared_error: 0.0681
# Epoch 3/100
# 187/187 [==============================] - 2s 12ms/step - loss: 1.1170 - r2_score: 0.2088 - mae: 0.0939 - root_mean_squared_error: 0.1211 - val_loss: 0.9342 - val_r2_score: 0.7683 - val_mae: 0.0426 - val_root_mean_squared_error: 0.0592
# Epoch 4/100
# 187/187 [==============================] - 2s 10ms/step - loss: 0.8008 - r2_score: 0.5955 - mae: 0.0666 - root_mean_squared_error: 0.0867 - val_loss: 0.6695 - val_r2_score: 0.8175 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0527
# Epoch 5/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.5705 - r2_score: 0.7389 - mae: 0.0528 - root_mean_squared_error: 0.0696 - val_loss: 0.4754 - val_r2_score: 0.8254 - val_mae: 0.0375 - val_root_mean_squared_error: 0.0516
# Epoch 6/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.4028 - r2_score: 0.7923 - mae: 0.0465 - root_mean_squared_error: 0.0621 - val_loss: 0.3339 - val_r2_score: 0.8264 - val_mae: 0.0370 - val_root_mean_squared_error: 0.0515
# Epoch 7/100
# 187/187 [==============================] - 2s 11ms/step - loss: 0.2813 - r2_score: 0.8119 - mae: 0.0437 - root_mean_squared_error: 0.0590 - val_loss: 0.2315 - val_r2_score: 0.8290 - val_mae: 0.0359 - val_root_mean_squared_error: 0.0511
# Epoch 8/100
# 187/187 [==============================] - 2s 11ms/step - loss: 0.1939 - r2_score: 0.8216 - mae: 0.0424 - root_mean_squared_error: 0.0575 - val_loss: 0.1583 - val_r2_score: 0.8281 - val_mae: 0.0364 - val_root_mean_squared_error: 0.0512
# Epoch 9/100
# 187/187 [==============================] - 2s 10ms/step - loss: 0.1318 - r2_score: 0.8269 - mae: 0.0415 - root_mean_squared_error: 0.0566 - val_loss: 0.1066 - val_r2_score: 0.8278 - val_mae: 0.0375 - val_root_mean_squared_error: 0.0513
# Epoch 10/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0882 - r2_score: 0.8327 - mae: 0.0407 - root_mean_squared_error: 0.0557 - val_loss: 0.0707 - val_r2_score: 0.8267 - val_mae: 0.0378 - val_root_mean_squared_error: 0.0515
# Epoch 11/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0582 - r2_score: 0.8371 - mae: 0.0400 - root_mean_squared_error: 0.0549 - val_loss: 0.0463 - val_r2_score: 0.8248 - val_mae: 0.0361 - val_root_mean_squared_error: 0.0517
# Epoch 12/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0380 - r2_score: 0.8417 - mae: 0.0393 - root_mean_squared_error: 0.0541 - val_loss: 0.0304 - val_r2_score: 0.8001 - val_mae: 0.0369 - val_root_mean_squared_error: 0.0550
# Epoch 13/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0247 - r2_score: 0.8436 - mae: 0.0389 - root_mean_squared_error: 0.0537 - val_loss: 0.0197 - val_r2_score: 0.8144 - val_mae: 0.0366 - val_root_mean_squared_error: 0.0531
# Epoch 14/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0162 - r2_score: 0.8481 - mae: 0.0384 - root_mean_squared_error: 0.0531 - val_loss: 0.0133 - val_r2_score: 0.8042 - val_mae: 0.0369 - val_root_mean_squared_error: 0.0545
# Epoch 15/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0110 - r2_score: 0.8492 - mae: 0.0381 - root_mean_squared_error: 0.0528 - val_loss: 0.0091 - val_r2_score: 0.8180 - val_mae: 0.0367 - val_root_mean_squared_error: 0.0527
# Epoch 16/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0078 - r2_score: 0.8526 - mae: 0.0376 - root_mean_squared_error: 0.0523 - val_loss: 0.0067 - val_r2_score: 0.8230 - val_mae: 0.0379 - val_root_mean_squared_error: 0.0520
# Epoch 17/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0059 - r2_score: 0.8555 - mae: 0.0372 - root_mean_squared_error: 0.0518 - val_loss: 0.0052 - val_r2_score: 0.8241 - val_mae: 0.0367 - val_root_mean_squared_error: 0.0518
# Epoch 18/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0047 - r2_score: 0.8556 - mae: 0.0370 - root_mean_squared_error: 0.0516 - val_loss: 0.0045 - val_r2_score: 0.8157 - val_mae: 0.0410 - val_root_mean_squared_error: 0.0531
# Epoch 19/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0041 - r2_score: 0.8564 - mae: 0.0371 - root_mean_squared_error: 0.0516 - val_loss: 0.0043 - val_r2_score: 0.7919 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0561
# Epoch 20/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0036 - r2_score: 0.8580 - mae: 0.0367 - root_mean_squared_error: 0.0513 - val_loss: 0.0035 - val_r2_score: 0.8289 - val_mae: 0.0362 - val_root_mean_squared_error: 0.0511
# Epoch 21/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0034 - r2_score: 0.8596 - mae: 0.0366 - root_mean_squared_error: 0.0511 - val_loss: 0.0033 - val_r2_score: 0.8286 - val_mae: 0.0362 - val_root_mean_squared_error: 0.0512
# Epoch 22/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0032 - r2_score: 0.8580 - mae: 0.0366 - root_mean_squared_error: 0.0511 - val_loss: 0.0032 - val_r2_score: 0.8271 - val_mae: 0.0383 - val_root_mean_squared_error: 0.0514
# Epoch 23/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0031 - r2_score: 0.8600 - mae: 0.0366 - root_mean_squared_error: 0.0510 - val_loss: 0.0032 - val_r2_score: 0.8212 - val_mae: 0.0403 - val_root_mean_squared_error: 0.0523
# Epoch 24/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0031 - r2_score: 0.8580 - mae: 0.0366 - root_mean_squared_error: 0.0512 - val_loss: 0.0034 - val_r2_score: 0.8035 - val_mae: 0.0441 - val_root_mean_squared_error: 0.0548
# Epoch 25/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0030 - r2_score: 0.8587 - mae: 0.0366 - root_mean_squared_error: 0.0511 - val_loss: 0.0030 - val_r2_score: 0.8288 - val_mae: 0.0352 - val_root_mean_squared_error: 0.0511
# Epoch 26/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0030 - r2_score: 0.8588 - mae: 0.0366 - root_mean_squared_error: 0.0511 - val_loss: 0.0030 - val_r2_score: 0.8265 - val_mae: 0.0388 - val_root_mean_squared_error: 0.0515
# Epoch 27/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0029 - r2_score: 0.8595 - mae: 0.0366 - root_mean_squared_error: 0.0510 - val_loss: 0.0030 - val_r2_score: 0.8197 - val_mae: 0.0351 - val_root_mean_squared_error: 0.0524
# Epoch 28/100
# 187/187 [==============================] - 1s 7ms/step - loss: 0.0029 - r2_score: 0.8603 - mae: 0.0364 - root_mean_squared_error: 0.0510 - val_loss: 0.0029 - val_r2_score: 0.8290 - val_mae: 0.0380 - val_root_mean_squared_error: 0.0511
# Epoch 29/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0029 - r2_score: 0.8598 - mae: 0.0364 - root_mean_squared_error: 0.0509 - val_loss: 0.0030 - val_r2_score: 0.8228 - val_mae: 0.0399 - val_root_mean_squared_error: 0.0520
# Epoch 30/100
# 187/187 [==============================] - 1s 7ms/step - loss: 0.0029 - r2_score: 0.8598 - mae: 0.0365 - root_mean_squared_error: 0.0509 - val_loss: 0.0031 - val_r2_score: 0.8111 - val_mae: 0.0426 - val_root_mean_squared_error: 0.0536
# Epoch 31/100
# 187/187 [==============================] - 2s 12ms/step - loss: 0.0028 - r2_score: 0.8604 - mae: 0.0364 - root_mean_squared_error: 0.0509 - val_loss: 0.0028 - val_r2_score: 0.8310 - val_mae: 0.0362 - val_root_mean_squared_error: 0.0508
# Epoch 32/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0028 - r2_score: 0.8611 - mae: 0.0364 - root_mean_squared_error: 0.0508 - val_loss: 0.0029 - val_r2_score: 0.8220 - val_mae: 0.0347 - val_root_mean_squared_error: 0.0521
# Epoch 33/100
# 187/187 [==============================] - 1s 7ms/step - loss: 0.0028 - r2_score: 0.8618 - mae: 0.0362 - root_mean_squared_error: 0.0507 - val_loss: 0.0031 - val_r2_score: 0.8088 - val_mae: 0.0356 - val_root_mean_squared_error: 0.0539
# Epoch 34/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0028 - r2_score: 0.8601 - mae: 0.0363 - root_mean_squared_error: 0.0508 - val_loss: 0.0030 - val_r2_score: 0.8192 - val_mae: 0.0347 - val_root_mean_squared_error: 0.0525
# Epoch 35/100
# 187/187 [==============================] - 1s 7ms/step - loss: 0.0028 - r2_score: 0.8609 - mae: 0.0363 - root_mean_squared_error: 0.0507 - val_loss: 0.0028 - val_r2_score: 0.8312 - val_mae: 0.0368 - val_root_mean_squared_error: 0.0508
# Epoch 36/100
# 187/187 [==============================] - 1s 7ms/step - loss: 0.0028 - r2_score: 0.8621 - mae: 0.0362 - root_mean_squared_error: 0.0506 - val_loss: 0.0029 - val_r2_score: 0.8239 - val_mae: 0.0346 - val_root_mean_squared_error: 0.0518
# Epoch 37/100
# 187/187 [==============================] - 1s 7ms/step - loss: 0.0027 - r2_score: 0.8620 - mae: 0.0362 - root_mean_squared_error: 0.0506 - val_loss: 0.0029 - val_r2_score: 0.8218 - val_mae: 0.0348 - val_root_mean_squared_error: 0.0521
# Epoch 38/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8623 - mae: 0.0362 - root_mean_squared_error: 0.0506 - val_loss: 0.0027 - val_r2_score: 0.8322 - val_mae: 0.0356 - val_root_mean_squared_error: 0.0506
# Epoch 39/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8623 - mae: 0.0360 - root_mean_squared_error: 0.0504 - val_loss: 0.0027 - val_r2_score: 0.8327 - val_mae: 0.0360 - val_root_mean_squared_error: 0.0506
# Epoch 40/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0027 - r2_score: 0.8622 - mae: 0.0360 - root_mean_squared_error: 0.0504 - val_loss: 0.0029 - val_r2_score: 0.8185 - val_mae: 0.0412 - val_root_mean_squared_error: 0.0526
# Epoch 41/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8606 - mae: 0.0361 - root_mean_squared_error: 0.0506 - val_loss: 0.0027 - val_r2_score: 0.8324 - val_mae: 0.0368 - val_root_mean_squared_error: 0.0506
# Epoch 42/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0027 - r2_score: 0.8637 - mae: 0.0359 - root_mean_squared_error: 0.0503 - val_loss: 0.0027 - val_r2_score: 0.8308 - val_mae: 0.0378 - val_root_mean_squared_error: 0.0508
# Epoch 43/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0027 - r2_score: 0.8637 - mae: 0.0359 - root_mean_squared_error: 0.0503 - val_loss: 0.0031 - val_r2_score: 0.8017 - val_mae: 0.0356 - val_root_mean_squared_error: 0.0549
# Epoch 44/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8637 - mae: 0.0359 - root_mean_squared_error: 0.0503 - val_loss: 0.0028 - val_r2_score: 0.8269 - val_mae: 0.0346 - val_root_mean_squared_error: 0.0514
# Epoch 45/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8622 - mae: 0.0361 - root_mean_squared_error: 0.0505 - val_loss: 0.0027 - val_r2_score: 0.8307 - val_mae: 0.0379 - val_root_mean_squared_error: 0.0508
# Epoch 46/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8644 - mae: 0.0358 - root_mean_squared_error: 0.0502 - val_loss: 0.0027 - val_r2_score: 0.8317 - val_mae: 0.0347 - val_root_mean_squared_error: 0.0507
# Epoch 47/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8640 - mae: 0.0358 - root_mean_squared_error: 0.0502 - val_loss: 0.0039 - val_r2_score: 0.7471 - val_mae: 0.0414 - val_root_mean_squared_error: 0.0618
# Epoch 48/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8631 - mae: 0.0360 - root_mean_squared_error: 0.0504 - val_loss: 0.0027 - val_r2_score: 0.8327 - val_mae: 0.0347 - val_root_mean_squared_error: 0.0505
# Epoch 49/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8639 - mae: 0.0358 - root_mean_squared_error: 0.0502 - val_loss: 0.0038 - val_r2_score: 0.7575 - val_mae: 0.0517 - val_root_mean_squared_error: 0.0606
# Epoch 50/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8628 - mae: 0.0361 - root_mean_squared_error: 0.0504 - val_loss: 0.0027 - val_r2_score: 0.8298 - val_mae: 0.0347 - val_root_mean_squared_error: 0.0510
# Epoch 51/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8653 - mae: 0.0357 - root_mean_squared_error: 0.0500 - val_loss: 0.0034 - val_r2_score: 0.7837 - val_mae: 0.0372 - val_root_mean_squared_error: 0.0572
# Epoch 52/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8647 - mae: 0.0357 - root_mean_squared_error: 0.0500 - val_loss: 0.0035 - val_r2_score: 0.7780 - val_mae: 0.0379 - val_root_mean_squared_error: 0.0580
# Epoch 53/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8640 - mae: 0.0359 - root_mean_squared_error: 0.0502 - val_loss: 0.0027 - val_r2_score: 0.8326 - val_mae: 0.0346 - val_root_mean_squared_error: 0.0506
# Epoch 54/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0026 - r2_score: 0.8646 - mae: 0.0358 - root_mean_squared_error: 0.0501 - val_loss: 0.0033 - val_r2_score: 0.7925 - val_mae: 0.0464 - val_root_mean_squared_error: 0.0562
# Epoch 55/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8644 - mae: 0.0358 - root_mean_squared_error: 0.0502 - val_loss: 0.0026 - val_r2_score: 0.8343 - val_mae: 0.0355 - val_root_mean_squared_error: 0.0503
# Epoch 56/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0026 - r2_score: 0.8661 - mae: 0.0355 - root_mean_squared_error: 0.0499 - val_loss: 0.0027 - val_r2_score: 0.8272 - val_mae: 0.0341 - val_root_mean_squared_error: 0.0513
# Epoch 57/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8652 - mae: 0.0355 - root_mean_squared_error: 0.0499 - val_loss: 0.0027 - val_r2_score: 0.8320 - val_mae: 0.0378 - val_root_mean_squared_error: 0.0506
# Epoch 58/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8655 - mae: 0.0356 - root_mean_squared_error: 0.0499 - val_loss: 0.0045 - val_r2_score: 0.7052 - val_mae: 0.0585 - val_root_mean_squared_error: 0.0666
# Epoch 59/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0027 - r2_score: 0.8622 - mae: 0.0362 - root_mean_squared_error: 0.0506 - val_loss: 0.0026 - val_r2_score: 0.8344 - val_mae: 0.0350 - val_root_mean_squared_error: 0.0503
# Epoch 60/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8663 - mae: 0.0354 - root_mean_squared_error: 0.0497 - val_loss: 0.0027 - val_r2_score: 0.8284 - val_mae: 0.0341 - val_root_mean_squared_error: 0.0512
# Epoch 61/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0026 - r2_score: 0.8649 - mae: 0.0357 - root_mean_squared_error: 0.0500 - val_loss: 0.0028 - val_r2_score: 0.8206 - val_mae: 0.0340 - val_root_mean_squared_error: 0.0523
# Epoch 62/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0026 - r2_score: 0.8662 - mae: 0.0356 - root_mean_squared_error: 0.0499 - val_loss: 0.0027 - val_r2_score: 0.8307 - val_mae: 0.0343 - val_root_mean_squared_error: 0.0508
# Epoch 63/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8654 - mae: 0.0356 - root_mean_squared_error: 0.0500 - val_loss: 0.0026 - val_r2_score: 0.8333 - val_mae: 0.0347 - val_root_mean_squared_error: 0.0505
# Epoch 64/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8657 - mae: 0.0355 - root_mean_squared_error: 0.0498 - val_loss: 0.0028 - val_r2_score: 0.8256 - val_mae: 0.0399 - val_root_mean_squared_error: 0.0516
# Epoch 65/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8662 - mae: 0.0356 - root_mean_squared_error: 0.0498 - val_loss: 0.0036 - val_r2_score: 0.7701 - val_mae: 0.0385 - val_root_mean_squared_error: 0.0590
# Epoch 66/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8658 - mae: 0.0356 - root_mean_squared_error: 0.0499 - val_loss: 0.0026 - val_r2_score: 0.8337 - val_mae: 0.0346 - val_root_mean_squared_error: 0.0504
# Epoch 67/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8657 - mae: 0.0355 - root_mean_squared_error: 0.0499 - val_loss: 0.0037 - val_r2_score: 0.7598 - val_mae: 0.0514 - val_root_mean_squared_error: 0.0603
# Epoch 68/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8636 - mae: 0.0360 - root_mean_squared_error: 0.0503 - val_loss: 0.0026 - val_r2_score: 0.8360 - val_mae: 0.0352 - val_root_mean_squared_error: 0.0501
# Epoch 69/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0026 - r2_score: 0.8656 - mae: 0.0355 - root_mean_squared_error: 0.0498 - val_loss: 0.0035 - val_r2_score: 0.7768 - val_mae: 0.0383 - val_root_mean_squared_error: 0.0581
# Epoch 70/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0026 - r2_score: 0.8656 - mae: 0.0356 - root_mean_squared_error: 0.0500 - val_loss: 0.0037 - val_r2_score: 0.7616 - val_mae: 0.0394 - val_root_mean_squared_error: 0.0601
# Epoch 71/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0026 - r2_score: 0.8646 - mae: 0.0357 - root_mean_squared_error: 0.0501 - val_loss: 0.0033 - val_r2_score: 0.7889 - val_mae: 0.0469 - val_root_mean_squared_error: 0.0565
# Epoch 72/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8661 - mae: 0.0356 - root_mean_squared_error: 0.0499 - val_loss: 0.0026 - val_r2_score: 0.8342 - val_mae: 0.0344 - val_root_mean_squared_error: 0.0503
# Epoch 73/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0026 - r2_score: 0.8664 - mae: 0.0354 - root_mean_squared_error: 0.0497 - val_loss: 0.0048 - val_r2_score: 0.6883 - val_mae: 0.0606 - val_root_mean_squared_error: 0.0686
# Epoch 74/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0026 - r2_score: 0.8618 - mae: 0.0362 - root_mean_squared_error: 0.0506 - val_loss: 0.0035 - val_r2_score: 0.7741 - val_mae: 0.0381 - val_root_mean_squared_error: 0.0585
# Epoch 75/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8664 - mae: 0.0355 - root_mean_squared_error: 0.0498 - val_loss: 0.0026 - val_r2_score: 0.8356 - val_mae: 0.0363 - val_root_mean_squared_error: 0.0501
# Epoch 76/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0025 - r2_score: 0.8673 - mae: 0.0354 - root_mean_squared_error: 0.0496 - val_loss: 0.0028 - val_r2_score: 0.8194 - val_mae: 0.0342 - val_root_mean_squared_error: 0.0525
# Epoch 77/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0025 - r2_score: 0.8674 - mae: 0.0353 - root_mean_squared_error: 0.0496 - val_loss: 0.0027 - val_r2_score: 0.8301 - val_mae: 0.0340 - val_root_mean_squared_error: 0.0509
# Epoch 78/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0026 - r2_score: 0.8664 - mae: 0.0355 - root_mean_squared_error: 0.0498 - val_loss: 0.0032 - val_r2_score: 0.7969 - val_mae: 0.0458 - val_root_mean_squared_error: 0.0556
# Epoch 79/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0026 - r2_score: 0.8655 - mae: 0.0357 - root_mean_squared_error: 0.0499 - val_loss: 0.0026 - val_r2_score: 0.8336 - val_mae: 0.0345 - val_root_mean_squared_error: 0.0504
# Epoch 80/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0025 - r2_score: 0.8672 - mae: 0.0353 - root_mean_squared_error: 0.0496 - val_loss: 0.0026 - val_r2_score: 0.8325 - val_mae: 0.0379 - val_root_mean_squared_error: 0.0506
# Epoch 81/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0025 - r2_score: 0.8672 - mae: 0.0354 - root_mean_squared_error: 0.0497 - val_loss: 0.0027 - val_r2_score: 0.8311 - val_mae: 0.0383 - val_root_mean_squared_error: 0.0508
# Epoch 82/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0025 - r2_score: 0.8662 - mae: 0.0354 - root_mean_squared_error: 0.0497 - val_loss: 0.0045 - val_r2_score: 0.7046 - val_mae: 0.0585 - val_root_mean_squared_error: 0.0667
# Epoch 83/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0026 - r2_score: 0.8647 - mae: 0.0357 - root_mean_squared_error: 0.0500 - val_loss: 0.0026 - val_r2_score: 0.8337 - val_mae: 0.0375 - val_root_mean_squared_error: 0.0504
# Epoch 84/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0025 - r2_score: 0.8673 - mae: 0.0354 - root_mean_squared_error: 0.0497 - val_loss: 0.0026 - val_r2_score: 0.8327 - val_mae: 0.0342 - val_root_mean_squared_error: 0.0505
# Epoch 85/100
# 187/187 [==============================] - 2s 11ms/step - loss: 0.0025 - r2_score: 0.8669 - mae: 0.0355 - root_mean_squared_error: 0.0497 - val_loss: 0.0036 - val_r2_score: 0.7651 - val_mae: 0.0392 - val_root_mean_squared_error: 0.0596
# Epoch 86/100
# 187/187 [==============================] - 2s 10ms/step - loss: 0.0025 - r2_score: 0.8665 - mae: 0.0355 - root_mean_squared_error: 0.0498 - val_loss: 0.0028 - val_r2_score: 0.8207 - val_mae: 0.0339 - val_root_mean_squared_error: 0.0523
# Epoch 87/100
# 187/187 [==============================] - 2s 9ms/step - loss: 0.0025 - r2_score: 0.8669 - mae: 0.0354 - root_mean_squared_error: 0.0497 - val_loss: 0.0026 - val_r2_score: 0.8352 - val_mae: 0.0346 - val_root_mean_squared_error: 0.0502
# Epoch 88/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0025 - r2_score: 0.8668 - mae: 0.0355 - root_mean_squared_error: 0.0498 - val_loss: 0.0026 - val_r2_score: 0.8310 - val_mae: 0.0341 - val_root_mean_squared_error: 0.0508
# Epoch 89/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0025 - r2_score: 0.8673 - mae: 0.0353 - root_mean_squared_error: 0.0495 - val_loss: 0.0026 - val_r2_score: 0.8362 - val_mae: 0.0363 - val_root_mean_squared_error: 0.0500
# Epoch 90/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0025 - r2_score: 0.8672 - mae: 0.0354 - root_mean_squared_error: 0.0497 - val_loss: 0.0032 - val_r2_score: 0.7929 - val_mae: 0.0363 - val_root_mean_squared_error: 0.0560
# Epoch 91/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0025 - r2_score: 0.8678 - mae: 0.0353 - root_mean_squared_error: 0.0496 - val_loss: 0.0041 - val_r2_score: 0.7327 - val_mae: 0.0431 - val_root_mean_squared_error: 0.0635
# Epoch 92/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0026 - r2_score: 0.8653 - mae: 0.0356 - root_mean_squared_error: 0.0500 - val_loss: 0.0032 - val_r2_score: 0.7951 - val_mae: 0.0360 - val_root_mean_squared_error: 0.0558
# Epoch 93/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0025 - r2_score: 0.8662 - mae: 0.0355 - root_mean_squared_error: 0.0498 - val_loss: 0.0036 - val_r2_score: 0.7660 - val_mae: 0.0390 - val_root_mean_squared_error: 0.0595
# Epoch 94/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0025 - r2_score: 0.8664 - mae: 0.0354 - root_mean_squared_error: 0.0497 - val_loss: 0.0035 - val_r2_score: 0.7712 - val_mae: 0.0389 - val_root_mean_squared_error: 0.0588
# Epoch 95/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0026 - r2_score: 0.8659 - mae: 0.0355 - root_mean_squared_error: 0.0499 - val_loss: 0.0032 - val_r2_score: 0.7970 - val_mae: 0.0457 - val_root_mean_squared_error: 0.0555
# Epoch 96/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0025 - r2_score: 0.8678 - mae: 0.0353 - root_mean_squared_error: 0.0496 - val_loss: 0.0053 - val_r2_score: 0.6482 - val_mae: 0.0537 - val_root_mean_squared_error: 0.0726
# Epoch 97/100
# 187/187 [==============================] - 1s 7ms/step - loss: 0.0026 - r2_score: 0.8620 - mae: 0.0362 - root_mean_squared_error: 0.0505 - val_loss: 0.0028 - val_r2_score: 0.8199 - val_mae: 0.0343 - val_root_mean_squared_error: 0.0524
# Epoch 98/100
# 187/187 [==============================] - 1s 8ms/step - loss: 0.0025 - r2_score: 0.8673 - mae: 0.0354 - root_mean_squared_error: 0.0497 - val_loss: 0.0027 - val_r2_score: 0.8285 - val_mae: 0.0342 - val_root_mean_squared_error: 0.0512
# Epoch 99/100
# 187/187 [==============================] - 2s 8ms/step - loss: 0.0025 - r2_score: 0.8675 - mae: 0.0352 - root_mean_squared_error: 0.0495 - val_loss: 0.0049 - val_r2_score: 0.6770 - val_mae: 0.0616 - val_root_mean_squared_error: 0.0696
# Epoch 100/100
# 187/187 [==============================] - 2s 10ms/step - loss: 0.0026 - r2_score: 0.8648 - mae: 0.0358 - root_mean_squared_error: 0.0501 - val_loss: 0.0026 - val_r2_score: 0.8308 - val_mae: 0.0386 - val_root_mean_squared_error: 0.0508

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('MSE - CNN Model')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/cnn/loss.png')
plt.show()

# %%
plt.plot(history.history['r2_score'])
plt.plot(history.history['val_r2_score'])
plt.title('R2 Score - CNN Model')
plt.ylabel('R2 Score')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/cnn/r2_score.png')
plt.show()

# %%
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('MAE - CNN Model')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/cnn/mae.png')
plt.show()

# %%
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('RMSE - CNN Model')
plt.ylabel('RMSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/cnn/rmse.png')
plt.show()

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='saved/cnn/model.png', show_shapes=True, show_layer_names=True)

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 29, 126)           378
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 14, 126)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1764)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1764)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                52950
# =================================================================
# Total params: 53,328
# Trainable params: 53,328
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
hist_df = pd.DataFrame(history.history) 
hist_csv_file = 'saved/cnn/history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
prediction = model.predict(X_test, verbose=0)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(prediction, y_test)
r2 = r2_score(prediction[0], y_test[0])
print('Predicted MSE : %s'%mse)
print('Predicted R2 Score : %s'%r2)
# Out:
# Predicted MSE : 0.006857756753128888
# Predicted R2 Score : 0.8900032678372384

# %%
y_test[0]
# Out:
# array([0.08691596, 0.04981832, 0.03586452, 0.08388375, 0.11699138,
#        0.34215042, 0.29021473, 0.20154741, 0.25396091, 0.45269545,
#        0.55495288, 0.54128889, 0.62561651, 0.60933899, 0.65328492,
#        0.86895792, 0.81044585, 1.        , 0.78533247, 0.83584153,
#        0.83610446, 0.69938878, 0.69801691, 0.54846812, 0.67222322,
#        0.38115346, 0.31971893, 0.24138264, 0.22270278, 0.17524422])

# %%
prediction[0]
# Out:
# array([0.12117609, 0.09158471, 0.08424993, 0.08297886, 0.10502626,
#        0.13611929, 0.18636107, 0.24045737, 0.30228537, 0.37136045,
#        0.45343876, 0.52650684, 0.58561254, 0.6501114 , 0.7087404 ,
#        0.73817694, 0.7731075 , 0.7801603 , 0.7831427 , 0.7687905 ,
#        0.7463238 , 0.6966978 , 0.6292305 , 0.5713233 , 0.50068486,
#        0.43080664, 0.3469607 , 0.28911674, 0.21808466, 0.1615986 ],
#       dtype=float32)

# %%
y_test_invert = scaler.inverse_transform(y_test)
y_test_invert
y_test_invert_final = []
# Inverse Box-Cox Transform
for i in range(len(y_test_invert[0])):
    y_test_invert_final.append(invert_boxcox(y_test_invert[0][i], ts_lamb))
x = np.arange(30)
plt.bar(x, y_test_invert_final)
# Out:
# <BarContainer object of 30 artists>

# %%
y_pred_invert = scaler.inverse_transform(prediction)

y_pred_invert_final = []
# Inverse Box-Cox Transform
for i in range(len(y_pred_invert[0])):
    y_pred_invert_final.append(invert_boxcox(y_pred_invert[0][i], ts_lamb))
x = np.arange(30)
plt.bar(x, y_pred_invert_final)
# Out:
# <BarContainer object of 30 artists>

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_pred_invert_final, y_test_invert_final)
r2 = r2_score(y_pred_invert_[0], y_test_invert_final[0])
print('Predicted MSE : %s'%mse)
print('Predicted R2 Score : %s'%r2)
# Out:
# Predicted MSE : 0.25772284066433787
# Predicted R2 Score : 0.8900032117545301

# %%
y_pred_invert
# Out:
# array([[14.962773, 14.781368, 14.736404, 14.728611, 14.86377 , 15.054381,
#         15.362381, 15.69401 , 16.073038, 16.49649 , 16.99966 , 17.447594,
#         17.809933, 18.205334, 18.564749, 18.745205, 18.959343, 19.002577,
#         19.02086 , 18.932877, 18.795149, 18.490923, 18.077326, 17.722334,
#         17.289295, 16.860918, 16.346912, 15.992309, 15.556857, 15.210577]],
#       dtype=float32)

# %%
y_test_invert
# Out:
# array([[14.75274718, 14.52532563, 14.43978398, 14.73415866, 14.93712005,
#         16.31742387, 15.99903992, 15.45547817, 15.7767913 , 16.99510365,
#         17.62197755, 17.53821249, 18.05517037, 17.95538347, 18.22478739,
#         19.54693849, 19.18823898, 20.35027236, 19.03428519, 19.34392341,
#         19.34553527, 18.50742023, 18.4990102 , 17.58222371, 18.34088583,
#         16.5565262 , 16.17991096, 15.69968205, 15.58516797, 15.29423038]])

# %%
plt.plot(y_test_invert[0])
plt.plot(y_pred_invert[0])
plt.title('CNN - 30 Day Forecast')
plt.ylabel('Rainfall')
plt.xlabel('Days')
plt.legend(['Actual', 'Predicted'], loc='upper left')
plt.savefig('saved/cnn/test.png')
plt.show()
