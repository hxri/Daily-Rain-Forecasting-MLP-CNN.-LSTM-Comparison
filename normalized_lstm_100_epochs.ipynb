# %%
# univariate multi-step vector-output 1d cnn example
from numpy import array
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
import pandas as pd

from math import log
from math import exp
from scipy.stats import boxcox

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps_in, n_steps_out):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps_in
		out_end_ix = end_ix + n_steps_out
		# check if we are beyond the sequence
		if out_end_ix > len(sequence):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# %%
# invert a boxcox transform for one value
def invert_boxcox(value, lam):
	# log case
	if lam == 0:
		return exp(value)
	# all other cases
	return exp(log(lam * value + 1) / lam)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

data = pd.read_csv("Timeseries_real_data_interview.csv")
t = data.iloc[0:11964] #11565
v = data.iloc[11964:19940]
ts = data.iloc[19940:20001]
# define input sequence
train_seq = t['Value'].values
val_seq = v['Value'].values
test_seq = ts['Value'].values

train_seq, tr_lamb = boxcox(train_seq)
val_seq, vl_lamb = boxcox(val_seq)
test_seq, ts_lamb = boxcox(test_seq)

train_seq = train_seq.reshape((len(train_seq), 1))
val_seq = val_seq.reshape((len(val_seq), 1))
test_seq = test_seq.reshape((len(test_seq), 1))

scaler1 = scaler.fit(train_seq)
train_seq = scaler1.transform(train_seq)

scaler2 = scaler.fit(val_seq)
val_seq = scaler2.transform(val_seq)

scaler3 = scaler.fit(test_seq)
test_seq = scaler3.transform(test_seq)

"""
tr, tr_lamb = boxcox(train_seq)
vl, vl_lamb = boxcox(val_seq)
ts, ts_lamb = boxcox(test_seq)
"""

print('Training Sequence : %d'%len(train_seq))
print('Validation Sequence : %d'%len(val_seq))
print('Testing Sequence : %d'%len(test_seq))

s1 = []
s2 = []
s3 = []

for i in range(len(train_seq)):
    s1.append(train_seq[i][0])
    
for i in range(len(val_seq)):
    s2.append(val_seq[i][0])
    
for i in range(len(test_seq)):
    s3.append(test_seq[i][0])
    
tr = s1
vl = s2
ts = s3
# Out:
# Training Sequence : 11964
# Validation Sequence : 7976
# Testing Sequence : 60

# %%
# choose a number of time steps
n_steps_in, n_steps_out = 30, 30
# split into samples
X_train, y_train = split_sequence(tr, n_steps_in, n_steps_out)
X_val, y_val = split_sequence(vl, n_steps_in, n_steps_out)
X_test, y_test = split_sequence(ts, n_steps_in, n_steps_out)
# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], n_features))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))

# %%
# define model
import keras.backend as kb

def r2_score(y_true, y_pred):
    ss_res = kb.sum(kb.square(y_true - y_pred))
    ss_tot = kb.sum(kb.square(y_true - kb.mean(y_true)))
    return (1 - ss_res/(ss_tot + kb.epsilon()))

model = Sequential()
model.add(LSTM(90, activation='relu', return_sequences=True, input_shape=(n_steps_in, n_features)))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(n_steps_out))

adam = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=adam, loss='mse', metrics=[r2_score,'mae', keras.metrics.RootMeanSquaredError()])

# %%
# fit model
history = model.fit(X_train, y_train, epochs=100, verbose=1, validation_data=(X_val, y_val), batch_size=64)
# Out:
# Epoch 1/100
# 187/187 [==============================] - 11s 57ms/step - loss: 0.0083 - r2_score: 0.5560 - mae: 0.0611 - root_mean_squared_error: 0.0911 - val_loss: 0.0027 - val_r2_score: 0.8262 - val_mae: 0.0367 - val_root_mean_squared_error: 0.0515
# Epoch 2/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0027 - r2_score: 0.8512 - mae: 0.0377 - root_mean_squared_error: 0.0524 - val_loss: 0.0026 - val_r2_score: 0.8266 - val_mae: 0.0359 - val_root_mean_squared_error: 0.0514
# Epoch 3/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0027 - r2_score: 0.8541 - mae: 0.0371 - root_mean_squared_error: 0.0517 - val_loss: 0.0027 - val_r2_score: 0.8242 - val_mae: 0.0358 - val_root_mean_squared_error: 0.0518
# Epoch 4/100
# 187/187 [==============================] - 7s 38ms/step - loss: 0.0026 - r2_score: 0.8577 - mae: 0.0368 - root_mean_squared_error: 0.0514 - val_loss: 0.0026 - val_r2_score: 0.8279 - val_mae: 0.0368 - val_root_mean_squared_error: 0.0512
# Epoch 5/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0026 - r2_score: 0.8594 - mae: 0.0366 - root_mean_squared_error: 0.0511 - val_loss: 0.0026 - val_r2_score: 0.8280 - val_mae: 0.0364 - val_root_mean_squared_error: 0.0512
# Epoch 6/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0026 - r2_score: 0.8603 - mae: 0.0364 - root_mean_squared_error: 0.0509 - val_loss: 0.0026 - val_r2_score: 0.8283 - val_mae: 0.0367 - val_root_mean_squared_error: 0.0512
# Epoch 7/100
# 187/187 [==============================] - 7s 38ms/step - loss: 0.0026 - r2_score: 0.8617 - mae: 0.0362 - root_mean_squared_error: 0.0506 - val_loss: 0.0026 - val_r2_score: 0.8276 - val_mae: 0.0356 - val_root_mean_squared_error: 0.0513
# Epoch 8/100
# 187/187 [==============================] - 7s 38ms/step - loss: 0.0025 - r2_score: 0.8634 - mae: 0.0360 - root_mean_squared_error: 0.0504 - val_loss: 0.0026 - val_r2_score: 0.8290 - val_mae: 0.0350 - val_root_mean_squared_error: 0.0511
# Epoch 9/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0025 - r2_score: 0.8648 - mae: 0.0357 - root_mean_squared_error: 0.0501 - val_loss: 0.0027 - val_r2_score: 0.8241 - val_mae: 0.0343 - val_root_mean_squared_error: 0.0518
# Epoch 10/100
# 187/187 [==============================] - 8s 41ms/step - loss: 0.0025 - r2_score: 0.8655 - mae: 0.0356 - root_mean_squared_error: 0.0499 - val_loss: 0.0026 - val_r2_score: 0.8261 - val_mae: 0.0392 - val_root_mean_squared_error: 0.0515
# Epoch 11/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0025 - r2_score: 0.8653 - mae: 0.0356 - root_mean_squared_error: 0.0499 - val_loss: 0.0026 - val_r2_score: 0.8311 - val_mae: 0.0371 - val_root_mean_squared_error: 0.0508
# Epoch 12/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0025 - r2_score: 0.8663 - mae: 0.0355 - root_mean_squared_error: 0.0498 - val_loss: 0.0028 - val_r2_score: 0.8166 - val_mae: 0.0346 - val_root_mean_squared_error: 0.0528
# Epoch 13/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0025 - r2_score: 0.8667 - mae: 0.0354 - root_mean_squared_error: 0.0497 - val_loss: 0.0026 - val_r2_score: 0.8311 - val_mae: 0.0378 - val_root_mean_squared_error: 0.0507
# Epoch 14/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0025 - r2_score: 0.8667 - mae: 0.0353 - root_mean_squared_error: 0.0495 - val_loss: 0.0026 - val_r2_score: 0.8321 - val_mae: 0.0355 - val_root_mean_squared_error: 0.0506
# Epoch 15/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0025 - r2_score: 0.8675 - mae: 0.0353 - root_mean_squared_error: 0.0496 - val_loss: 0.0026 - val_r2_score: 0.8309 - val_mae: 0.0348 - val_root_mean_squared_error: 0.0508
# Epoch 16/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8681 - mae: 0.0351 - root_mean_squared_error: 0.0494 - val_loss: 0.0025 - val_r2_score: 0.8331 - val_mae: 0.0354 - val_root_mean_squared_error: 0.0505
# Epoch 17/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8671 - mae: 0.0352 - root_mean_squared_error: 0.0495 - val_loss: 0.0026 - val_r2_score: 0.8325 - val_mae: 0.0355 - val_root_mean_squared_error: 0.0506
# Epoch 18/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8686 - mae: 0.0352 - root_mean_squared_error: 0.0494 - val_loss: 0.0025 - val_r2_score: 0.8331 - val_mae: 0.0373 - val_root_mean_squared_error: 0.0505
# Epoch 19/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8690 - mae: 0.0351 - root_mean_squared_error: 0.0493 - val_loss: 0.0026 - val_r2_score: 0.8274 - val_mae: 0.0349 - val_root_mean_squared_error: 0.0513
# Epoch 20/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8687 - mae: 0.0351 - root_mean_squared_error: 0.0493 - val_loss: 0.0025 - val_r2_score: 0.8331 - val_mae: 0.0350 - val_root_mean_squared_error: 0.0505
# Epoch 21/100
# 187/187 [==============================] - 8s 40ms/step - loss: 0.0024 - r2_score: 0.8696 - mae: 0.0350 - root_mean_squared_error: 0.0493 - val_loss: 0.0027 - val_r2_score: 0.8257 - val_mae: 0.0344 - val_root_mean_squared_error: 0.0515
# Epoch 22/100
# 187/187 [==============================] - 8s 42ms/step - loss: 0.0024 - r2_score: 0.8689 - mae: 0.0350 - root_mean_squared_error: 0.0493 - val_loss: 0.0025 - val_r2_score: 0.8331 - val_mae: 0.0357 - val_root_mean_squared_error: 0.0505
# Epoch 23/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8690 - mae: 0.0351 - root_mean_squared_error: 0.0493 - val_loss: 0.0026 - val_r2_score: 0.8296 - val_mae: 0.0387 - val_root_mean_squared_error: 0.0510
# Epoch 24/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8691 - mae: 0.0351 - root_mean_squared_error: 0.0493 - val_loss: 0.0025 - val_r2_score: 0.8344 - val_mae: 0.0350 - val_root_mean_squared_error: 0.0503
# Epoch 25/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8700 - mae: 0.0349 - root_mean_squared_error: 0.0491 - val_loss: 0.0029 - val_r2_score: 0.8100 - val_mae: 0.0349 - val_root_mean_squared_error: 0.0538
# Epoch 26/100
# 187/187 [==============================] - 8s 42ms/step - loss: 0.0024 - r2_score: 0.8664 - mae: 0.0351 - root_mean_squared_error: 0.0493 - val_loss: 0.0027 - val_r2_score: 0.8241 - val_mae: 0.0394 - val_root_mean_squared_error: 0.0517
# Epoch 27/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0025 - r2_score: 0.8667 - mae: 0.0353 - root_mean_squared_error: 0.0495 - val_loss: 0.0025 - val_r2_score: 0.8356 - val_mae: 0.0351 - val_root_mean_squared_error: 0.0501
# Epoch 28/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8698 - mae: 0.0350 - root_mean_squared_error: 0.0492 - val_loss: 0.0025 - val_r2_score: 0.8337 - val_mae: 0.0344 - val_root_mean_squared_error: 0.0504
# Epoch 29/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8701 - mae: 0.0349 - root_mean_squared_error: 0.0491 - val_loss: 0.0026 - val_r2_score: 0.8300 - val_mae: 0.0388 - val_root_mean_squared_error: 0.0509
# Epoch 30/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8698 - mae: 0.0350 - root_mean_squared_error: 0.0491 - val_loss: 0.0026 - val_r2_score: 0.8258 - val_mae: 0.0395 - val_root_mean_squared_error: 0.0515
# Epoch 31/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8703 - mae: 0.0349 - root_mean_squared_error: 0.0491 - val_loss: 0.0029 - val_r2_score: 0.8111 - val_mae: 0.0351 - val_root_mean_squared_error: 0.0536
# Epoch 32/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8695 - mae: 0.0350 - root_mean_squared_error: 0.0492 - val_loss: 0.0025 - val_r2_score: 0.8348 - val_mae: 0.0351 - val_root_mean_squared_error: 0.0502
# Epoch 33/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8710 - mae: 0.0348 - root_mean_squared_error: 0.0490 - val_loss: 0.0025 - val_r2_score: 0.8343 - val_mae: 0.0344 - val_root_mean_squared_error: 0.0503
# Epoch 34/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8709 - mae: 0.0348 - root_mean_squared_error: 0.0490 - val_loss: 0.0025 - val_r2_score: 0.8336 - val_mae: 0.0350 - val_root_mean_squared_error: 0.0504
# Epoch 35/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8717 - mae: 0.0347 - root_mean_squared_error: 0.0489 - val_loss: 0.0025 - val_r2_score: 0.8356 - val_mae: 0.0344 - val_root_mean_squared_error: 0.0501
# Epoch 36/100
# 187/187 [==============================] - 8s 42ms/step - loss: 0.0024 - r2_score: 0.8710 - mae: 0.0348 - root_mean_squared_error: 0.0489 - val_loss: 0.0025 - val_r2_score: 0.8367 - val_mae: 0.0361 - val_root_mean_squared_error: 0.0499
# Epoch 37/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8710 - mae: 0.0348 - root_mean_squared_error: 0.0490 - val_loss: 0.0025 - val_r2_score: 0.8343 - val_mae: 0.0369 - val_root_mean_squared_error: 0.0503
# Epoch 38/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8704 - mae: 0.0348 - root_mean_squared_error: 0.0490 - val_loss: 0.0025 - val_r2_score: 0.8339 - val_mae: 0.0342 - val_root_mean_squared_error: 0.0504
# Epoch 39/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8707 - mae: 0.0349 - root_mean_squared_error: 0.0490 - val_loss: 0.0025 - val_r2_score: 0.8368 - val_mae: 0.0355 - val_root_mean_squared_error: 0.0499
# Epoch 40/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8706 - mae: 0.0347 - root_mean_squared_error: 0.0489 - val_loss: 0.0025 - val_r2_score: 0.8344 - val_mae: 0.0370 - val_root_mean_squared_error: 0.0503
# Epoch 41/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8710 - mae: 0.0349 - root_mean_squared_error: 0.0490 - val_loss: 0.0025 - val_r2_score: 0.8351 - val_mae: 0.0345 - val_root_mean_squared_error: 0.0502
# Epoch 42/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8709 - mae: 0.0347 - root_mean_squared_error: 0.0489 - val_loss: 0.0025 - val_r2_score: 0.8329 - val_mae: 0.0379 - val_root_mean_squared_error: 0.0505
# Epoch 43/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8711 - mae: 0.0348 - root_mean_squared_error: 0.0489 - val_loss: 0.0025 - val_r2_score: 0.8370 - val_mae: 0.0364 - val_root_mean_squared_error: 0.0499
# Epoch 44/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8711 - mae: 0.0348 - root_mean_squared_error: 0.0489 - val_loss: 0.0025 - val_r2_score: 0.8368 - val_mae: 0.0348 - val_root_mean_squared_error: 0.0499
# Epoch 45/100
# 187/187 [==============================] - 8s 40ms/step - loss: 0.0024 - r2_score: 0.8697 - mae: 0.0347 - root_mean_squared_error: 0.0489 - val_loss: 0.0025 - val_r2_score: 0.8341 - val_mae: 0.0359 - val_root_mean_squared_error: 0.0504
# Epoch 46/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8712 - mae: 0.0348 - root_mean_squared_error: 0.0489 - val_loss: 0.0026 - val_r2_score: 0.8330 - val_mae: 0.0341 - val_root_mean_squared_error: 0.0505
# Epoch 47/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8717 - mae: 0.0347 - root_mean_squared_error: 0.0488 - val_loss: 0.0025 - val_r2_score: 0.8373 - val_mae: 0.0355 - val_root_mean_squared_error: 0.0498
# Epoch 48/100
# 187/187 [==============================] - 8s 42ms/step - loss: 0.0024 - r2_score: 0.8719 - mae: 0.0346 - root_mean_squared_error: 0.0487 - val_loss: 0.0025 - val_r2_score: 0.8343 - val_mae: 0.0342 - val_root_mean_squared_error: 0.0503
# Epoch 49/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8714 - mae: 0.0347 - root_mean_squared_error: 0.0488 - val_loss: 0.0026 - val_r2_score: 0.8285 - val_mae: 0.0393 - val_root_mean_squared_error: 0.0511
# Epoch 50/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8718 - mae: 0.0347 - root_mean_squared_error: 0.0488 - val_loss: 0.0025 - val_r2_score: 0.8371 - val_mae: 0.0365 - val_root_mean_squared_error: 0.0499
# Epoch 51/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8721 - mae: 0.0346 - root_mean_squared_error: 0.0487 - val_loss: 0.0025 - val_r2_score: 0.8368 - val_mae: 0.0360 - val_root_mean_squared_error: 0.0499
# Epoch 52/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8720 - mae: 0.0346 - root_mean_squared_error: 0.0487 - val_loss: 0.0025 - val_r2_score: 0.8369 - val_mae: 0.0365 - val_root_mean_squared_error: 0.0499
# Epoch 53/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8719 - mae: 0.0347 - root_mean_squared_error: 0.0487 - val_loss: 0.0026 - val_r2_score: 0.8311 - val_mae: 0.0386 - val_root_mean_squared_error: 0.0507
# Epoch 54/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8722 - mae: 0.0347 - root_mean_squared_error: 0.0487 - val_loss: 0.0025 - val_r2_score: 0.8356 - val_mae: 0.0349 - val_root_mean_squared_error: 0.0501
# Epoch 55/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8722 - mae: 0.0346 - root_mean_squared_error: 0.0487 - val_loss: 0.0025 - val_r2_score: 0.8375 - val_mae: 0.0346 - val_root_mean_squared_error: 0.0498
# Epoch 56/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8720 - mae: 0.0346 - root_mean_squared_error: 0.0487 - val_loss: 0.0026 - val_r2_score: 0.8274 - val_mae: 0.0398 - val_root_mean_squared_error: 0.0513
# Epoch 57/100
# 187/187 [==============================] - 8s 41ms/step - loss: 0.0024 - r2_score: 0.8713 - mae: 0.0347 - root_mean_squared_error: 0.0488 - val_loss: 0.0025 - val_r2_score: 0.8371 - val_mae: 0.0350 - val_root_mean_squared_error: 0.0499
# Epoch 58/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8723 - mae: 0.0346 - root_mean_squared_error: 0.0487 - val_loss: 0.0026 - val_r2_score: 0.8325 - val_mae: 0.0339 - val_root_mean_squared_error: 0.0505
# Epoch 59/100
# 187/187 [==============================] - 7s 38ms/step - loss: 0.0024 - r2_score: 0.8720 - mae: 0.0346 - root_mean_squared_error: 0.0487 - val_loss: 0.0025 - val_r2_score: 0.8370 - val_mae: 0.0368 - val_root_mean_squared_error: 0.0499
# Epoch 60/100
# 187/187 [==============================] - 8s 42ms/step - loss: 0.0024 - r2_score: 0.8725 - mae: 0.0346 - root_mean_squared_error: 0.0486 - val_loss: 0.0025 - val_r2_score: 0.8369 - val_mae: 0.0345 - val_root_mean_squared_error: 0.0499
# Epoch 61/100
# 187/187 [==============================] - 8s 41ms/step - loss: 0.0024 - r2_score: 0.8721 - mae: 0.0346 - root_mean_squared_error: 0.0487 - val_loss: 0.0025 - val_r2_score: 0.8346 - val_mae: 0.0374 - val_root_mean_squared_error: 0.0502
# Epoch 62/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8724 - mae: 0.0346 - root_mean_squared_error: 0.0486 - val_loss: 0.0025 - val_r2_score: 0.8364 - val_mae: 0.0365 - val_root_mean_squared_error: 0.0500
# Epoch 63/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8722 - mae: 0.0346 - root_mean_squared_error: 0.0486 - val_loss: 0.0026 - val_r2_score: 0.8317 - val_mae: 0.0384 - val_root_mean_squared_error: 0.0507
# Epoch 64/100
# 187/187 [==============================] - 9s 47ms/step - loss: 0.0024 - r2_score: 0.8723 - mae: 0.0346 - root_mean_squared_error: 0.0487 - val_loss: 0.0025 - val_r2_score: 0.8360 - val_mae: 0.0344 - val_root_mean_squared_error: 0.0501
# Epoch 65/100
# 187/187 [==============================] - 12s 62ms/step - loss: 0.0024 - r2_score: 0.8726 - mae: 0.0345 - root_mean_squared_error: 0.0486 - val_loss: 0.0025 - val_r2_score: 0.8373 - val_mae: 0.0362 - val_root_mean_squared_error: 0.0499
# Epoch 66/100
# 187/187 [==============================] - 7s 40ms/step - loss: 0.0024 - r2_score: 0.8722 - mae: 0.0346 - root_mean_squared_error: 0.0486 - val_loss: 0.0025 - val_r2_score: 0.8374 - val_mae: 0.0364 - val_root_mean_squared_error: 0.0498
# Epoch 67/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0024 - r2_score: 0.8729 - mae: 0.0345 - root_mean_squared_error: 0.0486 - val_loss: 0.0026 - val_r2_score: 0.8287 - val_mae: 0.0339 - val_root_mean_squared_error: 0.0511
# Epoch 68/100
# 187/187 [==============================] - 7s 36ms/step - loss: 0.0024 - r2_score: 0.8730 - mae: 0.0345 - root_mean_squared_error: 0.0486 - val_loss: 0.0029 - val_r2_score: 0.8101 - val_mae: 0.0349 - val_root_mean_squared_error: 0.0537
# Epoch 69/100
# 187/187 [==============================] - 6s 34ms/step - loss: 0.0024 - r2_score: 0.8720 - mae: 0.0346 - root_mean_squared_error: 0.0487 - val_loss: 0.0025 - val_r2_score: 0.8373 - val_mae: 0.0350 - val_root_mean_squared_error: 0.0498
# Epoch 70/100
# 187/187 [==============================] - 6s 34ms/step - loss: 0.0024 - r2_score: 0.8723 - mae: 0.0345 - root_mean_squared_error: 0.0486 - val_loss: 0.0026 - val_r2_score: 0.8280 - val_mae: 0.0394 - val_root_mean_squared_error: 0.0511
# Epoch 71/100
# 187/187 [==============================] - 7s 35ms/step - loss: 0.0024 - r2_score: 0.8710 - mae: 0.0347 - root_mean_squared_error: 0.0488 - val_loss: 0.0025 - val_r2_score: 0.8366 - val_mae: 0.0357 - val_root_mean_squared_error: 0.0499
# Epoch 72/100
# 187/187 [==============================] - 6s 35ms/step - loss: 0.0024 - r2_score: 0.8719 - mae: 0.0346 - root_mean_squared_error: 0.0487 - val_loss: 0.0025 - val_r2_score: 0.8386 - val_mae: 0.0361 - val_root_mean_squared_error: 0.0496
# Epoch 73/100
# 187/187 [==============================] - 7s 35ms/step - loss: 0.0024 - r2_score: 0.8729 - mae: 0.0345 - root_mean_squared_error: 0.0485 - val_loss: 0.0025 - val_r2_score: 0.8373 - val_mae: 0.0365 - val_root_mean_squared_error: 0.0498
# Epoch 74/100
# 187/187 [==============================] - 7s 36ms/step - loss: 0.0024 - r2_score: 0.8729 - mae: 0.0345 - root_mean_squared_error: 0.0486 - val_loss: 0.0026 - val_r2_score: 0.8323 - val_mae: 0.0346 - val_root_mean_squared_error: 0.0506
# Epoch 75/100
# 187/187 [==============================] - 7s 37ms/step - loss: 0.0024 - r2_score: 0.8727 - mae: 0.0346 - root_mean_squared_error: 0.0486 - val_loss: 0.0025 - val_r2_score: 0.8380 - val_mae: 0.0347 - val_root_mean_squared_error: 0.0498
# Epoch 76/100
# 187/187 [==============================] - 7s 36ms/step - loss: 0.0024 - r2_score: 0.8732 - mae: 0.0344 - root_mean_squared_error: 0.0485 - val_loss: 0.0025 - val_r2_score: 0.8378 - val_mae: 0.0344 - val_root_mean_squared_error: 0.0498
# Epoch 77/100
# 187/187 [==============================] - 7s 37ms/step - loss: 0.0024 - r2_score: 0.8733 - mae: 0.0345 - root_mean_squared_error: 0.0485 - val_loss: 0.0025 - val_r2_score: 0.8354 - val_mae: 0.0340 - val_root_mean_squared_error: 0.0501
# Epoch 78/100
# 187/187 [==============================] - 7s 36ms/step - loss: 0.0024 - r2_score: 0.8733 - mae: 0.0345 - root_mean_squared_error: 0.0485 - val_loss: 0.0025 - val_r2_score: 0.8390 - val_mae: 0.0354 - val_root_mean_squared_error: 0.0496
# Epoch 79/100
# 187/187 [==============================] - 6s 35ms/step - loss: 0.0024 - r2_score: 0.8726 - mae: 0.0344 - root_mean_squared_error: 0.0485 - val_loss: 0.0025 - val_r2_score: 0.8373 - val_mae: 0.0362 - val_root_mean_squared_error: 0.0499
# Epoch 80/100
# 187/187 [==============================] - 7s 35ms/step - loss: 0.0024 - r2_score: 0.8730 - mae: 0.0345 - root_mean_squared_error: 0.0485 - val_loss: 0.0026 - val_r2_score: 0.8290 - val_mae: 0.0338 - val_root_mean_squared_error: 0.0511
# Epoch 81/100
# 187/187 [==============================] - 7s 35ms/step - loss: 0.0024 - r2_score: 0.8726 - mae: 0.0346 - root_mean_squared_error: 0.0486 - val_loss: 0.0025 - val_r2_score: 0.8371 - val_mae: 0.0347 - val_root_mean_squared_error: 0.0499
# Epoch 82/100
# 187/187 [==============================] - 7s 36ms/step - loss: 0.0024 - r2_score: 0.8734 - mae: 0.0345 - root_mean_squared_error: 0.0485 - val_loss: 0.0025 - val_r2_score: 0.8372 - val_mae: 0.0345 - val_root_mean_squared_error: 0.0499
# Epoch 83/100
# 187/187 [==============================] - 7s 36ms/step - loss: 0.0023 - r2_score: 0.8734 - mae: 0.0344 - root_mean_squared_error: 0.0484 - val_loss: 0.0025 - val_r2_score: 0.8383 - val_mae: 0.0353 - val_root_mean_squared_error: 0.0497
# Epoch 84/100
# 187/187 [==============================] - 7s 37ms/step - loss: 0.0023 - r2_score: 0.8737 - mae: 0.0344 - root_mean_squared_error: 0.0484 - val_loss: 0.0026 - val_r2_score: 0.8308 - val_mae: 0.0337 - val_root_mean_squared_error: 0.0508
# Epoch 85/100
# 187/187 [==============================] - 7s 38ms/step - loss: 0.0024 - r2_score: 0.8733 - mae: 0.0344 - root_mean_squared_error: 0.0485 - val_loss: 0.0025 - val_r2_score: 0.8378 - val_mae: 0.0358 - val_root_mean_squared_error: 0.0498
# Epoch 86/100
# 187/187 [==============================] - 7s 35ms/step - loss: 0.0023 - r2_score: 0.8736 - mae: 0.0344 - root_mean_squared_error: 0.0485 - val_loss: 0.0026 - val_r2_score: 0.8272 - val_mae: 0.0338 - val_root_mean_squared_error: 0.0513
# Epoch 87/100
# 187/187 [==============================] - 8s 42ms/step - loss: 0.0024 - r2_score: 0.8729 - mae: 0.0345 - root_mean_squared_error: 0.0485 - val_loss: 0.0025 - val_r2_score: 0.8345 - val_mae: 0.0339 - val_root_mean_squared_error: 0.0503
# Epoch 88/100
# 187/187 [==============================] - 8s 42ms/step - loss: 0.0023 - r2_score: 0.8735 - mae: 0.0344 - root_mean_squared_error: 0.0485 - val_loss: 0.0025 - val_r2_score: 0.8336 - val_mae: 0.0340 - val_root_mean_squared_error: 0.0504
# Epoch 89/100
# 187/187 [==============================] - 6s 35ms/step - loss: 0.0023 - r2_score: 0.8733 - mae: 0.0344 - root_mean_squared_error: 0.0484 - val_loss: 0.0025 - val_r2_score: 0.8342 - val_mae: 0.0379 - val_root_mean_squared_error: 0.0503
# Epoch 90/100
# 187/187 [==============================] - 7s 38ms/step - loss: 0.0024 - r2_score: 0.8731 - mae: 0.0345 - root_mean_squared_error: 0.0485 - val_loss: 0.0025 - val_r2_score: 0.8368 - val_mae: 0.0349 - val_root_mean_squared_error: 0.0499
# Epoch 91/100
# 187/187 [==============================] - 7s 35ms/step - loss: 0.0023 - r2_score: 0.8732 - mae: 0.0344 - root_mean_squared_error: 0.0485 - val_loss: 0.0025 - val_r2_score: 0.8389 - val_mae: 0.0352 - val_root_mean_squared_error: 0.0496
# Epoch 92/100
# 187/187 [==============================] - 8s 41ms/step - loss: 0.0023 - r2_score: 0.8734 - mae: 0.0344 - root_mean_squared_error: 0.0484 - val_loss: 0.0025 - val_r2_score: 0.8375 - val_mae: 0.0342 - val_root_mean_squared_error: 0.0498
# Epoch 93/100
# 187/187 [==============================] - 7s 36ms/step - loss: 0.0023 - r2_score: 0.8731 - mae: 0.0345 - root_mean_squared_error: 0.0485 - val_loss: 0.0025 - val_r2_score: 0.8355 - val_mae: 0.0352 - val_root_mean_squared_error: 0.0501
# Epoch 94/100
# 187/187 [==============================] - 7s 36ms/step - loss: 0.0023 - r2_score: 0.8737 - mae: 0.0344 - root_mean_squared_error: 0.0484 - val_loss: 0.0025 - val_r2_score: 0.8344 - val_mae: 0.0377 - val_root_mean_squared_error: 0.0503
# Epoch 95/100
# 187/187 [==============================] - 7s 36ms/step - loss: 0.0023 - r2_score: 0.8736 - mae: 0.0344 - root_mean_squared_error: 0.0484 - val_loss: 0.0025 - val_r2_score: 0.8342 - val_mae: 0.0378 - val_root_mean_squared_error: 0.0503
# Epoch 96/100
# 187/187 [==============================] - 7s 35ms/step - loss: 0.0023 - r2_score: 0.8738 - mae: 0.0345 - root_mean_squared_error: 0.0484 - val_loss: 0.0025 - val_r2_score: 0.8383 - val_mae: 0.0356 - val_root_mean_squared_error: 0.0497
# Epoch 97/100
# 187/187 [==============================] - 7s 39ms/step - loss: 0.0023 - r2_score: 0.8737 - mae: 0.0343 - root_mean_squared_error: 0.0483 - val_loss: 0.0025 - val_r2_score: 0.8375 - val_mae: 0.0354 - val_root_mean_squared_error: 0.0499
# Epoch 98/100
# 187/187 [==============================] - 6s 35ms/step - loss: 0.0023 - r2_score: 0.8738 - mae: 0.0344 - root_mean_squared_error: 0.0484 - val_loss: 0.0025 - val_r2_score: 0.8369 - val_mae: 0.0345 - val_root_mean_squared_error: 0.0499
# Epoch 99/100
# 187/187 [==============================] - 7s 36ms/step - loss: 0.0023 - r2_score: 0.8741 - mae: 0.0344 - root_mean_squared_error: 0.0484 - val_loss: 0.0025 - val_r2_score: 0.8353 - val_mae: 0.0342 - val_root_mean_squared_error: 0.0502
# Epoch 100/100
# 187/187 [==============================] - 8s 42ms/step - loss: 0.0023 - r2_score: 0.8738 - mae: 0.0344 - root_mean_squared_error: 0.0484 - val_loss: 0.0025 - val_r2_score: 0.8374 - val_mae: 0.0344 - val_root_mean_squared_error: 0.0498

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('MSE - LSTM Model')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/lstm/loss.png')
plt.show()

# %%
plt.plot(history.history['r2_score'])
plt.plot(history.history['val_r2_score'])
plt.title('R2 Score - LSTM Model')
plt.ylabel('R2 Score')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/lstm/r2_score.png')
plt.show()

# %%
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('MAE - LSTM Model')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/lstm/mae.png')
plt.show()

# %%
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('RMSE - LSTM Model')
plt.ylabel('RMSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('saved/lstm/rmse.png')
plt.show()

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='saved/lstm/model.png', show_shapes=True, show_layer_names=True)

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 90)            33120
# _________________________________________________________________
# flatten (Flatten)            (None, 2700)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2700)              0
# _________________________________________________________________
# dense (Dense)                (None, 30)                81030
# =================================================================
# Total params: 114,150
# Trainable params: 114,150
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
hist_df = pd.DataFrame(history.history) 
hist_csv_file = 'saved/lstm/history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
prediction = model.predict(X_test, verbose=0)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(prediction, y_test)
r2 = r2_score(prediction[0], y_test[0])
print('Predicted MSE : %s'%mse)
print('Predicted R2 Score : %s'%r2)
# Out:
# Predicted MSE : 0.01601462100956502
# Predicted R2 Score : 0.5778337430988011

# %%
y_test[0]
# Out:
# array([0.08691596, 0.04981832, 0.03586452, 0.08388375, 0.11699138,
#        0.34215042, 0.29021473, 0.20154741, 0.25396091, 0.45269545,
#        0.55495288, 0.54128889, 0.62561651, 0.60933899, 0.65328492,
#        0.86895792, 0.81044585, 1.        , 0.78533247, 0.83584153,
#        0.83610446, 0.69938878, 0.69801691, 0.54846812, 0.67222322,
#        0.38115346, 0.31971893, 0.24138264, 0.22270278, 0.17524422])

# %%
prediction[0]
# Out:
# array([0.16805016, 0.13069427, 0.12331218, 0.12716685, 0.13405082,
#        0.15649267, 0.189892  , 0.2434419 , 0.28363544, 0.34229118,
#        0.3970052 , 0.44343   , 0.49407548, 0.53891486, 0.5900343 ,
#        0.62597215, 0.650543  , 0.6644169 , 0.6723809 , 0.6643611 ,
#        0.65087473, 0.63190293, 0.5851724 , 0.5309347 , 0.4801836 ,
#        0.41573298, 0.36511868, 0.31384093, 0.2402735 , 0.19439425],
#       dtype=float32)

# %%
y_test_invert = scaler.inverse_transform(y_test)
y_test_invert
y_test_invert_final = []
# Inverse Box-Cox Transform
for i in range(len(y_test_invert[0])):
    y_test_invert_final.append(invert_boxcox(y_test_invert[0][i], ts_lamb))
x = np.arange(30)
plt.bar(x, y_test_invert_final)
# Out:
# <BarContainer object of 30 artists>

# %%
y_pred_invert = scaler.inverse_transform(prediction)

y_pred_invert_final = []
# Inverse Box-Cox Transform
for i in range(len(y_pred_invert[0])):
    y_pred_invert_final.append(invert_boxcox(y_pred_invert[0][i], ts_lamb))
x = np.arange(30)
plt.bar(x, y_pred_invert_final)
# Out:
# <BarContainer object of 30 artists>

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_pred_invert_final, y_test_invert_final)
r2 = r2_score(y_pred_invert_final, y_test_invert_final)
print('Predicted MSE : %s'%mse)
print('Predicted R2 Score : %s'%r2)
# Out:
# Predicted MSE : 57.025508259285424
# Predicted R2 Score : 0.5124752740456615

# %%
y_pred_invert
# Out:
# array([[15.250128, 15.021123, 14.975869, 14.999499, 15.0417  , 15.179277,
#         15.384027, 15.712306, 15.958707, 16.318287, 16.653702, 16.938303,
#         17.248777, 17.523659, 17.837038, 18.05735 , 18.20798 , 18.29303 ,
#         18.341852, 18.292688, 18.210012, 18.093708, 17.807234, 17.474737,
#         17.163616, 16.76851 , 16.458227, 16.143877, 15.692883, 15.411626]],
#       dtype=float32)

# %%
y_test_invert
# Out:
# array([[14.75274718, 14.52532563, 14.43978398, 14.73415866, 14.93712005,
#         16.31742387, 15.99903992, 15.45547817, 15.7767913 , 16.99510365,
#         17.62197755, 17.53821249, 18.05517037, 17.95538347, 18.22478739,
#         19.54693849, 19.18823898, 20.35027236, 19.03428519, 19.34392341,
#         19.34553527, 18.50742023, 18.4990102 , 17.58222371, 18.34088583,
#         16.5565262 , 16.17991096, 15.69968205, 15.58516797, 15.29423038]])

# %%
plt.plot(y_test_invert[0])
plt.plot(y_pred_invert[0])
plt.title('LSTM - 30 Day Forecast')
plt.ylabel('Rainfall')
plt.xlabel('Days')
plt.legend(['Actual', 'Predicted'], loc='upper left')
plt.savefig('saved/lstm/test.png')
plt.show()
